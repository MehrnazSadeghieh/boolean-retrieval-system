# %%
import numpy as np
import nltk
import pandas as pd
import re

# %%
# !pip install hazm --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 371.7/371.7 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 25.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.5/993.5 kB 39.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.7/227.7 kB 18.8 MB/s eta 0:00:00
#   Building wheel for flashtext (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.

# %%
import hazm

# %% [markdown]
# #Persian Dataset

# %%
# !wget https://github.com/mohamad-dehghani/persian-pdf-books-dataset/raw/master/final_books.xlsx
# Out:
# --2023-11-10 16:06:15--  https://github.com/mohamad-dehghani/persian-pdf-books-dataset/raw/master/final_books.xlsx
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/mohamad-dehghani/persian-pdf-books-dataset/master/final_books.xlsx [following]
# --2023-11-10 16:06:16--  https://raw.githubusercontent.com/mohamad-dehghani/persian-pdf-books-dataset/master/final_books.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1380625 (1.3M) [application/octet-stream]
# Saving to: ‘final_books.xlsx’
#
# final_books.xlsx    100%[===================>]   1.32M  6.04MB/s    in 0.2s
#
# 2023-11-10 16:06:16 (6.04 MB/s) - ‘final_books.xlsx’ saved [1380625/1380625]

# %%
df = pd.read_excel('/content/final_books.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2824 entries, 0 to 2823
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     2824 non-null   object
#  1   date      2824 non-null   object
#  2   content   2441 non-null   object
#  3   category  2824 non-null   object
#  4   author    2824 non-null   object
#  5   comments  2824 non-null   object
# dtypes: object(6)
# memory usage: 132.5+ KB

# %%
df.head()
# Out:
#                              title           date  \
# 0             بهترین درسهای زندگی‎     ۲ دی ۱۳۹۸
# 1               از سلاجقه تا صفویه     ۱ دی ۱۳۹۸
# 2                    سرگذشت رضاشاه   ۲۹ آذر ۱۳۹۸
# 3   سیری نوین در فرگشت و اسرار مغز   ۲۸ آذر ۱۳۹۸
# 4                    آسمان پرستاره   ۲۶ آذر ۱۳۹۸
#
#                                              content           category  \
# 0   تی دی جیکس یک کشیش، نویسنده، سخنران آمریکایی ...          روانشناسی
# 1   کتاب حاضر که اینک در دسترس خوانندگان محترم قر...        تاریخ ایران
# 2   دکتر فتح الله بینا تحصیلات خود را در رشته پزش...        تاریخ ایران
# 3   مجموعه پیش رو مطالبیست که در گروه Evolution ت...         علم و دانش
# 4   کتاب آسمان پرستاره نوشته‌ی کتی هایدن، به زبان...  کودکان و نوجوانان
#
#                          author     comments
# 0                  سارا رزولت    بدون دیدگاه
# 1            نصرت الله مشکوتی    بدون دیدگاه
# 2               فتح الله بینا    بدون دیدگاه
# 3                مانی منوچهری    بدون دیدگاه
# 4                   کتی هایدن    بدون دیدگاه

# %%
df.iloc[440:480]
# Out:
#                                                  title            date  \
# 440                              صوتی هاشمی بدون روتوش   ۱۸ بهمن ۱۳۹۶
# 441   تاریخ زندگی اقتصادی روستاییان و طبقات اجتماعی...   ۱۷ بهمن ۱۳۹۶
# 442                    کاهش وزن سریع با ۳۰ تکنیک طلایی   ۱۵ بهمن ۱۳۹۶
# 443                                صوتی روانشناسی زنان   ۱۵ بهمن ۱۳۹۶
# 444                                ایران در عهد باستان   ۱۳ بهمن ۱۳۹۶
# 445        صوتی ناکامی چپ در ایران : شورشیان آرمانخواه   ۱۲ بهمن ۱۳۹۶
# 446               آن زندگی را انتخاب کنید که می خواهید   ۱۰ بهمن ۱۳۹۶
# 447                                      درباره‌ی زمان    ۹ بهمن ۱۳۹۶
# 448                                        صوتی شهریار    ۸ بهمن ۱۳۹۶
# 449                                   PHP به زبان ساده    ۸ بهمن ۱۳۹۶
# 450                                     دانشمندان بزرگ    ۶ بهمن ۱۳۹۶
# 451                                  زندگی و زمانه شاه    ۵ بهمن ۱۳۹۶
# 452                       بابک خرمدین، دلاور آذربایجان    ۴ بهمن ۱۳۹۶
# 453                      تاریخ تریاک و تریاکی در ایران    ۱ بهمن ۱۳۹۶
# 454                                        کریمخان زند    ۱ بهمن ۱۳۹۶
# 455                کتیبه‌ های تخت جمشید از نگاهی دیگر‎     ۲۹ دی ۱۳۹۶
# 456                                        پزشکی آینده     ۲۵ دی ۱۳۹۶
# 457                          جانوران زهرآگین خلیج فارس     ۲۵ دی ۱۳۹۶
# 458                                   همسر دوست داشتنی     ۲۳ دی ۱۳۹۶
# 459                                       فرشتگان بزرگ     ۲۲ دی ۱۳۹۶
# 460                                یک، دو، سه، بینهایت     ۱۹ دی ۱۳۹۶
# 461                  جاذبه های گردشگری در ایران و جهان     ۱۸ دی ۱۳۹۶
# 462                              مروری بر تاریخ آمریکا     ۱۶ دی ۱۳۹۶
# 463                            زبان شناسی و زبان فارسی     ۱۴ دی ۱۳۹۶
# 464                              دانستنی های فیلم سازی     ۱۲ دی ۱۳۹۶
# 465                                       قلعه حیوانات     ۱۱ دی ۱۳۹۶
# 466                             دومینوی تهران فرو ریخت     ۱۱ دی ۱۳۹۶
# 467                         آموزش برنامه نویسی در اکسل      ۹ دی ۱۳۹۶
# 468                                 چگونه انسان غول شد      ۷ دی ۱۳۹۶
# 469                          فارسی دوم دبستان سال ۱۳۶۰      ۵ دی ۱۳۹۶
# 470               تعلیمات اجتماعی سوم ابتدایی سال ۱۳۶۲      ۳ دی ۱۳۹۶
# 471                                    دنیای پس از مرگ      ۲ دی ۱۳۹۶
# 472                            ویتامین ها و مواد معدنی    ۲۹ آذر ۱۳۹۶
# 473                                     لایحه بودجه ۹۷    ۲۶ آذر ۱۳۹۶
# 474                                          اصول تشیع    ۲۵ آذر ۱۳۹۶
# 475                         آرمان شهریاری ایران باستان    ۲۲ آذر ۱۳۹۶
# 476                                              لبخند    ۲۱ آذر ۱۳۹۶
# 477                                           زندگاهان    ۲۱ آذر ۱۳۹۶
# 478                           همه ‌چیز درباره بیت‌کوین    ۱۸ آذر ۱۳۹۶
# 479                                        علوم تکمیلی    ۱۷ آذر ۱۳۹۶
#
#                                                content          category  \
# 440  کتاب صوتی «هاشمی بدون روتوش» مجموعه گفت‌و‌گوها...    دسته‌بندی نشده
# 441   موضوع این کتاب چنانکه از نام آن برمی آید دربا...       تاریخ ایران
# 442   با کتاب کاهش وزن سریع با ۳۰ تکنیک طلایی نوشته...     پزشکی و سلامت
# 443  کتاب صوتی «روانشناسی زنان» (Feminine Psycholog...         روانشناسی
# 444   ایران در عهد باستان: در تاریخ اقوام و پادشاها...       تاریخ ایران
# 445   کتاب صوتی «ناکامی چپ در ایران : شورشیان آرمان...    دسته‌بندی نشده
# 446   اواسط ژانویه بود. در حیاط دانشگاه هاروارد به ...         روانشناسی
# 447   مفهوم زمان چندان آشنا و نزدیک است، که نامفهوم...             فلسفه
# 448  کتاب صوتی «شهریار» اثر نیکولو ماکیاولی (۱۵۲۷-۱...    دسته‌بندی نشده
# 449  در این کتاب سعی شده است که مطالب به زبان و کده...      برنامه نویسی
# 450  کتاب مشتمل بر شرح حال علمایی ست که تحقیقات و آ...         زندگینامه
# 451  «زندگی و زمانه شاه» دی ماه سال ۱۳۸۷ روانه بازا...       تاریخ ایران
# 452   یکی از بزرگترین جنبش هایی که برای کوتاه کردن ...       تاریخ ایران
# 453   تریاک از نخستین داروهایی است که بشر شناخته اس...       تاریخ ایران
# 454   کتاب شرح زندگی کریمخان زند معروف به وکیل الرع...       تاریخ ایران
# 455   تخت جمشید (پارسه) یکی از شاهکار های هنر و تمد...       تاریخ ایران
# 456   آینده پژوهان بر این باورند که پزشکی به آن گون...     پزشکی و سلامت
# 457   دریا گستره‌ای بس زیبا، فریبنده و شگفت انگیز ا...           حیوانات
# 458   کتاب همسر دوست داشتنی نوشته مهدی خدامیان آران...    خانه و خانواده
# 459  مترلینک در سال ۱۸۶۲ در شهر گنت در قسمت فلاندر ...             فلسفه
# 460  از اتم ها و ستارگان و ابرها، از انتروپی و ژن ه...       علوم مهندسی
# 461   ۱۰ آرامگاه تماشایی جهان – ۴نکته مهم در رانندگ...             ایران
# 462   تاریخ آمریکا بعنوان یک کشور به کمابیش دویست س...        تاریخ جهان
# 463   دستور زبان فارسی خانلری اولین بار در سال ۱۳۴۳...        آموزش زبان
# 464   فیلم‌ برداری مهم ‌ترین مرحله تولید فیلم است. ...             سینما
# 465   مزرعهٔ حیوانات ( Animal Farm) که در ایران به ...           حیوانات
# 466   کتاب الکترونیکی «دومینوی تهران فرو ریخت»، یک ...     داستان و رمان
# 467  نسخه‌های ویندوزی نرم‌افزار اکسل از برنامه‌نویس...              آفیس
# 468  انسان ها در حدوذ ۶۰۰۰ سال پیش که مردم بیابان گ...        علم و دانش
# 469   هیچ لذتی برای انسان در هنگام پیری یادآواری کو...   درسی و دانشگاهی
# 470   کودکی از پدیده‌هایی است که می‌تواند تا آخر عم...   درسی و دانشگاهی
# 471   موریس مترلینگ در کتاب «دنیای پس از مرگ» به مس...  علوم ماورا طبیعی
# 472   • « ویتامین A » • «روی» عنصری حیاتی • ” ویتام...     پزشکی و سلامت
# 473   بودجهٔ کل کشور در ایران برنامهٔ مالی دولت این...            اقتصاد
# 474  اصول تشیع بررسی عقاید مذهب تشیع و جواب از شبها...      دینی و مذهبی
# 475  هرکس به تاریخ شاهنشاهی ایران باستان آگاه باشد ...       تاریخ ایران
# 476  مهدی آذریزدی (آذر خرمشاهی)، نویسنده و بازنویس ...     داستان و رمان
# 477   کتاب زندگاهان اثر شروین وکیلی، جلد نخست از مج...             فلسفه
# 478   شاید جالب‌ترین، عجیب‌ترین و کمی هم حسرت‌ بران...            اقتصاد
# 479   علوم تجربی بخشی از دانش امروزی است که حاصل مط...        علم و دانش
#
#                                                 author     comments
# 440            صادق زیباکلام، فرشته‌السادات اتفاق‌فر       ۱ دیدگاه
# 441                                 غلامرضا انصافپور       ۱ دیدگاه
# 442                                 ابراهیم رجب زاده       ۲ دیدگاه
# 443                                      کارن هورنای    بدون دیدگاه
# 444                                   محمدجواد مشکور    بدون دیدگاه
# 445                                     مازیار بهروز    بدون دیدگاه
# 446                                     تال بن شاهار    بدون دیدگاه
# 447                                      شروین وکیلی    بدون دیدگاه
# 448                                  نیکولو ماکیاولی       ۲ دیدگاه
# 449                                    یونس ابراهیمی    بدون دیدگاه
# 450                                        فیلیپ کان    بدون دیدگاه
# 451                                    غلامرضا افخمی       ۲ دیدگاه
# 452                                       سعید نفیسی       ۶ دیدگاه
# 453                                  ح . کوهی کرمانی       ۴ دیدگاه
# 454                                  عبدالحسین نوایی       ۲ دیدگاه
# 455                                      کوروش شهرکی       ۱ دیدگاه
# 456                                دکتر ایرج نبی پور       ۲ دیدگاه
# 457                                دکتر ایرج نبی پور    بدون دیدگاه
# 458                               مهدی خدامیان آرانی       ۲ دیدگاه
# 459                                    موریس مترلینگ       ۱ دیدگاه
# 460                                       جورج گاموف       ۲ دیدگاه
# 461                                       مجله ویستا       ۳ دیدگاه
# 462                                           نامشخص       ۱ دیدگاه
# 463                                پرویز ناتل خانلری    بدون دیدگاه
# 464                                         پیام آور    بدون دیدگاه
# 465                                       جورج اورول      ۴۹ دیدگاه
# 466                                  فرورتیش رضوانیه       ۲ دیدگاه
# 467                                       وحید فرزام       ۱ دیدگاه
# 468                                       ایلین سگال    بدون دیدگاه
# 469                                           نامشخص       ۲ دیدگاه
# 470                                غلامعلی حداد عادل    بدون دیدگاه
# 471                                    موریس مترلینگ       ۳ دیدگاه
# 472                                       مجله ویستا       ۱ دیدگاه
# 473                            سازمان برنامه و بودجه       ۲ دیدگاه
# 474                            ابراهیم انصاری زنجانی    بدون دیدگاه
# 475                                    ولفگانگ کناوت    بدون دیدگاه
# 476                                     مهدی آذریزدی    بدون دیدگاه
# 477                                      شروین وکیلی    بدون دیدگاه
# 478                                     ماهنامه شبکه       ۲ دیدگاه
# 479                سازمان پژوهش و برنامه ریزی آموزشی    بدون دیدگاه

# %%
df['content'].fillna(df['title'], inplace=True)

# %%
null_counts = df.isnull().sum()
null_counts
# Out:
# title       0
# date        0
# content     0
# category    0
# author      0
# comments    0
# dtype: int64

# %%
df['concat'] = df['title'] + ' ' + df['date'] + ' ' + df['content'] + ' ' + df['category'] + ' ' + df['author'] + ' ' + df['comments']
df
# Out:
#                                                title                date  \
# 0                               بهترین درسهای زندگی‎          ۲ دی ۱۳۹۸
# 1                                 از سلاجقه تا صفویه          ۱ دی ۱۳۹۸
# 2                                      سرگذشت رضاشاه        ۲۹ آذر ۱۳۹۸
# 3                     سیری نوین در فرگشت و اسرار مغز        ۲۸ آذر ۱۳۹۸
# 4                                      آسمان پرستاره        ۲۶ آذر ۱۳۹۸
# ...                                              ...                 ...
# 2819                            آشنایی با علم رباتیک   ۱۲ اردیبهشت ۱۳۸۸
# 2820  دانلود مجله الکترونیکی برنامه نویس – شماره اول   ۱۱ اردیبهشت ۱۳۸۸
# 2821                      داستان خواستگاری یا انتخاب   ۱۱ اردیبهشت ۱۳۸۸
# 2822             آشنایی با قطعات سخت افزاری کامپیوتر   ۱۱ اردیبهشت ۱۳۸۸
# 2823                   الکترونیکی آموزش ورد ( word )   ۱۱ اردیبهشت ۱۳۸۸
#
#                                                 content           category  \
# 0      تی دی جیکس یک کشیش، نویسنده، سخنران آمریکایی ...          روانشناسی
# 1      کتاب حاضر که اینک در دسترس خوانندگان محترم قر...        تاریخ ایران
# 2      دکتر فتح الله بینا تحصیلات خود را در رشته پزش...        تاریخ ایران
# 3      مجموعه پیش رو مطالبیست که در گروه Evolution ت...         علم و دانش
# 4      کتاب آسمان پرستاره نوشته‌ی کتی هایدن، به زبان...  کودکان و نوجوانان
# ...                                                 ...                ...
# 2819                               آشنایی با علم رباتیک             رباتیک
# 2820     دانلود مجله الکترونیکی برنامه نویس – شماره اول       برنامه نویسی
# 2821   کتابی که می خواهید مطالعه کنید به صورت فیلم ن...      داستان و رمان
# 2822                آشنایی با قطعات سخت افزاری کامپیوتر          سخت افزار
# 2823                      الکترونیکی آموزش ورد ( word )               آفیس
#
#                             author     comments  \
# 0                     سارا رزولت    بدون دیدگاه
# 1               نصرت الله مشکوتی    بدون دیدگاه
# 2                  فتح الله بینا    بدون دیدگاه
# 3                   مانی منوچهری    بدون دیدگاه
# 4                      کتی هایدن    بدون دیدگاه
# ...                            ...          ...
# 2819                  شبنم عاقلی      ۲۱ دیدگاه
# 2820            Barnamenevis.org      ۱۰ دیدگاه
# 2821                 م. مودب پور      ۱۲ دیدگاه
# 2822                    پارس بوک      ۵۲ دیدگاه
# 2823               امین مهدی پور      ۳۸ دیدگاه
#
#                                                  concat
# 0      بهترین درسهای زندگی‎  ۲ دی ۱۳۹۸   تی دی جیکس ...
# 1      از سلاجقه تا صفویه  ۱ دی ۱۳۹۸   کتاب حاضر که ...
# 2      سرگذشت رضاشاه  ۲۹ آذر ۱۳۹۸   دکتر فتح الله بی...
# 3      سیری نوین در فرگشت و اسرار مغز  ۲۸ آذر ۱۳۹۸  ...
# 4      آسمان پرستاره  ۲۶ آذر ۱۳۹۸   کتاب آسمان پرستا...
# ...                                                 ...
# 2819   آشنایی با علم رباتیک  ۱۲ اردیبهشت ۱۳۸۸   آشنا...
# 2820  دانلود مجله الکترونیکی برنامه نویس – شماره اول...
# 2821   داستان خواستگاری یا انتخاب  ۱۱ اردیبهشت ۱۳۸۸ ...
# 2822   آشنایی با قطعات سخت افزاری کامپیوتر  ۱۱ اردیب...
# 2823   الکترونیکی آموزش ورد ( word )  ۱۱ اردیبهشت ۱۳...
#
# [2824 rows x 7 columns]

# %%
from hazm import Normalizer, Stemmer, stopwords_list, WordTokenizer

normalizer = Normalizer()
stemmer = Stemmer()
persian_stopwords = set(stopwords_list())

def tokenize_persian(text):
    text = remove_punctuation_persian(text)
    tokenizer = hazm.WordTokenizer()
    tokens = tokenizer.tokenize(text)
    return tokens

def remove_punctuation_persian(text):
    text = re.sub(r'_', '\u200c', text)
    punctuation_pattern = r'[^\w\s]+'
    text = re.sub(punctuation_pattern, ' ', text)
    text = text.strip()

    return text

def normalize_persian(tokens):
    tokens = [normalizer.normalize(token) for token in tokens]
    return tokens

def stemming(tokens):
    tokens = [stemmer.stem(token) for token in tokens]
    return tokens

def remove_stopwords(tokens):
    tokens = [token for token in tokens if token not in persian_stopwords]
    return tokens

df['tokenized_content'] = df['concat'].apply(tokenize_persian)
df['tokenized_content'] = df['tokenized_content'].apply(remove_stopwords)
df['normalized_content'] = df['tokenized_content'].apply(normalize_persian)
df['stemming_content'] = df['normalized_content'].apply(stemming)

# %%
print(df.loc[0,'tokenized_content'])
# Out:
# ['درسهای', 'زندگی', '۲', 'دی', '۱۳۹۸', 'تی', 'دی', 'جیکس', 'کشیش', 'نویسنده', 'سخنران', 'آمریکایی', 'سمینار', 'های', 'تی', 'دی', 'جیکس', 'انگیزشی', 'مذهبی', 'دلیل', 'ایران', 'سخنران', 'انگیزشی', 'سیاه', 'پوست', 'لقب', 'زندگینامه', 'تی', 'دی', 'جیکس', 'شاهد', 'فعالیت', 'های', 'مختلفی', 'خواهان', 'تجربه', 'تلاش', 'مواردی', 'اعلام', 'فعالیت', 'های', 'جیکس', 'کشیش', 'خانه', 'پاتر', 'مخاطبان', 'موعظه', 'های\xa0', 'سخنرانی', 'ها', 'تی', 'دی', 'جیکس', 'کلیسا', 'شبکه', 'های', 'تلویزیونی', 'رادیویی', 'مختلف', 'کتاب', 'گزیده_ای', 'سخنرانی', 'های', 'جیکز', 'سخنران', 'های', 'انگیزشی', 'دنیا', 'امید', 'مطالعه', 'دقیق', 'باور', 'عمیق', 'تغییری', 'مثبت', 'زندگیتان', 'ایجاد', 'روانشناسی', 'سارا', 'رزولت', 'دیدگاه']

# %%
print(df.loc[0,'normalized_content'])
# Out:
# ['درسهای', 'زندگی', '۲', 'دی', '۱۳۹۸', 'تی', 'دی', 'جیکس', 'کشیش', 'نویسنده', 'سخنران', 'آمریکایی', 'سمینار', 'های', 'تی', 'دی', 'جیکس', 'انگیزشی', 'مذهبی', 'دلیل', 'ایران', 'سخنران', 'انگیزشی', 'سیاه', 'پوست', 'لقب', 'زندگینامه', 'تی', 'دی', 'جیکس', 'شاهد', 'فعالیت', 'های', 'مختلفی', 'خواهان', 'تجربه', 'تلاش', 'مواردی', 'اعلام', 'فعالیت', 'های', 'جیکس', 'کشیش', 'خانه', 'پاتر', 'مخاطبان', 'موعظه', 'های', 'سخنرانی', 'ها', 'تی', 'دی', 'جیکس', 'کلیسا', 'شبکه', 'های', 'تلویزیونی', 'رادیویی', 'مختلف', 'کتاب', 'گزیده_ای', 'سخنرانی', 'های', 'جیکز', 'سخنران', 'های', 'انگیزشی', 'دنیا', 'امید', 'مطالعه', 'دقیق', 'باور', 'عمیق', 'تغییری', 'مثبت', 'زندگیتان', 'ایجاد', 'روانشناسی', 'سارا', 'رزولت', 'دیدگاه']

# %%
print(df.loc[0,'stemming_content'])
# Out:
# ['درس', 'زندگ', '۲', 'د', '۱۳۹۸', 'ت', 'د', 'جیکس', 'کش', 'نویسنده', 'سخنر', 'آمریکا', 'سمینار', '', 'ت', 'د', 'جیکس', 'انگیزش', 'مذهب', 'دلیل', 'ایر', 'سخنر', 'انگیزش', 'سیاه', 'پوس', 'لقب', 'زندگینامه', 'ت', 'د', 'جیکس', 'شاهد', 'فعال', '', 'مختلف', 'خواه', 'تجربه', 'تلا', 'موارد', 'اعلا', 'فعال', '', 'جیکس', 'کش', 'خانه', 'پا', 'مخاطب', 'موعظه', '', 'سخنران', '', 'ت', 'د', 'جیکس', 'کلیسا', 'شبکه', '', 'تلویزیون', 'رادیو', 'مختلف', 'کتاب', 'گزیده_ا', 'سخنران', '', 'جیکز', 'سخنر', '', 'انگیزش', 'دنیا', 'امید', 'مطالعه', 'دقیق', 'باور', 'عمیق', 'تغییر', 'مثب', 'زندگ', 'ایجاد', 'روانشناس', 'سارا', 'رزول', 'دیدگاه']

# %%
df.iloc[0]
# Out:
# title                                              بهترین درسهای زندگی‎
# date                                                         ۲ دی ۱۳۹۸
# content                تی دی جیکس یک کشیش، نویسنده، سخنران آمریکایی ...
# category                                                      روانشناسی
# author                                                     سارا رزولت
# comments                                                    بدون دیدگاه
# concat                 بهترین درسهای زندگی‎  ۲ دی ۱۳۹۸   تی دی جیکس ...
# tokenized_content     [درسهای, زندگی, ۲, دی, ۱۳۹۸, تی, دی, جیکس, کشی...
# normalized_content    [درسهای, زندگی, ۲, دی, ۱۳۹۸, تی, دی, جیکس, کشی...
# stemming_content      [درس, زندگ, ۲, د, ۱۳۹۸, ت, د, جیکس, کش, نویسند...
# Name: 0, dtype: object

# %%
from collections import defaultdict

def create_persian_inverted_index(df):
  subset_dataset = df.head(1000)

  inverted_index = defaultdict(list)
  term_dictionary = defaultdict(int)

  for index, row in subset_dataset.iterrows():
      document_id = index + 1
      normalized_text = row['stemming_content']

      term_count = defaultdict(int)
      for token in normalized_text:
          term_count[token] += 1

      for term, count in term_count.items():
          if term not in term_dictionary:
              term_dictionary[term] = 0
          term_dictionary[term] += count

          inverted_index[term].append((document_id, count))

  for term, postings in inverted_index.items():
      inverted_index[term] = sorted(postings, key=lambda x: x[1], reverse=True)


  with open('inverted_index_persian.txt', 'w') as file:
    for term, postings in inverted_index.items():
        term_freq = term_dictionary[term]
        posting_list = [(doc_id, count) for doc_id, count in postings]
        output_line = f"({term}) : frequency = {term_freq}, posting list: {posting_list}\n"
        print(f"({term}) : frequency = {term_freq}, posting list: {posting_list}")
        file.write(output_line)

  return inverted_index

# %%
def create_terms_binary(inverted_index):
  terms_binary = {}

  unique_docs = set(doc_id for postings in inverted_index.values() for _, doc_id in postings)

  for term, postings in inverted_index.items():
      term_occurrence_list = [1 if doc_id in {doc_id for _, doc_id in postings} else 0 for doc_id in unique_docs]
      terms_binary[term] = term_occurrence_list

  return terms_binary

# %%
import re

def persian_query_processing(query):
    pattern = r'[^\.\+]+|[\.\+]'
    matches = re.findall(pattern, query)

    terms = []
    operators = []

    for match in matches:
        if match in ('.', '+'):
            operators.append(match)
        else:
            terms.append(match)

    for i in terms:
      print(i)

    print("List of terms:", terms)
    print("List of operators:", operators)

    return terms, operators

# %%
def process_term_in_query_persian(term):
  tokenized = tokenize_persian(term)
  normalized = normalize_persian(tokenized)
  stem = stemming(normalized)

  return stem

# %%
def boolean_retrieval(terms_binary, terms, operators):

  length_of_values = max(len(value) for value in terms_binary.values())

  cur_term = terms[0]
  is_not = 0

  print('term: ', cur_term)

  if cur_term.startswith('!'):
    cur_term = cur_term[1:]
    is_not = 1

  processed_term = process_term_in_query_persian(cur_term)[0]
  print('processed term : ', processed_term)

  if processed_term in terms_binary:
    term_binary = terms_binary.get(processed_term, '')
    term_binary = ''.join(map(str, term_binary))
  else:
    term_binary = '0'.zfill(length_of_values)
    print('(not found)')

  if is_not == 1:
    term_binary = ''.join(['1' if bit == '0' else '0' for bit in term_binary])
    print('(NOT)')

  print('term binary : ', term_binary)

  result = term_binary


  for i in range(1, len(terms)):
      is_not = 0
      term = terms[i]
      operator = operators[i - 1]
      print('term : ', term)

      if term.startswith('!'):
        term = term[1:]
        is_not = 1

      processed_term = process_term_in_query_persian(term)[0]

      print('processed term : ', processed_term)


      if processed_term in terms_binary:
        term_binary = terms_binary.get(processed_term, '')
        term_binary = ''.join(map(str, term_binary))
      else:
        term_binary = '0'.zfill(length_of_values)
        print('(not found)')

      if is_not == 1:
        term_binary = ''.join(['1' if bit == '0' else '0' for bit in term_binary])
        print('(NOT)')

      print('term binary : ', term_binary)

      if operator == '+':
          result = "".join(['1' if a == '1' or b == '1' else '0' for a, b in zip(result, term_binary)])
      elif operator == '.':
          result = "".join(['1' if a == '1' and b == '1' else '0' for a, b in zip(result, term_binary)])

  document_numbers = [i + 1 for i, bit in enumerate(result) if bit == '1']

  print("Result:", result)
  print("Document Numbers:", document_numbers)

  return result, document_numbers

# %%
import time
start_time = time.time()
persian_inverted_index = create_persian_inverted_index(df)
end_time = time.time()
execution_time = end_time - start_time
print(f"زمان اجرا: {execution_time} ثانیه")
# Out:
# Streaming output truncated to the last 5000 lines.
# (۱۳۸۰) : frequency = 2, posting list: [(417, 1), (592, 1)]
# (پارسه) : frequency = 4, posting list: [(456, 3), (417, 1)]
# (تأسیس) : frequency = 5, posting list: [(417, 1), (426, 1), (511, 1), (628, 1), (912, 1)]
# (آدولف) : frequency = 9, posting list: [(418, 4), (567, 2), (925, 2), (613, 1)]
# (هیتلر) : frequency = 13, posting list: [(418, 5), (925, 5), (460, 1), (567, 1), (613, 1)]
# (۱۸۸۹) : frequency = 2, posting list: [(418, 1), (939, 1)]
# (ناز) : frequency = 7, posting list: [(567, 4), (418, 2), (613, 1)]
# (صدراعظ) : frequency = 3, posting list: [(418, 2), (530, 1)]
# (سودا) : frequency = 2, posting list: [(418, 1), (428, 1)]
# (نقا) : frequency = 9, posting list: [(604, 4), (513, 2), (418, 1), (608, 1), (785, 1)]
# (پروراند) : frequency = 1, posting list: [(418, 1)]
# (فجایع) : frequency = 1, posting list: [(418, 1)]
# (نافرجا) : frequency = 1, posting list: [(418, 1)]
# (جوفروش) : frequency = 1, posting list: [(418, 1)]
# (مونیخ) : frequency = 1, posting list: [(418, 1)]
# (وایمار) : frequency = 1, posting list: [(418, 1)]
# (بدل) : frequency = 4, posting list: [(418, 1), (441, 1), (449, 1), (572, 1)]
# (ترج) : frequency = 1, posting list: [(418, 1)]
# (ناسیونال) : frequency = 4, posting list: [(418, 2), (925, 2)]
# (سوسیالیس) : frequency = 5, posting list: [(925, 2), (418, 1), (502, 1), (964, 1)]
# (تسویه) : frequency = 1, posting list: [(418, 1)]
# (رودلف) : frequency = 2, posting list: [(418, 1), (925, 1)]
# (دیکته) : frequency = 4, posting list: [(901, 2), (418, 1), (925, 1)]
# (سوسیالیست) : frequency = 5, posting list: [(502, 3), (418, 1), (943, 1)]
# (بازنگر) : frequency = 3, posting list: [(418, 1), (651, 1), (674, 1)]
# (اتر) : frequency = 5, posting list: [(418, 1), (436, 1), (753, 1), (804, 1), (982, 1)]
# (چندان) : frequency = 5, posting list: [(418, 1), (429, 1), (435, 1), (958, 1), (961, 1)]
# (دیرینه) : frequency = 2, posting list: [(418, 1), (627, 1)]
# (خواست) : frequency = 2, posting list: [(418, 1), (490, 1)]
# (نیکبخت) : frequency = 1, posting list: [(418, 1)]
# (بیگانگ) : frequency = 3, posting list: [(418, 1), (776, 1), (840, 1)]
# (معا) : frequency = 1, posting list: [(418, 1)]
# (خواهد_گرف) : frequency = 4, posting list: [(432, 2), (418, 1), (500, 1)]
# (حاصلخیز) : frequency = 3, posting list: [(418, 1), (469, 1), (622, 1)]
# (افک) : frequency = 1, posting list: [(419, 1)]
# (دوربر) : frequency = 1, posting list: [(419, 1)]
# (گرادیان) : frequency = 1, posting list: [(419, 1)]
# (تعلیم) : frequency = 2, posting list: [(420, 1), (637, 1)]
# (همسو) : frequency = 4, posting list: [(420, 1), (449, 1), (631, 1), (791, 1)]
# (فراتحلیل) : frequency = 1, posting list: [(420, 1)]
# (تبیین) : frequency = 10, posting list: [(651, 2), (420, 1), (449, 1), (630, 1), (642, 1), (898, 1), (907, 1), (921, 1), (964, 1)]
# (محمدتق) : frequency = 3, posting list: [(421, 1), (620, 1), (888, 1)]
# (مطمئنا) : frequency = 2, posting list: [(422, 1), (722, 1)]
# (یافته_ا) : frequency = 1, posting list: [(422, 1)]
# (نتوانسته_ا) : frequency = 2, posting list: [(422, 1), (435, 1)]
# (برآ) : frequency = 1, posting list: [(422, 1)]
# (پیش) : frequency = 1, posting list: [(422, 1)]
# (نگرفتن) : frequency = 2, posting list: [(422, 1), (727, 1)]
# (سعدیا) : frequency = 3, posting list: [(428, 2), (422, 1)]
# (سخند) : frequency = 1, posting list: [(422, 1)]
# (برآید) : frequency = 3, posting list: [(422, 1), (442, 1), (840, 1)]
# (سخندان) : frequency = 1, posting list: [(422, 1)]
# (میرابوالقاسم) : frequency = 1, posting list: [(422, 1)]
# (درآمدزا) : frequency = 2, posting list: [(423, 2)]
# (استثنائ) : frequency = 3, posting list: [(424, 2), (930, 1)]
# (بینظیر) : frequency = 1, posting list: [(424, 1)]
# (مجمل) : frequency = 2, posting list: [(424, 2)]
# (بگوئ) : frequency = 1, posting list: [(424, 1)]
# (لابلا) : frequency = 1, posting list: [(424, 1)]
# (اشار) : frequency = 2, posting list: [(424, 1), (645, 1)]
# (مستقیم) : frequency = 1, posting list: [(424, 1)]
# (گفته_باشد) : frequency = 1, posting list: [(424, 1)]
# (گوهر) : frequency = 1, posting list: [(424, 1)]
# (جاود) : frequency = 1, posting list: [(424, 1)]
# (ملول) : frequency = 1, posting list: [(424, 1)]
# (نمی‌شوید) : frequency = 1, posting list: [(424, 1)]
# (سخنان) : frequency = 4, posting list: [(424, 1), (456, 1), (712, 1), (776, 1)]
# (کهنگ) : frequency = 1, posting list: [(424, 1)]
# (نمی‌کنید) : frequency = 2, posting list: [(424, 1), (560, 1)]
# (خلیفه) : frequency = 2, posting list: [(424, 1), (453, 1)]
# (عبدالحک) : frequency = 1, posting list: [(424, 1)]
# (آموزنده) : frequency = 12, posting list: [(517, 4), (425, 1), (495, 1), (546, 1), (681, 1), (699, 1), (810, 1), (916, 1), (986, 1)]
# (تجسم) : frequency = 2, posting list: [(426, 1), (805, 1)]
# (ماک) : frequency = 4, posting list: [(785, 3), (426, 1)]
# (متره) : frequency = 1, posting list: [(426, 1)]
# (ترازیاب) : frequency = 1, posting list: [(426, 1)]
# (نیوز) : frequency = 1, posting list: [(426, 1)]
# (یزد) : frequency = 7, posting list: [(426, 1), (462, 1), (477, 1), (509, 1), (591, 1), (798, 1), (856, 1)]
# (دیتیل) : frequency = 1, posting list: [(426, 1)]
# (محوطه) : frequency = 1, posting list: [(426, 1)]
# (فرنو) : frequency = 1, posting list: [(426, 1)]
# (دباغ) : frequency = 1, posting list: [(426, 1)]
# (پدیدار) : frequency = 4, posting list: [(427, 1), (610, 1), (653, 1), (762, 1)]
# (برانگیخ) : frequency = 3, posting list: [(427, 1), (687, 1), (770, 1)]
# (سطور) : frequency = 1, posting list: [(427, 1)]
# (کاربس) : frequency = 2, posting list: [(427, 1), (627, 1)]
# (برداشت) : frequency = 3, posting list: [(427, 1), (448, 1), (982, 1)]
# (بدنه) : frequency = 2, posting list: [(427, 1), (548, 1)]
# (بدایع) : frequency = 2, posting list: [(428, 2)]
# (دایع) : frequency = 1, posting list: [(428, 1)]
# (مصلح) : frequency = 1, posting list: [(428, 1)]
# (نفیس) : frequency = 10, posting list: [(615, 4), (428, 1), (453, 1), (458, 1), (604, 1), (679, 1), (859, 1)]
# (بزرگوار) : frequency = 3, posting list: [(428, 1), (585, 1), (654, 1)]
# (مصروف) : frequency = 1, posting list: [(428, 1)]
# (۵۸۰) : frequency = 1, posting list: [(428, 1)]
# (۶۹۱) : frequency = 1, posting list: [(428, 1)]
# (اتابک) : frequency = 2, posting list: [(428, 1), (620, 1)]
# (بکر) : frequency = 1, posting list: [(428, 1)]
# (بیستون) : frequency = 2, posting list: [(428, 1), (614, 1)]
# (درو) : frequency = 3, posting list: [(428, 1), (644, 1), (782, 1)]
# (کنج) : frequency = 1, posting list: [(428, 1)]
# (منسب) : frequency = 1, posting list: [(428, 1)]
# (فان) : frequency = 2, posting list: [(428, 1), (650, 1)]
# (عاقل) : frequency = 2, posting list: [(428, 1), (932, 1)]
# (وآنچه) : frequency = 1, posting list: [(428, 1)]
# (غفل) : frequency = 4, posting list: [(428, 1), (588, 1), (671, 1), (707, 1)]
# (مگذار) : frequency = 1, posting list: [(428, 1)]
# (فو) : frequency = 2, posting list: [(428, 1), (798, 1)]
# (ناد) : frequency = 1, posting list: [(428, 1)]
# (هندو) : frequency = 7, posting list: [(548, 3), (428, 2), (568, 1), (652, 1)]
# (بحشر) : frequency = 1, posting list: [(428, 1)]
# (متفرق) : frequency = 1, posting list: [(428, 1)]
# (اندر) : frequency = 2, posting list: [(428, 2)]
# (نیارد) : frequency = 1, posting list: [(428, 1)]
# (ربود) : frequency = 1, posting list: [(428, 1)]
# (تاختن) : frequency = 1, posting list: [(428, 1)]
# (اجل) : frequency = 2, posting list: [(428, 1), (447, 1)]
# (قیام) : frequency = 4, posting list: [(752, 2), (428, 1), (897, 1)]
# (خیمه) : frequency = 1, posting list: [(428, 1)]
# (نرسد) : frequency = 1, posting list: [(428, 1)]
# (لاف) : frequency = 1, posting list: [(428, 1)]
# (مزن) : frequency = 1, posting list: [(428, 1)]
# (نخواهد_خرید) : frequency = 1, posting list: [(428, 1)]
# (غمزه) : frequency = 2, posting list: [(428, 1), (644, 1)]
# (نوساز) : frequency = 6, posting list: [(429, 3), (483, 1), (649, 1), (663, 1)]
# (مایه) : frequency = 9, posting list: [(429, 1), (481, 1), (500, 1), (547, 1), (588, 1), (628, 1), (632, 1), (652, 1), (883, 1)]
# (ایستا) : frequency = 3, posting list: [(429, 1), (618, 1), (689, 1)]
# (دامدار) : frequency = 1, posting list: [(429, 1)]
# (قبله) : frequency = 1, posting list: [(429, 1)]
# (شهرنشین) : frequency = 2, posting list: [(429, 1), (707, 1)]
# (آستانه) : frequency = 5, posting list: [(429, 1), (684, 1), (767, 1), (788, 1), (833, 1)]
# (پراکنده) : frequency = 3, posting list: [(429, 1), (654, 1), (785, 1)]
# (منقطع) : frequency = 1, posting list: [(429, 1)]
# (منفک) : frequency = 1, posting list: [(429, 1)]
# (گذاردن) : frequency = 1, posting list: [(429, 1)]
# (دوگانه) : frequency = 2, posting list: [(429, 1), (532, 1)]
# (نارضایت) : frequency = 4, posting list: [(429, 1), (463, 1), (507, 1), (819, 1)]
# (کاود) : frequency = 1, posting list: [(429, 1)]
# (بارقه) : frequency = 1, posting list: [(429, 1)]
# (طلبانه) : frequency = 2, posting list: [(429, 1), (833, 1)]
# (ناصرالدین) : frequency = 24, posting list: [(614, 5), (841, 5), (530, 3), (705, 3), (804, 3), (429, 1), (540, 1), (600, 1), (687, 1), (936, 1)]
# (گذر) : frequency = 4, posting list: [(429, 1), (523, 1), (740, 1), (761, 1)]
# (بطل) : frequency = 1, posting list: [(429, 1)]
# (نهادن) : frequency = 1, posting list: [(429, 1)]
# (تنباکو) : frequency = 4, posting list: [(530, 3), (429, 1)]
# (مارکسیس) : frequency = 6, posting list: [(564, 2), (429, 1), (446, 1), (943, 1), (964, 1)]
# (فئودالیس) : frequency = 3, posting list: [(429, 1), (564, 1), (864, 1)]
# (بورژواز) : frequency = 1, posting list: [(429, 1)]
# (نرسید) : frequency = 2, posting list: [(429, 1), (609, 1)]
# (برشمارد) : frequency = 1, posting list: [(429, 1)]
# (بگذر) : frequency = 2, posting list: [(429, 1), (961, 1)]
# (جملگ) : frequency = 1, posting list: [(429, 1)]
# (نتوانستند) : frequency = 1, posting list: [(429, 1)]
# (توفیق) : frequency = 3, posting list: [(429, 1), (532, 1), (884, 1)]
# (ناکا) : frequency = 3, posting list: [(429, 1), (654, 1), (663, 1)]
# (ماندند) : frequency = 2, posting list: [(429, 1), (647, 1)]
# (یاسر) : frequency = 3, posting list: [(430, 2), (952, 1)]
# (خواهیم_جلو) : frequency = 1, posting list: [(430, 1)]
# (خواهیم_با) : frequency = 1, posting list: [(430, 1)]
# (ترسیدند) : frequency = 1, posting list: [(430, 1)]
# (قلاب) : frequency = 7, posting list: [(431, 6), (566, 1)]
# (مباجث) : frequency = 1, posting list: [(431, 1)]
# (نخ) : frequency = 3, posting list: [(885, 2), (431, 1)]
# (شس) : frequency = 2, posting list: [(431, 1), (518, 1)]
# (تورباف) : frequency = 1, posting list: [(431, 1)]
# (خواهد_پرداخ) : frequency = 1, posting list: [(431, 1)]
# (جادکمه) : frequency = 1, posting list: [(431, 1)]
# (ریسمان) : frequency = 2, posting list: [(431, 1), (794, 1)]
# (هنرل) : frequency = 1, posting list: [(431, 1)]
# (جوزف) : frequency = 4, posting list: [(432, 3), (552, 1)]
# (جابه) : frequency = 2, posting list: [(432, 1), (860, 1)]
# (سابق) : frequency = 6, posting list: [(432, 1), (596, 1), (790, 1), (865, 1), (896, 1), (923, 1)]
# (گرفته_باشد) : frequency = 2, posting list: [(432, 1), (522, 1)]
# (مبدا) : frequency = 3, posting list: [(432, 1), (460, 1), (625, 1)]
# (برتر) : frequency = 3, posting list: [(432, 2), (816, 1)]
# (موازنه) : frequency = 2, posting list: [(432, 2)]
# (نامعلو) : frequency = 2, posting list: [(432, 1), (553, 1)]
# (۲۰۴۱) : frequency = 1, posting list: [(432, 1)]
# (تحلیلگر) : frequency = 1, posting list: [(432, 1)]
# (ویک) : frequency = 5, posting list: [(684, 4), (432, 1)]
# (مغلوب) : frequency = 4, posting list: [(432, 1), (708, 1), (794, 1), (921, 1)]
# (پساآمریکا) : frequency = 1, posting list: [(432, 1)]
# (نشده_ا) : frequency = 3, posting list: [(432, 1), (545, 1), (940, 1)]
# (پیکار) : frequency = 3, posting list: [(433, 2), (962, 1)]
# (شین) : frequency = 5, posting list: [(433, 4), (907, 1)]
# (پرتو) : frequency = 10, posting list: [(433, 7), (625, 2), (457, 1)]
# (شیرازپور) : frequency = 1, posting list: [(433, 1)]
# (۱۲۸۶) : frequency = 2, posting list: [(433, 1), (939, 1)]
# (کنگاور) : frequency = 2, posting list: [(433, 1), (614, 1)]
# (درگذشته) : frequency = 3, posting list: [(433, 1), (557, 1), (861, 1)]
# (فیلمبردار) : frequency = 1, posting list: [(433, 1)]
# (ویشکا) : frequency = 1, posting list: [(433, 1)]
# (شاعرانه) : frequency = 2, posting list: [(433, 1), (860, 1)]
# (منثور) : frequency = 2, posting list: [(433, 1), (615, 1)]
# (میه) : frequency = 3, posting list: [(731, 2), (433, 1)]
# (انیر) : frequency = 1, posting list: [(433, 1)]
# (دارنده) : frequency = 1, posting list: [(434, 1)]
# (فارق) : frequency = 1, posting list: [(434, 1)]
# (بروس) : frequency = 1, posting list: [(434, 1)]
# (حمیدرضا) : frequency = 3, posting list: [(434, 1), (673, 1), (744, 1)]
# (تمهید) : frequency = 1, posting list: [(435, 1)]
# (۵۷) : frequency = 5, posting list: [(619, 2), (435, 1), (452, 1), (684, 1)]
# (متحدین) : frequency = 1, posting list: [(435, 1)]
# (بالاخص) : frequency = 3, posting list: [(435, 2), (723, 1)]
# (رفته_بودند) : frequency = 1, posting list: [(435, 1)]
# (تحولات) : frequency = 1, posting list: [(435, 1)]
# (دموکر) : frequency = 1, posting list: [(435, 1)]
# (جیم) : frequency = 1, posting list: [(435, 1)]
# (نوب) : frequency = 8, posting list: [(483, 2), (435, 1), (489, 1), (648, 1), (750, 1), (788, 1), (867, 1)]
# (واشنگتن) : frequency = 1, posting list: [(435, 1)]
# (محافل) : frequency = 3, posting list: [(435, 1), (627, 1), (709, 1)]
# (زیاد) : frequency = 3, posting list: [(435, 1), (720, 1), (991, 1)]
# (وابستگ) : frequency = 3, posting list: [(435, 1), (696, 1), (993, 1)]
# (یکسویه) : frequency = 1, posting list: [(435, 1)]
# (مسخ) : frequency = 7, posting list: [(806, 6), (435, 1)]
# (شعارزده) : frequency = 1, posting list: [(435, 1)]
# (غیرواقع) : frequency = 1, posting list: [(435, 1)]
# (روانکاور) : frequency = 1, posting list: [(436, 1)]
# (روانکاو) : frequency = 12, posting list: [(436, 7), (710, 3), (444, 1), (671, 1)]
# (Question) : frequency = 1, posting list: [(436, 1)]
# (Lay) : frequency = 1, posting list: [(436, 1)]
# (واجد) : frequency = 5, posting list: [(682, 2), (436, 1), (492, 1), (604, 1)]
# (گذرانده_باشند) : frequency = 1, posting list: [(436, 1)]
# (می‌انج) : frequency = 2, posting list: [(436, 1), (664, 1)]
# (نارسا) : frequency = 3, posting list: [(436, 1), (977, 1), (999, 1)]
# (غرایز) : frequency = 2, posting list: [(436, 1), (966, 1)]
# (نخود) : frequency = 3, posting list: [(436, 1), (521, 1), (782, 1)]
# (خواهد_خود) : frequency = 1, posting list: [(436, 1)]
# (زیگموند) : frequency = 4, posting list: [(436, 1), (710, 1), (959, 1), (963, 1)]
# (خواهید_برد) : frequency = 1, posting list: [(437, 1)]
# (دلهره) : frequency = 2, posting list: [(437, 1), (672, 1)]
# (سینا) : frequency = 7, posting list: [(988, 2), (437, 1), (477, 1), (576, 1), (615, 1), (842, 1)]
# (یرواند) : frequency = 11, posting list: [(735, 5), (438, 3), (809, 3)]
# (آبراهام) : frequency = 13, posting list: [(735, 6), (809, 4), (438, 3)]
# (۱۹۴۰) : frequency = 3, posting list: [(438, 1), (460, 1), (972, 1)]
# (خصوم) : frequency = 4, posting list: [(710, 2), (438, 1), (838, 1)]
# (سرنگون) : frequency = 3, posting list: [(438, 2), (453, 1)]
# (محمدرضاشاه) : frequency = 1, posting list: [(438, 1)]
# (۱۳۵۸) : frequency = 6, posting list: [(438, 1), (441, 1), (446, 1), (488, 1), (637, 1), (944, 1)]
# (گروگ) : frequency = 2, posting list: [(438, 1), (441, 1)]
# (اسار) : frequency = 2, posting list: [(438, 1), (867, 1)]
# (۴۴۴) : frequency = 1, posting list: [(438, 1)]
# (اریبه) : frequency = 1, posting list: [(438, 1)]
# (زده_شد) : frequency = 2, posting list: [(438, 1), (988, 1)]
# (گسل) : frequency = 1, posting list: [(438, 1)]
# (تقدیر) : frequency = 3, posting list: [(438, 2), (523, 1)]
# (متعارف) : frequency = 2, posting list: [(438, 2)]
# (تلاش) : frequency = 6, posting list: [(438, 1), (518, 1), (631, 1), (780, 1), (886, 1), (995, 1)]
# (درستکار) : frequency = 1, posting list: [(438, 1)]
# (مصالحه) : frequency = 1, posting list: [(438, 1)]
# (سرسخت) : frequency = 1, posting list: [(438, 1)]
# (روانشناسانه) : frequency = 1, posting list: [(438, 1)]
# (برگرد) : frequency = 4, posting list: [(635, 2), (438, 1), (837, 1)]
# (موثق) : frequency = 2, posting list: [(438, 1), (649, 1)]
# (امپریالیس) : frequency = 4, posting list: [(993, 3), (438, 1)]
# (ناسیونالیس) : frequency = 2, posting list: [(438, 1), (449, 1)]
# (پلورالیس) : frequency = 1, posting list: [(438, 1)]
# (زدا) : frequency = 2, posting list: [(438, 2)]
# (سکولار) : frequency = 1, posting list: [(438, 1)]
# (مشروع) : frequency = 2, posting list: [(438, 1), (690, 1)]
# (مرگبار) : frequency = 3, posting list: [(438, 1), (639, 1), (649, 1)]
# (پارانوئید) : frequency = 1, posting list: [(438, 1)]
# (پالا) : frequency = 2, posting list: [(439, 2)]
# (شناختند) : frequency = 1, posting list: [(439, 1)]
# (ندان) : frequency = 1, posting list: [(440, 1)]
# (باکیف) : frequency = 3, posting list: [(440, 1), (527, 1), (605, 1)]
# (تندخوان) : frequency = 5, posting list: [(440, 5)]
# (فرد) : frequency = 1, posting list: [(440, 1)]
# (نظرطب) : frequency = 1, posting list: [(440, 1)]
# (دوپینگ) : frequency = 1, posting list: [(440, 1)]
# (خلسه) : frequency = 2, posting list: [(440, 2)]
# (مراقبه) : frequency = 5, posting list: [(671, 3), (440, 2)]
# (گاشو) : frequency = 2, posting list: [(440, 2)]
# (مقاصد) : frequency = 1, posting list: [(440, 1)]
# (فرشته) : frequency = 4, posting list: [(441, 2), (968, 2)]
# (الساد) : frequency = 2, posting list: [(441, 2)]
# (۱۳۵۶) : frequency = 2, posting list: [(441, 1), (866, 1)]
# (۱۳۲۷) : frequency = 3, posting list: [(441, 1), (518, 1), (532, 1)]
# (۱۳۹۵) : frequency = 257, posting list: [(908, 2), (915, 2), (441, 1), (653, 1), (654, 1), (655, 1), (656, 1), (657, 1), (658, 1), (659, 1), (660, 1), (661, 1), (662, 1), (663, 1), (664, 1), (665, 1), (666, 1), (667, 1), (668, 1), (669, 1), (670, 1), (671, 1), (672, 1), (673, 1), (674, 1), (675, 1), (676, 1), (677, 1), (678, 1), (679, 1), (680, 1), (681, 1), (682, 1), (683, 1), (684, 1), (685, 1), (686, 1), (687, 1), (688, 1), (689, 1), (690, 1), (691, 1), (692, 1), (693, 1), (694, 1), (695, 1), (696, 1), (697, 1), (698, 1), (699, 1), (700, 1), (701, 1), (702, 1), (703, 1), (704, 1), (705, 1), (706, 1), (707, 1), (708, 1), (709, 1), (710, 1), (711, 1), (712, 1), (713, 1), (714, 1), (715, 1), (716, 1), (717, 1), (718, 1), (719, 1), (720, 1), (721, 1), (722, 1), (723, 1), (724, 1), (725, 1), (726, 1), (727, 1), (728, 1), (729, 1), (730, 1), (731, 1), (732, 1), (733, 1), (734, 1), (735, 1), (736, 1), (737, 1), (738, 1), (739, 1), (740, 1), (741, 1), (742, 1), (743, 1), (744, 1), (745, 1), (746, 1), (747, 1), (748, 1), (749, 1), (750, 1), (751, 1), (752, 1), (753, 1), (754, 1), (755, 1), (756, 1), (757, 1), (758, 1), (759, 1), (760, 1), (761, 1), (762, 1), (763, 1), (764, 1), (765, 1), (766, 1), (767, 1), (768, 1), (769, 1), (770, 1), (771, 1), (772, 1), (773, 1), (774, 1), (775, 1), (776, 1), (777, 1), (778, 1), (779, 1), (780, 1), (781, 1), (782, 1), (783, 1), (784, 1), (785, 1), (786, 1), (787, 1), (788, 1), (789, 1), (790, 1), (791, 1), (792, 1), (793, 1), (794, 1), (795, 1), (796, 1), (797, 1), (798, 1), (799, 1), (800, 1), (801, 1), (802, 1), (803, 1), (804, 1), (805, 1), (806, 1), (807, 1), (808, 1), (809, 1), (810, 1), (811, 1), (812, 1), (813, 1), (814, 1), (815, 1), (816, 1), (817, 1), (818, 1), (819, 1), (820, 1), (821, 1), (822, 1), (823, 1), (824, 1), (825, 1), (826, 1), (827, 1), (828, 1), (829, 1), (830, 1), (831, 1), (832, 1), (833, 1), (834, 1), (835, 1), (836, 1), (837, 1), (838, 1), (839, 1), (840, 1), (841, 1), (842, 1), (843, 1), (844, 1), (845, 1), (846, 1), (847, 1), (848, 1), (849, 1), (850, 1), (851, 1), (852, 1), (853, 1), (854, 1), (855, 1), (856, 1), (857, 1), (858, 1), (859, 1), (860, 1), (861, 1), (862, 1), (863, 1), (864, 1), (865, 1), (866, 1), (867, 1), (868, 1), (869, 1), (870, 1), (871, 1), (872, 1), (873, 1), (874, 1), (875, 1), (876, 1), (877, 1), (878, 1), (879, 1), (880, 1), (881, 1), (882, 1), (883, 1), (884, 1), (885, 1), (886, 1), (887, 1), (888, 1), (889, 1), (890, 1), (891, 1), (892, 1), (893, 1), (894, 1), (895, 1), (896, 1), (897, 1), (898, 1), (899, 1), (900, 1), (901, 1), (902, 1), (903, 1), (904, 1)]
# (۱۳۱۳) : frequency = 1, posting list: [(441, 1)]
# (پارگراف) : frequency = 1, posting list: [(441, 1)]
# (گفتگوس) : frequency = 1, posting list: [(441, 1)]
# (الواقع) : frequency = 1, posting list: [(441, 1)]
# (گفته_باش) : frequency = 1, posting list: [(441, 1)]
# (جدل) : frequency = 2, posting list: [(441, 1), (523, 1)]
# (بحبوحه) : frequency = 1, posting list: [(441, 1)]
# (۷۸) : frequency = 1, posting list: [(441, 1)]
# (۱۳۷۷) : frequency = 1, posting list: [(441, 1)]
# (تنور) : frequency = 1, posting list: [(441, 1)]
# (ناظر) : frequency = 4, posting list: [(441, 1), (531, 1), (645, 1), (946, 1)]
# (رادیکال) : frequency = 1, posting list: [(441, 1)]
# (حذف) : frequency = 4, posting list: [(441, 1), (675, 1), (822, 1), (875, 1)]
# (گذاشته_بودند) : frequency = 2, posting list: [(441, 1), (788, 1)]
# (اپوزیسیون) : frequency = 4, posting list: [(684, 3), (441, 1)]
# (بسیج) : frequency = 3, posting list: [(928, 2), (441, 1)]
# (چنانکه) : frequency = 3, posting list: [(442, 1), (452, 1), (828, 1)]
# (المعارف) : frequency = 3, posting list: [(442, 1), (461, 1), (587, 1)]
# (ننموده_اس) : frequency = 1, posting list: [(442, 1)]
# (انصافپور) : frequency = 1, posting list: [(442, 1)]
# (نهایتا) : frequency = 1, posting list: [(443, 1)]
# (موراد) : frequency = 1, posting list: [(443, 1)]
# (Feminine) : frequency = 1, posting list: [(444, 1)]
# (Psychology) : frequency = 1, posting list: [(444, 1)]
# (کارن) : frequency = 4, posting list: [(444, 3), (710, 1)]
# (هورنا) : frequency = 7, posting list: [(444, 5), (710, 2)]
# (۱۹۵۲) : frequency = 1, posting list: [(444, 1)]
# (۱۸۸۵) : frequency = 2, posting list: [(444, 1), (597, 1)]
# (پیشتاز) : frequency = 1, posting list: [(444, 1)]
# (فرمولاسیون) : frequency = 1, posting list: [(444, 1)]
# (مشاهد) : frequency = 2, posting list: [(444, 1), (981, 1)]
# (زنانگ) : frequency = 1, posting list: [(444, 1)]
# (بوته) : frequency = 5, posting list: [(909, 3), (444, 1), (636, 1)]
# (۶۵۲) : frequency = 1, posting list: [(445, 1)]
# (اقوام) : frequency = 1, posting list: [(445, 1)]
# (زیستند) : frequency = 1, posting list: [(445, 1)]
# (مرهون) : frequency = 2, posting list: [(445, 1), (547, 1)]
# (مردمان) : frequency = 6, posting list: [(643, 2), (817, 2), (445, 1), (956, 1)]
# (سلسمحمدجواد) : frequency = 1, posting list: [(445, 1)]
# (مشکورله) : frequency = 1, posting list: [(445, 1)]
# (ایلام) : frequency = 1, posting list: [(445, 1)]
# (شورش) : frequency = 5, posting list: [(446, 5)]
# (آرمانخواه) : frequency = 5, posting list: [(446, 5)]
# (بهروز) : frequency = 6, posting list: [(782, 3), (446, 2), (534, 1)]
# (استادیار) : frequency = 1, posting list: [(446, 1)]
# (ایالت) : frequency = 1, posting list: [(446, 1)]
# (فرانسیسکو) : frequency = 1, posting list: [(446, 1)]
# (مارکسیست) : frequency = 4, posting list: [(446, 3), (930, 1)]
# (فروپاشید) : frequency = 1, posting list: [(446, 1)]
# (احزاب) : frequency = 2, posting list: [(446, 1), (645, 1)]
# (فرع) : frequency = 5, posting list: [(446, 1), (541, 1), (605, 1), (642, 1), (745, 1)]
# (زیستگاه) : frequency = 3, posting list: [(446, 1), (463, 1), (764, 1)]
# (۱۳۶۰) : frequency = 3, posting list: [(446, 1), (470, 1), (764, 1)]
# (پرداختند) : frequency = 3, posting list: [(446, 1), (647, 1), (849, 1)]
# (فدا) : frequency = 3, posting list: [(446, 3)]
# (تندروانه) : frequency = 1, posting list: [(446, 1)]
# (برگزینند) : frequency = 1, posting list: [(446, 1)]
# (غیردموکراتیک) : frequency = 1, posting list: [(446, 1)]
# (خواهید_ ۱۰) : frequency = 1, posting list: [(447, 1)]
# (ایستاد) : frequency = 2, posting list: [(447, 1), (825, 1)]
# (خیره) : frequency = 3, posting list: [(447, 1), (497, 1), (923, 1)]
# (نمر) : frequency = 2, posting list: [(447, 2)]
# (معلق) : frequency = 1, posting list: [(447, 1)]
# (مبهو) : frequency = 2, posting list: [(447, 1), (512, 1)]
# (برگه) : frequency = 1, posting list: [(447, 1)]
# (ایستاده_بود) : frequency = 1, posting list: [(447, 1)]
# (پیوس) : frequency = 10, posting list: [(638, 3), (447, 1), (526, 1), (547, 1), (589, 1), (600, 1), (768, 1), (783, 1)]
# (نتوانسته_بود) : frequency = 1, posting list: [(447, 1)]
# (نمره) : frequency = 2, posting list: [(447, 1), (609, 1)]
# (بیزار) : frequency = 2, posting list: [(447, 2)]
# (شدت) : frequency = 1, posting list: [(447, 1)]
# (نامفهو) : frequency = 2, posting list: [(447, 1), (448, 1)]
# (سبد) : frequency = 1, posting list: [(447, 1)]
# (بسکتبال) : frequency = 1, posting list: [(447, 1)]
# (شکوفا) : frequency = 6, posting list: [(716, 2), (447, 1), (643, 1), (817, 1), (892, 1)]
# (تال) : frequency = 1, posting list: [(447, 1)]
# (شاهار) : frequency = 1, posting list: [(447, 1)]
# (آورانه) : frequency = 2, posting list: [(448, 2)]
# (نگریسته_شده_اس) : frequency = 2, posting list: [(448, 1), (564, 1)]
# (رمزگذار) : frequency = 5, posting list: [(610, 2), (812, 2), (448, 1)]
# (برآمده) : frequency = 3, posting list: [(448, 1), (762, 1), (864, 1)]
# (نیکولو) : frequency = 3, posting list: [(449, 2), (766, 1)]
# (ماکیاول) : frequency = 11, posting list: [(449, 10), (964, 1)]
# (۱۵۲۷) : frequency = 1, posting list: [(449, 1)]
# (۱۴۶۹) : frequency = 1, posting list: [(449, 1)]
# (تاکس) : frequency = 1, posting list: [(449, 1)]
# (مترو) : frequency = 1, posting list: [(449, 1)]
# (شنیده_اید) : frequency = 2, posting list: [(449, 1), (499, 1)]
# (گفته_اید) : frequency = 1, posting list: [(449, 1)]
# (فلان) : frequency = 1, posting list: [(449, 1)]
# (ماکیاولیس) : frequency = 2, posting list: [(449, 2)]
# (فریبکار) : frequency = 1, posting list: [(449, 1)]
# (پایبند) : frequency = 1, posting list: [(449, 1)]
# (نیرنگ) : frequency = 2, posting list: [(449, 2)]
# (بجد) : frequency = 1, posting list: [(449, 1)]
# (مدافع) : frequency = 2, posting list: [(449, 1), (712, 1)]
# (رذال) : frequency = 1, posting list: [(449, 1)]
# (خاندان) : frequency = 4, posting list: [(867, 2), (449, 1), (740, 1)]
# (کوشش) : frequency = 2, posting list: [(449, 1), (505, 1)]
# (فروگذار) : frequency = 2, posting list: [(449, 1), (827, 1)]
# (نیکولا) : frequency = 1, posting list: [(449, 1)]
# (فلورانس) : frequency = 1, posting list: [(449, 1)]
# (بخ) : frequency = 1, posting list: [(449, 1)]
# (پرفروغ) : frequency = 1, posting list: [(449, 1)]
# (عالمگیر) : frequency = 1, posting list: [(449, 1)]
# (دستورنامه) : frequency = 1, posting list: [(449, 1)]
# (واضع) : frequency = 1, posting list: [(449, 1)]
# (شبح) : frequency = 1, posting list: [(449, 1)]
# (گرایانه) : frequency = 4, posting list: [(449, 1), (457, 1), (502, 1), (840, 1)]
# (اشتباهات) : frequency = 2, posting list: [(449, 1), (506, 1)]
# (چاپلوس) : frequency = 2, posting list: [(449, 2)]
# (پادشاهان) : frequency = 3, posting list: [(449, 1), (455, 1), (804, 1)]
# (اسکریپت) : frequency = 2, posting list: [(450, 1), (845, 1)]
# (اعجاب) : frequency = 3, posting list: [(803, 2), (451, 1)]
# (نادان) : frequency = 2, posting list: [(451, 1), (860, 1)]
# (تنگدست) : frequency = 3, posting list: [(513, 2), (451, 1)]
# (یازد) : frequency = 1, posting list: [(451, 1)]
# (بگشاید) : frequency = 1, posting list: [(451, 1)]
# (فیلیپ) : frequency = 3, posting list: [(451, 1), (492, 1), (628, 1)]
# (۱۳۸۷) : frequency = 2, posting list: [(452, 1), (928, 1)]
# (افخم) : frequency = 2, posting list: [(452, 2)]
# (کالیفرنیا) : frequency = 1, posting list: [(452, 1)]
# (معاون) : frequency = 4, posting list: [(452, 2), (772, 2)]
# (رییس) : frequency = 4, posting list: [(452, 1), (628, 1), (728, 1), (853, 1)]
# (ثمره) : frequency = 3, posting list: [(452, 2), (830, 1)]
# (خوانده_اس) : frequency = 2, posting list: [(452, 1), (543, 1)]
# (خرمدین) : frequency = 9, posting list: [(453, 8), (547, 1)]
# (دلاور) : frequency = 2, posting list: [(453, 1), (870, 1)]
# (تاز) : frequency = 3, posting list: [(453, 1), (461, 1), (989, 1)]
# (جامگ) : frequency = 1, posting list: [(453, 1)]
# (تاجیک) : frequency = 1, posting list: [(453, 1)]
# (مجسمه) : frequency = 4, posting list: [(453, 1), (682, 1), (897, 1), (972, 1)]
# (نخجو) : frequency = 3, posting list: [(453, 1), (708, 1), (960, 1)]
# (خرم) : frequency = 1, posting list: [(453, 1)]
# (کامروا) : frequency = 2, posting list: [(453, 1), (919, 1)]
# (۲۰۴) : frequency = 1, posting list: [(453, 1)]
# (۲۱۱) : frequency = 1, posting list: [(453, 1)]
# (۲۱۲) : frequency = 1, posting list: [(453, 1)]
# (۲۱۴) : frequency = 1, posting list: [(453, 1)]
# (۲۱۷) : frequency = 1, posting list: [(453, 1)]
# (۲۱۸) : frequency = 1, posting list: [(453, 1)]
# (۲۱۹) : frequency = 1, posting list: [(453, 1)]
# (۲۲۰) : frequency = 2, posting list: [(453, 1), (926, 1)]
# (معتص) : frequency = 1, posting list: [(453, 1)]
# (افشین) : frequency = 1, posting list: [(453, 1)]
# (۲۲۱) : frequency = 1, posting list: [(453, 1)]
# (۲۲۲) : frequency = 1, posting list: [(453, 1)]
# (تریاک) : frequency = 9, posting list: [(454, 8), (996, 1)]
# (سومر) : frequency = 8, posting list: [(617, 2), (454, 1), (543, 1), (599, 1), (643, 1), (971, 1), (997, 1)]
# (علامات) : frequency = 1, posting list: [(454, 1)]
# (خشخا) : frequency = 3, posting list: [(454, 3)]
# (بردند) : frequency = 4, posting list: [(454, 3), (825, 1)]
# (کتابخانه) : frequency = 10, posting list: [(798, 3), (604, 2), (454, 1), (545, 1), (614, 1), (615, 1), (628, 1)]
# (آشور) : frequency = 4, posting list: [(454, 1), (462, 1), (643, 1), (976, 1)]
# (پال) : frequency = 2, posting list: [(454, 1), (878, 1)]
# (مصری) : frequency = 1, posting list: [(454, 1)]
# (سومری) : frequency = 1, posting list: [(454, 1)]
# (آموختند) : frequency = 3, posting list: [(454, 1), (647, 1), (652, 1)]
# (پادزهر) : frequency = 1, posting list: [(454, 1)]
# (پورداود) : frequency = 1, posting list: [(454, 1)]
# (شده_بودند) : frequency = 4, posting list: [(454, 1), (643, 1), (750, 1), (817, 1)]
# (خوردند) : frequency = 2, posting list: [(454, 1), (769, 1)]
# (شتر) : frequency = 2, posting list: [(454, 1), (853, 1)]
# (خوراندند) : frequency = 1, posting list: [(454, 1)]
# (کریمخ) : frequency = 4, posting list: [(455, 4)]
# (الرعایا) : frequency = 1, posting list: [(455, 1)]
# (دروازه) : frequency = 5, posting list: [(455, 1), (513, 1), (751, 1), (761, 1), (830, 1)]
# (بصره) : frequency = 1, posting list: [(455, 1)]
# (برافرا) : frequency = 1, posting list: [(455, 1)]
# (طایفه) : frequency = 2, posting list: [(455, 1), (968, 1)]
# (ملایر) : frequency = 2, posting list: [(455, 2)]
# (سکن) : frequency = 1, posting list: [(455, 1)]
# (کوچانیده) : frequency = 1, posting list: [(455, 1)]
# (مجددا) : frequency = 4, posting list: [(455, 1), (460, 1), (589, 1), (842, 1)]
# (همد) : frequency = 3, posting list: [(455, 1), (614, 1), (729, 1)]
# (پید) : frequency = 1, posting list: [(455, 1)]
# (ابوالفتح) : frequency = 3, posting list: [(455, 1), (768, 1), (883, 1)]
# (اسکندر) : frequency = 12, posting list: [(652, 4), (455, 1), (456, 1), (557, 1), (672, 1), (737, 1), (840, 1), (952, 1), (964, 1)]
# (مهاجمین) : frequency = 1, posting list: [(455, 1)]
# (نوا) : frequency = 1, posting list: [(455, 1)]
# (ساخته_شده_اس) : frequency = 3, posting list: [(456, 1), (762, 1), (874, 1)]
# (محققین) : frequency = 2, posting list: [(456, 1), (670, 1)]
# (افروز) : frequency = 1, posting list: [(456, 1)]
# (کاستن) : frequency = 1, posting list: [(456, 1)]
# (مقاوم) : frequency = 5, posting list: [(456, 2), (991, 2), (713, 1)]
# (متجاوز) : frequency = 1, posting list: [(456, 1)]
# (مقدون) : frequency = 6, posting list: [(456, 2), (652, 1), (737, 1), (840, 1), (952, 1)]
# (پابرجا) : frequency = 1, posting list: [(456, 1)]
# (خرابه) : frequency = 1, posting list: [(456, 1)]
# (بورزند) : frequency = 1, posting list: [(456, 1)]
# (پورپیرار) : frequency = 3, posting list: [(456, 2), (547, 1)]
# (پرداختن) : frequency = 4, posting list: [(456, 1), (627, 1), (755, 1), (964, 1)]
# (نباشند) : frequency = 1, posting list: [(456, 1)]
# (آورده_بودند) : frequency = 2, posting list: [(456, 1), (591, 1)]
# (خواهد_باخ) : frequency = 1, posting list: [(457, 1)]
# (نشانگ) : frequency = 1, posting list: [(457, 1)]
# (مبدل) : frequency = 4, posting list: [(457, 1), (483, 1), (495, 1), (628, 1)]
# (همگرا) : frequency = 2, posting list: [(457, 1), (562, 1)]
# (پیشگیرانه) : frequency = 1, posting list: [(457, 1)]
# (ژنومیک) : frequency = 1, posting list: [(457, 1)]
# (پروتئومیک) : frequency = 1, posting list: [(457, 1)]
# (آهستگ) : frequency = 1, posting list: [(457, 1)]
# (۲۰۲۵) : frequency = 1, posting list: [(457, 1)]
# (۲۰۵۰) : frequency = 1, posting list: [(457, 1)]
# (روند) : frequency = 3, posting list: [(457, 1), (902, 1), (942, 1)]
# (جیمز) : frequency = 6, posting list: [(955, 2), (457, 1), (528, 1), (687, 1), (710, 1)]
# (زهرآگین) : frequency = 4, posting list: [(458, 3), (770, 1)]
# (فریبنده) : frequency = 4, posting list: [(458, 1), (604, 1), (740, 1), (878, 1)]
# (دیده_اند) : frequency = 1, posting list: [(458, 1)]
# (جاندار) : frequency = 4, posting list: [(458, 2), (650, 1), (651, 1)]
# (آبکاو) : frequency = 1, posting list: [(458, 1)]
# (توریس) : frequency = 2, posting list: [(458, 1), (462, 1)]
# (زیرآب) : frequency = 1, posting list: [(458, 1)]
# (برخاسته) : frequency = 1, posting list: [(458, 1)]
# (۱۳۸۹) : frequency = 2, posting list: [(458, 1), (534, 1)]
# (خدام) : frequency = 2, posting list: [(459, 2)]
# (آران) : frequency = 2, posting list: [(459, 2)]
# (رسیده_اید) : frequency = 1, posting list: [(459, 1)]
# (خواهر) : frequency = 1, posting list: [(459, 1)]
# (شناسید) : frequency = 2, posting list: [(459, 1), (801, 1)]
# (مرحم) : frequency = 1, posting list: [(459, 1)]
# (بکند) : frequency = 4, posting list: [(459, 1), (552, 1), (763, 1), (929, 1)]
# (ثواب) : frequency = 3, posting list: [(459, 1), (461, 1), (644, 1)]
# (یأس) : frequency = 1, posting list: [(459, 1)]
# (خواهید_این) : frequency = 1, posting list: [(459, 1)]
# (زنان) : frequency = 2, posting list: [(459, 1), (958, 1)]
# (نوشته_ا) : frequency = 2, posting list: [(459, 1), (653, 1)]
# (خواهند_در) : frequency = 1, posting list: [(459, 1)]
# (کرده_با) : frequency = 1, posting list: [(459, 1)]
# (مترلینک) : frequency = 2, posting list: [(460, 2)]
# (۱۸۶۲) : frequency = 2, posting list: [(460, 1), (939, 1)]
# (گن) : frequency = 1, posting list: [(460, 1)]
# (فلاندر) : frequency = 1, posting list: [(460, 1)]
# (فراگرف) : frequency = 2, posting list: [(460, 1), (766, 1)]
# (آموخ) : frequency = 2, posting list: [(460, 1), (747, 1)]
# (بارب) : frequency = 1, posting list: [(460, 1)]
# (حشره) : frequency = 2, posting list: [(460, 1), (806, 1)]
# (مدارج) : frequency = 1, posting list: [(460, 1)]
# (۱۸۸۴) : frequency = 1, posting list: [(460, 1)]
# (وکلا) : frequency = 1, posting list: [(460, 1)]
# (۱۸۸۷) : frequency = 1, posting list: [(460, 1)]
# (غور) : frequency = 1, posting list: [(460, 1)]
# (۱۸۹۶) : frequency = 3, posting list: [(460, 1), (600, 1), (939, 1)]
# (سمبولیس) : frequency = 4, posting list: [(460, 1), (770, 1), (846, 1), (939, 1)]
# (۱۹۰۰) : frequency = 2, posting list: [(460, 1), (735, 1)]
# (لبل) : frequency = 1, posting list: [(460, 1)]
# (Georgette) : frequency = 1, posting list: [(460, 1)]
# (Leblance) : frequency = 1, posting list: [(460, 1)]
# (۱۹۱۱) : frequency = 3, posting list: [(460, 1), (600, 1), (939, 1)]
# (نپذیرف) : frequency = 1, posting list: [(460, 1)]
# (دراوج) : frequency = 1, posting list: [(460, 1)]
# (۱۹۲۰) : frequency = 1, posting list: [(460, 1)]
# (اشغال) : frequency = 4, posting list: [(460, 1), (582, 1), (687, 1), (750, 1)]
# (بنابر) : frequency = 6, posting list: [(460, 1), (520, 1), (604, 1), (628, 1), (844, 1), (875, 1)]
# (ادعائ) : frequency = 1, posting list: [(460, 1)]
# (گریزپا) : frequency = 1, posting list: [(460, 1)]
# (فطرتا) : frequency = 1, posting list: [(460, 1)]
# (احضار) : frequency = 3, posting list: [(460, 1), (639, 1), (840, 1)]
# (خرف) : frequency = 1, posting list: [(460, 1)]
# (منگ) : frequency = 1, posting list: [(460, 1)]
# (ابال) : frequency = 1, posting list: [(460, 1)]
# (سربه) : frequency = 1, posting list: [(460, 1)]
# (جاهل) : frequency = 4, posting list: [(794, 2), (460, 1), (547, 1)]
# (ابله) : frequency = 1, posting list: [(460, 1)]
# (رسند) : frequency = 2, posting list: [(460, 1), (613, 1)]
# (فنا) : frequency = 1, posting list: [(460, 1)]
# (سرگرد) : frequency = 2, posting list: [(460, 1), (691, 1)]
# (مترلینگ) : frequency = 10, posting list: [(939, 5), (472, 4), (460, 1)]
# (انتروپ) : frequency = 1, posting list: [(461, 1)]
# (ژن) : frequency = 2, posting list: [(461, 1), (625, 1)]
# (منحن) : frequency = 1, posting list: [(461, 1)]
# (راک) : frequency = 2, posting list: [(461, 1), (771, 1)]
# (براست) : frequency = 2, posting list: [(461, 1), (919, 1)]
# (گردآوردن) : frequency = 1, posting list: [(461, 1)]
# (بغا) : frequency = 1, posting list: [(461, 1)]
# (برزگ) : frequency = 2, posting list: [(461, 1), (578, 1)]
# (بگسترد) : frequency = 1, posting list: [(461, 1)]
# (لازم) : frequency = 1, posting list: [(461, 1)]
# (اندگ) : frequency = 1, posting list: [(461, 1)]
# (بطوریکه) : frequency = 2, posting list: [(461, 1), (700, 1)]
# (صغیر) : frequency = 3, posting list: [(461, 1), (622, 1), (652, 1)]
# (حادث) : frequency = 1, posting list: [(461, 1)]
# (ساخته_ا) : frequency = 1, posting list: [(461, 1)]
# (پیشترف) : frequency = 1, posting list: [(461, 1)]
# (انفجار) : frequency = 4, posting list: [(771, 2), (461, 1), (712, 1)]
# (سوپرنووا) : frequency = 1, posting list: [(461, 1)]
# (نوترینو) : frequency = 1, posting list: [(461, 1)]
# (تصاد) : frequency = 1, posting list: [(461, 1)]
# (طرد) : frequency = 4, posting list: [(629, 2), (461, 1), (806, 1)]
# (کان) : frequency = 1, posting list: [(461, 1)]
# (لاپلاس) : frequency = 1, posting list: [(461, 1)]
# (زدوده_شده_بود) : frequency = 1, posting list: [(461, 1)]
# (ذمه) : frequency = 1, posting list: [(461, 1)]
# (متعیید) : frequency = 1, posting list: [(461, 1)]
# (سپاسگزار) : frequency = 1, posting list: [(461, 1)]
# (جورج) : frequency = 6, posting list: [(466, 2), (504, 2), (461, 1), (502, 1)]
# (گاموف) : frequency = 1, posting list: [(461, 1)]
# (آرامگاه) : frequency = 9, posting list: [(506, 7), (462, 2)]
# (تابستان) : frequency = 1, posting list: [(462, 1)]
# (دوقلو) : frequency = 1, posting list: [(462, 1)]
# (آبگر) : frequency = 1, posting list: [(462, 1)]
# (گیو) : frequency = 2, posting list: [(462, 1), (938, 1)]
# (آبیانه) : frequency = 1, posting list: [(462, 1)]
# (آتشکده) : frequency = 1, posting list: [(462, 1)]
# (آتلانتیس) : frequency = 1, posting list: [(462, 1)]
# (جویدن) : frequency = 1, posting list: [(462, 1)]
# (حو) : frequency = 1, posting list: [(462, 1)]
# (دلتا) : frequency = 3, posting list: [(492, 2), (462, 1)]
# (ورکز) : frequency = 1, posting list: [(462, 1)]
# (هلند) : frequency = 2, posting list: [(462, 1), (995, 1)]
# (گلدن) : frequency = 1, posting list: [(462, 1)]
# (مالز) : frequency = 1, posting list: [(462, 1)]
# (امپایر) : frequency = 1, posting list: [(462, 1)]
# (است) : frequency = 1, posting list: [(462, 1)]
# (ایتایپو) : frequency = 1, posting list: [(462, 1)]
# (کربلا) : frequency = 5, posting list: [(614, 2), (462, 1), (853, 1), (994, 1)]
# (قیزقلعه) : frequency = 1, posting list: [(462, 1)]
# (اردک) : frequency = 1, posting list: [(462, 1)]
# (قلعه) : frequency = 5, posting list: [(466, 2), (462, 1), (851, 1), (925, 1)]
# (الشرقاط) : frequency = 1, posting list: [(462, 1)]
# (اسداله) : frequency = 1, posting list: [(462, 1)]
# (روضات) : frequency = 1, posting list: [(462, 1)]
# (آک) : frequency = 1, posting list: [(462, 1)]
# (سک) : frequency = 1, posting list: [(462, 1)]
# (آیزانو) : frequency = 1, posting list: [(462, 1)]
# (آیوالیک) : frequency = 1, posting list: [(462, 1)]
# (راین) : frequency = 1, posting list: [(462, 1)]
# (کریمخان) : frequency = 1, posting list: [(462, 1)]
# (خارگ) : frequency = 2, posting list: [(462, 1), (687, 1)]
# (اسال) : frequency = 1, posting list: [(462, 1)]
# (خطابه) : frequency = 2, posting list: [(462, 1), (964, 1)]
# (دلزدگ) : frequency = 1, posting list: [(462, 1)]
# (طع) : frequency = 3, posting list: [(462, 2), (471, 1)]
# (کانگورو) : frequency = 1, posting list: [(462, 1)]
# (مسافرت) : frequency = 2, posting list: [(462, 1), (878, 1)]
# (اشکف) : frequency = 1, posting list: [(462, 1)]
# (دوفیر) : frequency = 1, posting list: [(462, 1)]
# (گذرنامه) : frequency = 1, posting list: [(462, 1)]
# (گرمارود) : frequency = 1, posting list: [(462, 1)]
# (المو) : frequency = 1, posting list: [(462, 1)]
# (افشره) : frequency = 1, posting list: [(462, 1)]
# (اقیانوس) : frequency = 1, posting list: [(462, 1)]
# (کوچولو) : frequency = 2, posting list: [(462, 1), (623, 1)]
# (امامزاده) : frequency = 1, posting list: [(462, 1)]
# (کلور) : frequency = 1, posting list: [(462, 1)]
# (کماب) : frequency = 3, posting list: [(463, 1), (792, 1), (817, 1)]
# (کما) : frequency = 1, posting list: [(463, 1)]
# (۱۷۷۶) : frequency = 1, posting list: [(463, 1)]
# (مستعمر) : frequency = 1, posting list: [(463, 1)]
# (بسو) : frequency = 3, posting list: [(463, 2), (604, 1)]
# (منازع) : frequency = 1, posting list: [(463, 1)]
# (رونق) : frequency = 4, posting list: [(463, 1), (553, 1), (683, 1), (833, 1)]
# (کساد) : frequency = 1, posting list: [(463, 1)]
# (نیودیل) : frequency = 1, posting list: [(463, 1)]
# (خانلر) : frequency = 7, posting list: [(464, 5), (633, 2)]
# (۱۳۴۳) : frequency = 2, posting list: [(464, 1), (803, 1)]
# (تجدیدنظر) : frequency = 1, posting list: [(464, 1)]
# (رسیدند) : frequency = 2, posting list: [(464, 1), (779, 1)]
# (برپایه) : frequency = 1, posting list: [(464, 1)]
# (گزاره) : frequency = 2, posting list: [(464, 1), (728, 1)]
# (برساخته) : frequency = 1, posting list: [(464, 1)]
# (ناتل) : frequency = 2, posting list: [(464, 1), (633, 1)]
# (نورافکن) : frequency = 1, posting list: [(465, 1)]
# (سرو) : frequency = 1, posting list: [(465, 1)]
# (کارگردان) : frequency = 1, posting list: [(465, 1)]
# (صدابردار) : frequency = 1, posting list: [(465, 1)]
# (آماده_باشد) : frequency = 1, posting list: [(465, 1)]
# (جوید) : frequency = 2, posting list: [(465, 1), (989, 1)]
# (Animal) : frequency = 1, posting list: [(466, 1)]
# (Farm) : frequency = 1, posting list: [(466, 1)]
# (اورول) : frequency = 2, posting list: [(466, 2)]
# (دومینو) : frequency = 2, posting list: [(467, 2)]
# (ریخ) : frequency = 2, posting list: [(467, 2)]
# (مهیب) : frequency = 3, posting list: [(467, 2), (481, 1)]
# (خواهیم_دانس) : frequency = 1, posting list: [(467, 1)]
# (فرورت) : frequency = 1, posting list: [(467, 1)]
# (رضوانیه) : frequency = 1, posting list: [(467, 1)]
# (VBA) : frequency = 4, posting list: [(468, 4)]
# (Basic) : frequency = 3, posting list: [(945, 2), (468, 1)]
# (for) : frequency = 1, posting list: [(468, 1)]
# (Applications) : frequency = 1, posting list: [(468, 1)]
# (قرارداده) : frequency = 1, posting list: [(468, 1)]
# (بخشیده_اس) : frequency = 3, posting list: [(468, 1), (650, 1), (878, 1)]
# (ار) : frequency = 2, posting list: [(468, 1), (734, 1)]
# (اتوماسیون) : frequency = 1, posting list: [(468, 1)]
# (فرزا) : frequency = 1, posting list: [(468, 1)]
# (غول) : frequency = 14, posting list: [(831, 7), (469, 1), (570, 1), (625, 1), (644, 1), (673, 1), (887, 1), (897, 1)]
# (حدوذ) : frequency = 1, posting list: [(469, 1)]
# (بیاب) : frequency = 3, posting list: [(469, 1), (644, 1), (807, 1)]
# (اهله) : frequency = 1, posting list: [(469, 1)]
# (یکسال) : frequency = 1, posting list: [(469, 1)]
# (شکار) : frequency = 4, posting list: [(836, 3), (469, 1)]
# (وگذ) : frequency = 1, posting list: [(469, 1)]
# (یکجانشین) : frequency = 1, posting list: [(469, 1)]
# (وکشاورز) : frequency = 1, posting list: [(469, 1)]
# (ایلین) : frequency = 1, posting list: [(469, 1)]
# (سگال) : frequency = 1, posting list: [(469, 1)]
# (افت) : frequency = 1, posting list: [(471, 1)]
# (دستپخ) : frequency = 1, posting list: [(471, 1)]
# (گرم) : frequency = 4, posting list: [(471, 1), (591, 1), (779, 1), (860, 1)]
# (شیء) : frequency = 1, posting list: [(471, 1)]
# (کبو) : frequency = 1, posting list: [(471, 1)]
# (همنشین) : frequency = 1, posting list: [(471, 1)]
# (کوچه) : frequency = 2, posting list: [(471, 1), (788, 1)]
# (ناظ) : frequency = 2, posting list: [(471, 1), (785, 1)]
# (نسبت) : frequency = 1, posting list: [(471, 1)]
# (زدند) : frequency = 3, posting list: [(471, 1), (770, 1), (952, 1)]
# (غلامعل) : frequency = 3, posting list: [(471, 1), (830, 1), (928, 1)]
# (حداد) : frequency = 1, posting list: [(471, 1)]
# (عادل) : frequency = 3, posting list: [(513, 2), (471, 1)]
# (نقیض) : frequency = 2, posting list: [(472, 1), (712, 1)]
# (می‌گوید) : frequency = 5, posting list: [(472, 2), (631, 1), (756, 1), (961, 1)]
# (غیرمنتظره) : frequency = 1, posting list: [(472, 1)]
# (نمی‌ک) : frequency = 1, posting list: [(472, 1)]
# (B) : frequency = 2, posting list: [(473, 1), (945, 1)]
# (D) : frequency = 2, posting list: [(473, 2)]
# (کلس) : frequency = 4, posting list: [(886, 2), (473, 1), (864, 1)]
# (اسید) : frequency = 1, posting list: [(473, 1)]
# (فولیک) : frequency = 1, posting list: [(473, 1)]
# (ث) : frequency = 1, posting list: [(473, 1)]
# (E) : frequency = 1, posting list: [(473, 1)]
# (شیمیائ) : frequency = 1, posting list: [(473, 1)]
# (K) : frequency = 2, posting list: [(473, 2)]
# (دیابت) : frequency = 1, posting list: [(473, 1)]
# (شلغ) : frequency = 1, posting list: [(473, 1)]
# (Eدر) : frequency = 1, posting list: [(473, 1)]
# (لک) : frequency = 11, posting list: [(995, 6), (605, 4), (473, 1)]
# (املاح) : frequency = 2, posting list: [(473, 1), (801, 1)]
# (لایحه) : frequency = 2, posting list: [(474, 2)]
# (نگهب) : frequency = 1, posting list: [(474, 1)]
# (ابلاغ) : frequency = 3, posting list: [(474, 1), (699, 1), (784, 1)]
# (سیاست) : frequency = 1, posting list: [(474, 1)]
# (دریافت) : frequency = 1, posting list: [(474, 1)]
# (خزانه) : frequency = 2, posting list: [(474, 1), (628, 1)]
# (عمران) : frequency = 1, posting list: [(474, 1)]
# (درذیل) : frequency = 2, posting list: [(475, 1), (604, 1)]
# (عزادار) : frequency = 1, posting list: [(475, 1)]
# (نصیرالدین) : frequency = 1, posting list: [(475, 1)]
# (طوس) : frequency = 3, posting list: [(475, 1), (846, 1), (897, 1)]
# (انصار) : frequency = 2, posting list: [(475, 1), (629, 1)]
# (کسنفن) : frequency = 1, posting list: [(476, 1)]
# (آناباسیس) : frequency = 1, posting list: [(476, 1)]
# (اردشیر) : frequency = 2, posting list: [(476, 1), (688, 1)]
# (خشایارشا) : frequency = 2, posting list: [(476, 1), (737, 1)]
# (بخواند) : frequency = 1, posting list: [(476, 1)]
# (کورپد) : frequency = 1, posting list: [(476, 1)]
# (بسنجد) : frequency = 1, posting list: [(476, 1)]
# (خواهد_گذ) : frequency = 1, posting list: [(476, 1)]
# (آرمان) : frequency = 1, posting list: [(476, 1)]
# (یادمان) : frequency = 1, posting list: [(476, 1)]
# (داریو) : frequency = 10, posting list: [(610, 3), (592, 2), (476, 1), (547, 1), (566, 1), (601, 1), (737, 1)]
# (کنده) : frequency = 1, posting list: [(476, 1)]
# (Magan) : frequency = 1, posting list: [(476, 1)]
# (Karta) : frequency = 1, posting list: [(476, 1)]
# (می‌نام) : frequency = 1, posting list: [(476, 1)]
# (زردشت) : frequency = 1, posting list: [(476, 1)]
# (قابوس) : frequency = 1, posting list: [(476, 1)]
# (اندیشمندانه) : frequency = 1, posting list: [(476, 1)]
# (می‌آوردند) : frequency = 1, posting list: [(476, 1)]
# (وظائف) : frequency = 1, posting list: [(476, 1)]
# (نگاهدار) : frequency = 1, posting list: [(476, 1)]
# (انظباط) : frequency = 1, posting list: [(476, 1)]
# (بویژه) : frequency = 2, posting list: [(476, 1), (918, 1)]
# (یزدان) : frequency = 2, posting list: [(476, 1), (968, 1)]
# (ولفگانگ) : frequency = 1, posting list: [(476, 1)]
# (کناو) : frequency = 1, posting list: [(476, 1)]
# (آذریزد) : frequency = 4, posting list: [(477, 4)]
# (خرمشاه) : frequency = 2, posting list: [(477, 2)]
# (بازنویس) : frequency = 4, posting list: [(477, 2), (592, 1), (594, 1)]
# (۱۳۰۰) : frequency = 5, posting list: [(477, 1), (699, 1), (770, 1), (837, 1), (888, 1)]
# (طلبگ) : frequency = 1, posting list: [(477, 1)]
# (چاپخانه) : frequency = 1, posting list: [(477, 1)]
# (۱۳۳۵) : frequency = 3, posting list: [(477, 1), (488, 1), (597, 1)]
# (کلیله) : frequency = 3, posting list: [(477, 1), (541, 1), (989, 1)]
# (دمنه) : frequency = 3, posting list: [(477, 1), (541, 1), (989, 1)]
# (بادنامه) : frequency = 1, posting list: [(477, 1)]
# (انوار) : frequency = 1, posting list: [(477, 1)]
# (سهیل) : frequency = 2, posting list: [(477, 1), (980, 1)]
# (ناقلا) : frequency = 1, posting list: [(477, 1)]
# (خاله) : frequency = 3, posting list: [(477, 2), (803, 1)]
# (سوسکه) : frequency = 1, posting list: [(477, 1)]
# (قورباغه) : frequency = 1, posting list: [(477, 1)]
# (تبنل) : frequency = 1, posting list: [(477, 1)]
# (درسال) : frequency = 2, posting list: [(477, 2)]
# (۱۳۴۵) : frequency = 3, posting list: [(477, 2), (939, 1)]
# (یونسکو) : frequency = 4, posting list: [(605, 3), (477, 1)]
# (تقدیردریاف) : frequency = 1, posting list: [(477, 1)]
# (وپنج) : frequency = 1, posting list: [(477, 1)]
# (ازسو) : frequency = 1, posting list: [(477, 1)]
# (فکاه) : frequency = 1, posting list: [(477, 1)]
# (لطائف) : frequency = 1, posting list: [(477, 1)]
# (ظرائف) : frequency = 1, posting list: [(477, 1)]
# (سنجی) : frequency = 1, posting list: [(477, 1)]
# (زندگاه) : frequency = 2, posting list: [(478, 2)]
# (آغازگاه) : frequency = 1, posting list: [(478, 1)]
# (زاده_شد) : frequency = 2, posting list: [(478, 1), (512, 1)]
# (نفد) : frequency = 1, posting list: [(478, 1)]
# (واساز) : frequency = 2, posting list: [(478, 1), (553, 1)]
# (کلیدواژه) : frequency = 2, posting list: [(478, 1), (675, 1)]
# (۲۰۰۸) : frequency = 2, posting list: [(479, 1), (809, 1)]
# ...
# (مظفرعال) : frequency = 1, posting list: [(946, 1)]
# (هبوط) : frequency = 6, posting list: [(947, 6)]
# (سمبلیک) : frequency = 1, posting list: [(947, 1)]
# (برشمردن) : frequency = 1, posting list: [(947, 1)]
# (هامبورگ) : frequency = 1, posting list: [(948, 1)]
# (۱۳۸۲) : frequency = 1, posting list: [(948, 1)]
# (فیلدمارشال) : frequency = 1, posting list: [(949, 1)]
# (بوناپار) : frequency = 1, posting list: [(949, 1)]
# (می‌ماندند) : frequency = 1, posting list: [(949, 1)]
# (ژنرالیسیم) : frequency = 1, posting list: [(949, 1)]
# (ورماخ) : frequency = 1, posting list: [(949, 1)]
# (ریخته_بودند) : frequency = 1, posting list: [(949, 1)]
# (رامساز) : frequency = 1, posting list: [(949, 1)]
# (آرامساز) : frequency = 1, posting list: [(949, 1)]
# (مارشال) : frequency = 1, posting list: [(949, 1)]
# (باریاتینسک) : frequency = 1, posting list: [(949, 1)]
# (می‌گمارد) : frequency = 1, posting list: [(949, 1)]
# (تودورسک) : frequency = 1, posting list: [(949, 1)]
# (داغستان) : frequency = 1, posting list: [(949, 1)]
# (می‌فرستد) : frequency = 1, posting list: [(949, 1)]
# (تهام) : frequency = 1, posting list: [(949, 1)]
# (خرمشهر) : frequency = 5, posting list: [(952, 5)]
# (رشادت) : frequency = 1, posting list: [(952, 1)]
# (جانفشان) : frequency = 1, posting list: [(952, 1)]
# (ساخنتد) : frequency = 1, posting list: [(952, 1)]
# (نخواهیم_اغراق) : frequency = 1, posting list: [(952, 1)]
# (آلکساندریا) : frequency = 1, posting list: [(952, 1)]
# (التقا) : frequency = 1, posting list: [(952, 1)]
# (کارون) : frequency = 1, posting list: [(952, 1)]
# (اروندرود) : frequency = 1, posting list: [(952, 1)]
# (خاراکس) : frequency = 1, posting list: [(952, 1)]
# (بارما) : frequency = 1, posting list: [(952, 1)]
# (محمره) : frequency = 1, posting list: [(952, 1)]
# (بسزائ) : frequency = 1, posting list: [(952, 1)]
# (محرز) : frequency = 1, posting list: [(952, 1)]
# (خلف) : frequency = 1, posting list: [(952, 1)]
# (کلر) : frequency = 4, posting list: [(953, 4)]
# (توانایی) : frequency = 3, posting list: [(953, 3)]
# (خلل) : frequency = 1, posting list: [(953, 1)]
# (باوجود) : frequency = 1, posting list: [(953, 1)]
# (ناتوانی) : frequency = 1, posting list: [(953, 1)]
# (۱۸۸۰) : frequency = 1, posting list: [(953, 1)]
# (ناتوانیهاس) : frequency = 1, posting list: [(953, 1)]
# (ماهگ) : frequency = 1, posting list: [(953, 1)]
# (شنوا) : frequency = 1, posting list: [(953, 1)]
# (برقرارساختن) : frequency = 1, posting list: [(953, 1)]
# (لجوج) : frequency = 1, posting list: [(953, 1)]
# (لق) : frequency = 1, posting list: [(953, 1)]
# (سالیو) : frequency = 1, posting list: [(953, 1)]
# (ناشکافته) : frequency = 1, posting list: [(954, 1)]
# (بلوکباش) : frequency = 1, posting list: [(954, 1)]
# (پراگماتیس) : frequency = 3, posting list: [(955, 3)]
# (متفکران) : frequency = 1, posting list: [(955, 1)]
# (هورلا) : frequency = 2, posting list: [(956, 2)]
# (دوموپاس) : frequency = 1, posting list: [(956, 1)]
# (داستا) : frequency = 1, posting list: [(956, 1)]
# (سپیدار) : frequency = 1, posting list: [(956, 1)]
# (الجثه) : frequency = 1, posting list: [(956, 1)]
# (علفزار) : frequency = 1, posting list: [(956, 1)]
# (مرده_اند) : frequency = 1, posting list: [(956, 1)]
# (اندیشند) : frequency = 1, posting list: [(956, 1)]
# (موپاس) : frequency = 1, posting list: [(956, 1)]
# (موافقید) : frequency = 1, posting list: [(957, 1)]
# (۱۱۰۰) : frequency = 1, posting list: [(957, 1)]
# (منتشرشده) : frequency = 2, posting list: [(957, 1), (977, 1)]
# (درواقع) : frequency = 1, posting list: [(957, 1)]
# (فقرزده) : frequency = 1, posting list: [(958, 1)]
# (مجبورند) : frequency = 1, posting list: [(958, 1)]
# (ستم) : frequency = 1, posting list: [(958, 1)]
# (تلاف) : frequency = 1, posting list: [(958, 1)]
# (حکفرماس) : frequency = 1, posting list: [(958, 1)]
# (پسران) : frequency = 1, posting list: [(959, 1)]
# (عص) : frequency = 1, posting list: [(959, 1)]
# (منفور) : frequency = 1, posting list: [(959, 1)]
# (اودیپ) : frequency = 1, posting list: [(959, 1)]
# (مانده_بود) : frequency = 1, posting list: [(959, 1)]
# (زنا) : frequency = 1, posting list: [(959, 1)]
# (محار) : frequency = 1, posting list: [(959, 1)]
# (دوگانگ) : frequency = 1, posting list: [(959, 1)]
# (توتمیس) : frequency = 1, posting list: [(959, 1)]
# (بلغارس) : frequency = 1, posting list: [(960, 1)]
# (مرمره) : frequency = 1, posting list: [(960, 1)]
# (اژه) : frequency = 1, posting list: [(960, 1)]
# (تنگه) : frequency = 1, posting list: [(960, 1)]
# (بسفر) : frequency = 1, posting list: [(960, 1)]
# (داردانل) : frequency = 1, posting list: [(960, 1)]
# (۷۸۳) : frequency = 1, posting list: [(960, 1)]
# (۳۷) : frequency = 2, posting list: [(960, 1), (986, 1)]
# (کوهستان) : frequency = 1, posting list: [(960, 1)]
# (ترانز) : frequency = 1, posting list: [(960, 1)]
# (۲۵۰۰) : frequency = 1, posting list: [(961, 1)]
# (تزو) : frequency = 6, posting list: [(961, 6)]
# (می‌نویسد) : frequency = 1, posting list: [(961, 1)]
# (پیشک) : frequency = 1, posting list: [(961, 1)]
# (می‌نامد) : frequency = 1, posting list: [(961, 1)]
# (ازینکه) : frequency = 1, posting list: [(961, 1)]
# (علارغ) : frequency = 1, posting list: [(961, 1)]
# (تلوزیون) : frequency = 1, posting list: [(961, 1)]
# (اوردن) : frequency = 1, posting list: [(961, 1)]
# (می‌نامید) : frequency = 1, posting list: [(961, 1)]
# (هنگف) : frequency = 1, posting list: [(961, 1)]
# (عشیره) : frequency = 1, posting list: [(962, 1)]
# (پهنه) : frequency = 1, posting list: [(962, 1)]
# (یواخ) : frequency = 1, posting list: [(962, 1)]
# (بارکهاوزن) : frequency = 1, posting list: [(962, 1)]
# (هابرماس) : frequency = 1, posting list: [(964, 1)]
# (آکونیاس) : frequency = 1, posting list: [(964, 1)]
# (فوتسه) : frequency = 1, posting list: [(964, 1)]
# (کنسرواتیس) : frequency = 1, posting list: [(964, 1)]
# (لیبرالیس) : frequency = 1, posting list: [(964, 1)]
# (ناشیس) : frequency = 1, posting list: [(964, 1)]
# (نئوکنسرواتیس) : frequency = 1, posting list: [(964, 1)]
# (ایرونیگ) : frequency = 1, posting list: [(964, 1)]
# (کریستول) : frequency = 1, posting list: [(964, 1)]
# (گائتانا) : frequency = 1, posting list: [(964, 1)]
# (موسکا) : frequency = 1, posting list: [(964, 1)]
# (گاستون) : frequency = 1, posting list: [(964, 1)]
# (بوتو) : frequency = 1, posting list: [(964, 1)]
# (شخصیه) : frequency = 1, posting list: [(965, 1)]
# (عقود) : frequency = 1, posting list: [(965, 1)]
# (مزاجند) : frequency = 1, posting list: [(966, 1)]
# (آماده_اند) : frequency = 1, posting list: [(966, 1)]
# (استانل) : frequency = 1, posting list: [(966, 1)]
# (هال) : frequency = 1, posting list: [(966, 1)]
# (خواهد_که) : frequency = 1, posting list: [(966, 1)]
# (همسال) : frequency = 1, posting list: [(966, 1)]
# (بکوشند) : frequency = 1, posting list: [(966, 1)]
# (هویت) : frequency = 1, posting list: [(966, 1)]
# (LG) : frequency = 1, posting list: [(967, 1)]
# (۵۸) : frequency = 1, posting list: [(967, 1)]
# (قاب) : frequency = 1, posting list: [(967, 1)]
# (اسپیکر) : frequency = 1, posting list: [(967, 1)]
# (دروبین) : frequency = 1, posting list: [(967, 1)]
# (لنز) : frequency = 1, posting list: [(967, 1)]
# (LCD) : frequency = 1, posting list: [(967, 1)]
# (فلکس) : frequency = 1, posting list: [(967, 1)]
# (هلپ) : frequency = 1, posting list: [(967, 1)]
# (Êzidî) : frequency = 1, posting list: [(968, 1)]
# (ئیزید) : frequency = 1, posting list: [(968, 1)]
# (ایزید) : frequency = 1, posting list: [(968, 1)]
# (غیرمعمول) : frequency = 1, posting list: [(968, 1)]
# (مهرپرست) : frequency = 1, posting list: [(968, 1)]
# (عد) : frequency = 2, posting list: [(968, 2)]
# (طاووس) : frequency = 5, posting list: [(968, 5)]
# (یزیدیه) : frequency = 1, posting list: [(968, 1)]
# (التونج) : frequency = 1, posting list: [(968, 1)]
# (خواهد_اگر) : frequency = 1, posting list: [(969, 1)]
# (چندبرابر) : frequency = 1, posting list: [(969, 1)]
# (حاتم) : frequency = 1, posting list: [(969, 1)]
# (آرار) : frequency = 2, posting list: [(970, 1), (976, 1)]
# (تمد) : frequency = 1, posting list: [(970, 1)]
# (گرج) : frequency = 1, posting list: [(970, 1)]
# (ششصد) : frequency = 1, posting list: [(970, 1)]
# (پیو) : frequency = 1, posting list: [(970, 1)]
# (ووسک) : frequency = 1, posting list: [(970, 1)]
# (گمشده) : frequency = 1, posting list: [(971, 1)]
# (آکاد) : frequency = 1, posting list: [(971, 1)]
# (آسور) : frequency = 1, posting list: [(971, 1)]
# (استیو) : frequency = 1, posting list: [(971, 1)]
# (هینتس) : frequency = 1, posting list: [(971, 1)]
# (داشیل) : frequency = 4, posting list: [(972, 4)]
# (اسپید) : frequency = 1, posting list: [(972, 1)]
# (دزدیدن) : frequency = 1, posting list: [(972, 1)]
# (پاورق) : frequency = 1, posting list: [(972, 1)]
# (ساخته_شدند) : frequency = 1, posting list: [(972, 1)]
# (هیوستن) : frequency = 3, posting list: [(972, 3)]
# (دکوپاژ) : frequency = 1, posting list: [(972, 1)]
# (وارنر) : frequency = 1, posting list: [(972, 1)]
# (هام) : frequency = 1, posting list: [(972, 1)]
# (عمه) : frequency = 2, posting list: [(973, 1), (974, 1)]
# (صفورا) : frequency = 2, posting list: [(973, 1), (974, 1)]
# (غفارزاده) : frequency = 2, posting list: [(973, 1), (974, 1)]
# (خوشخو) : frequency = 1, posting list: [(975, 1)]
# (آناطول) : frequency = 1, posting list: [(976, 1)]
# (سرسخ) : frequency = 1, posting list: [(976, 1)]
# (عزرائیل) : frequency = 2, posting list: [(977, 2)]
# (درتولید) : frequency = 1, posting list: [(977, 1)]
# (اندرحکا) : frequency = 1, posting list: [(977, 1)]
# (زنگوله) : frequency = 1, posting list: [(977, 1)]
# (عزراییل) : frequency = 1, posting list: [(977, 1)]
# (ماسوله) : frequency = 1, posting list: [(978, 1)]
# (بستان) : frequency = 1, posting list: [(978, 1)]
# (مسروب) : frequency = 1, posting list: [(979, 1)]
# (ماشتوتس) : frequency = 1, posting list: [(979, 1)]
# (ادیک) : frequency = 1, posting list: [(979, 1)]
# (باغداسار) : frequency = 1, posting list: [(979, 1)]
# (پولدار) : frequency = 2, posting list: [(980, 2)]
# (وضوع) : frequency = 1, posting list: [(980, 1)]
# (ادغا) : frequency = 1, posting list: [(980, 1)]
# (رابر) : frequency = 1, posting list: [(980, 1)]
# (کیوساک) : frequency = 1, posting list: [(980, 1)]
# (تریس) : frequency = 1, posting list: [(980, 1)]
# (تمارین) : frequency = 1, posting list: [(980, 1)]
# (شیوافر) : frequency = 1, posting list: [(980, 1)]
# (مح) : frequency = 1, posting list: [(981, 1)]
# (دعل) : frequency = 1, posting list: [(981, 1)]
# (محلات) : frequency = 2, posting list: [(981, 2)]
# (متوف) : frequency = 1, posting list: [(981, 1)]
# (۱۲۸۸) : frequency = 1, posting list: [(981, 1)]
# (اسعد) : frequency = 1, posting list: [(981, 1)]
# (دلتنگ) : frequency = 1, posting list: [(981, 1)]
# (ترانه) : frequency = 1, posting list: [(982, 1)]
# (اپرا) : frequency = 1, posting list: [(982, 1)]
# (۱۳۸۸) : frequency = 3, posting list: [(983, 3)]
# (امورخارجه) : frequency = 1, posting list: [(983, 1)]
# (سازمانن) : frequency = 1, posting list: [(983, 1)]
# (خودار) : frequency = 1, posting list: [(983, 1)]
# (۰۶) : frequency = 1, posting list: [(983, 1)]
# (۰۷) : frequency = 1, posting list: [(983, 1)]
# (۰۴) : frequency = 1, posting list: [(983, 1)]
# (مهتد) : frequency = 2, posting list: [(984, 2)]
# (ایرانیان) : frequency = 1, posting list: [(984, 1)]
# (مانوس) : frequency = 1, posting list: [(984, 1)]
# (آفرید) : frequency = 1, posting list: [(984, 1)]
# (ناهموار) : frequency = 1, posting list: [(985, 1)]
# (نمایه) : frequency = 1, posting list: [(985, 1)]
# (شالچ) : frequency = 1, posting list: [(985, 1)]
# (جوئ) : frequency = 1, posting list: [(986, 1)]
# (بگیریند) : frequency = 1, posting list: [(986, 1)]
# (رض) : frequency = 3, posting list: [(987, 3)]
# (۱۳۴۲) : frequency = 1, posting list: [(987, 1)]
# (پیداکرد) : frequency = 1, posting list: [(987, 1)]
# (الانبیاء) : frequency = 1, posting list: [(987, 1)]
# (سزارین) : frequency = 1, posting list: [(988, 1)]
# (چرخید) : frequency = 1, posting list: [(988, 1)]
# (Avecina) : frequency = 1, posting list: [(988, 1)]
# (مشهورند) : frequency = 1, posting list: [(988, 1)]
# (چاقو) : frequency = 1, posting list: [(988, 1)]
# (اذکا) : frequency = 1, posting list: [(988, 1)]
# (جریر) : frequency = 2, posting list: [(989, 2)]
# (۳۵۲) : frequency = 1, posting list: [(989, 1)]
# (تفضیل) : frequency = 1, posting list: [(989, 1)]
# (مرسل) : frequency = 1, posting list: [(989, 1)]
# (اسلوب) : frequency = 2, posting list: [(989, 2)]
# (بیهق) : frequency = 1, posting list: [(989, 1)]
# (ابومنصور) : frequency = 1, posting list: [(989, 1)]
# (ایدون) : frequency = 1, posting list: [(989, 1)]
# (ایدر) : frequency = 1, posting list: [(989, 1)]
# (پرگس) : frequency = 1, posting list: [(989, 1)]
# (کارگیرد) : frequency = 1, posting list: [(989, 1)]
# (ودستیاب) : frequency = 1, posting list: [(990, 1)]
# (اینصور) : frequency = 1, posting list: [(990, 1)]
# (میانبر) : frequency = 1, posting list: [(990, 1)]
# (نپخته) : frequency = 1, posting list: [(991, 1)]
# (جوانه) : frequency = 3, posting list: [(991, 3)]
# (جوانتر) : frequency = 1, posting list: [(991, 1)]
# (آنفلونزا) : frequency = 1, posting list: [(991, 1)]
# (معالجه) : frequency = 1, posting list: [(991, 1)]
# (دیاب) : frequency = 1, posting list: [(991, 1)]
# (اولسر) : frequency = 1, posting list: [(991, 1)]
# (مفاصل) : frequency = 1, posting list: [(991, 1)]
# (غذایی) : frequency = 1, posting list: [(991, 1)]
# (صدمه) : frequency = 2, posting list: [(991, 2)]
# (نمی‌زنند) : frequency = 1, posting list: [(991, 1)]
# (خوراکخانه) : frequency = 1, posting list: [(991, 1)]
# (زندن) : frequency = 1, posting list: [(991, 1)]
# (نان) : frequency = 2, posting list: [(991, 2)]
# (ویفر) : frequency = 1, posting list: [(991, 1)]
# (آشامیدنی) : frequency = 1, posting list: [(991, 1)]
# (سوزا) : frequency = 1, posting list: [(991, 1)]
# (ناکنتن) : frequency = 1, posting list: [(991, 1)]
# (اسپهبد) : frequency = 1, posting list: [(992, 1)]
# (سرخاب) : frequency = 1, posting list: [(992, 1)]
# (قارن) : frequency = 1, posting list: [(992, 1)]
# (سعدالدین) : frequency = 2, posting list: [(992, 2)]
# (وراوین) : frequency = 3, posting list: [(992, 3)]
# (۶۱۷) : frequency = 1, posting list: [(992, 1)]
# (بلامنازع) : frequency = 1, posting list: [(992, 1)]
# (مزین) : frequency = 1, posting list: [(992, 1)]
# (روضهالعقول) : frequency = 1, posting list: [(992, 1)]
# (امپریالیست) : frequency = 1, posting list: [(993, 1)]
# (مستعمره) : frequency = 1, posting list: [(993, 1)]
# (استمرار) : frequency = 1, posting list: [(993, 1)]
# (بارنز) : frequency = 1, posting list: [(993, 1)]
# (زیارت) : frequency = 1, posting list: [(994, 1)]
# (تقر) : frequency = 1, posting list: [(994, 1)]
# (ربوب) : frequency = 1, posting list: [(994, 1)]
# (شیفتگ) : frequency = 1, posting list: [(994, 1)]
# (خرمن) : frequency = 1, posting list: [(994, 1)]
# (ائمه) : frequency = 3, posting list: [(994, 3)]
# (بازپسین) : frequency = 1, posting list: [(994, 1)]
# (برچینند) : frequency = 1, posting list: [(994, 1)]
# (توشه) : frequency = 1, posting list: [(994, 1)]
# (اطهار) : frequency = 1, posting list: [(994, 1)]
# (سامراء) : frequency = 1, posting list: [(994, 1)]
# (اربعین) : frequency = 2, posting list: [(994, 2)]
# (سیستان) : frequency = 1, posting list: [(994, 1)]
# (پرکش) : frequency = 1, posting list: [(995, 1)]
# (میندر) : frequency = 2, posting list: [(995, 2)]
# (فریزلند) : frequency = 1, posting list: [(995, 1)]
# (کریستس) : frequency = 1, posting list: [(995, 1)]
# (آندرسن) : frequency = 1, posting list: [(995, 1)]
# (دویونگ) : frequency = 1, posting list: [(995, 1)]
# (گوار) : frequency = 1, posting list: [(996, 1)]
# (هروئین) : frequency = 1, posting list: [(996, 1)]
# (سنن) : frequency = 1, posting list: [(997, 1)]
# (جاودان) : frequency = 1, posting list: [(997, 1)]
# (نغماچ) : frequency = 1, posting list: [(997, 1)]
# (کازرون) : frequency = 1, posting list: [(997, 1)]
# (می‌گذارند) : frequency = 1, posting list: [(998, 1)]
# (نانوان) : frequency = 1, posting list: [(999, 1)]
# (آزواسپرم) : frequency = 1, posting list: [(999, 1)]
# (نعوظ) : frequency = 2, posting list: [(999, 2)]
# (بیضه) : frequency = 3, posting list: [(999, 3)]
# (تستوسترون) : frequency = 1, posting list: [(999, 1)]
# (هیپوگونادیس) : frequency = 1, posting list: [(999, 1)]
# (دیررس) : frequency = 1, posting list: [(999, 1)]
# (خوردگ) : frequency = 1, posting list: [(999, 1)]
# (نغز) : frequency = 1, posting list: [(1000, 1)]
# (شادرو) : frequency = 1, posting list: [(1000, 1)]
# (وجدان) : frequency = 1, posting list: [(1000, 1)]
# (خوانده_بود) : frequency = 1, posting list: [(1000, 1)]
# (اورمیه) : frequency = 1, posting list: [(1000, 1)]
# (داغسر) : frequency = 1, posting list: [(1000, 1)]
# زمان اجرا: 3.5234038829803467 ثانیه

# %%
def calculate_statistics_Persian(df):
    total_tokens = 0
    for index, row in df.iterrows():
        normalized_text = row['stemming_content']
        total_tokens += len(normalized_text)

    total_documents = len(df)
    total_file_size = df['stemming_content'].apply(lambda x: len(x)).sum()

    file_path = "/content/inverted_index_persian.txt"
    if os.path.exists(file_path):
      file_size = os.path.getsize(file_path)
    else:
      print("file not found")

    return total_tokens, total_documents, total_file_size,file_size

total_tokens, total_documents, total_file_size, file_size = calculate_statistics_Persian(df)
print(f"Total Tokens: {total_tokens}")
print(f"Total Documents: {total_documents}")
print(f"Total File Size: {total_file_size} bytes")
print(f"The size of Persian inverted index file: {file_size} bytes")
# Out:
# Total Tokens: 243131
# Total Documents: 2824
# Total File Size: 243131 bytes
# The size of Persian inverted index file: 1311474 bytes

# %%
persian_terms_binary = create_terms_binary(persian_inverted_index)

# %%
query = input("Enter query ... : ")
print(query)
# Out:
# Enter query ... : شاهکار.هنر.تمدن
# شاهکار.هنر.تمدن

# %%
terms, operators = persian_query_processing(query)
result, document_numbers = boolean_retrieval(persian_terms_binary, terms, operators)
# Out:
# شاهکار
# هنر
# تمدن
# List of terms: ['شاهکار', 'هنر', 'تمدن']
# List of operators: ['.', '.']
# term:  شاهکار
# processed term :  شاهکار
# term binary :  100000000000000000000000000000
# term :  هنر
# processed term :  هنر
# term binary :  111111001000100000000000000000
# term :  تمدن
# processed term :  تمدن
# term binary :  111110101100010000000000000000
# Result: 100000000000000000000000000000
# Document Numbers: [1]

# %%
file_path = "persian_queries.txt"

query_number = "1"

result_list = [str(item) for item in document_numbers]

result_list_str = ','.join(result_list)


with open(file_path, 'w') as file:
    file.write(query_number + ',')
    file.write(result_list_str)

# %%
query_number = "12"

result_list = [str(item) for item in document_numbers]

result_list_str = ','.join(result_list)

with open(file_path, 'a') as file:
    file.write('\n')
    file.write(query_number + ',')
    file.write(result_list_str)

# %% [markdown]
# #English Dataset

# %%
# !wget http://www.cs.cmu.edu/~ark/personas/data/MovieSummaries.tar.gz
# !tar -xf MovieSummaries.tar.gz
# Out:
# --2023-11-10 16:29:25--  http://www.cs.cmu.edu/~ark/personas/data/MovieSummaries.tar.gz
# Resolving www.cs.cmu.edu (www.cs.cmu.edu)... 128.2.42.95
# Connecting to www.cs.cmu.edu (www.cs.cmu.edu)|128.2.42.95|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48002242 (46M) [application/x-gzip]
# Saving to: ‘MovieSummaries.tar.gz’
#
# MovieSummaries.tar. 100%[===================>]  45.78M   654KB/s    in 83s
#
# 2023-11-10 16:30:49 (568 KB/s) - ‘MovieSummaries.tar.gz’ saved [48002242/48002242]

# %%
df2 = pd.read_csv("/content/MovieSummaries/plot_summaries.txt", delimiter = "\t",names=["id","text"])
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42303 entries, 0 to 42302
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      42303 non-null  int64
#  1   text    42303 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 661.1+ KB

# %%
df2.head()
# Out:
#          id                                               text
# 0  23890098  Shlykov, a hard-working taxi driver and Lyosha...
# 1  31186339  The nation of Panem consists of a wealthy Capi...
# 2  20663735  Poovalli Induchoodan  is sentenced for six yea...
# 3   2231378  The Lemon Drop Kid , a New York City swindler,...
# 4    595909  Seventh-day Adventist Church pastor Michael Ch...

# %%
df2.iloc[333:343]
# Out:
#            id                                               text
# 333   3182458  The stories follow a black formal tailcoat as ...
# 334  14901197  Crossing the plains, a wagon train comes acros...
# 335    474750  A new heroine has arrived in Gotham whose iden...
# 336  32777283  Justin Bayard, a Northern Territory policeman,...
# 337   6002416  The central character is the Post Master who i...
# 338   3322205  Pooja Dharamchand  is the daughter of a rich M...
# 339   3006994  The film features two anonymous Scottish-accen...
# 340   9537791  Sam, a college student in a small Northwestern...
# 341  23910715  She's in for a wild ride, when Jean Madison , ...
# 342     45772   On November 25, 1975, Rocky Balboa  is introd...

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
null_counts = df2.isnull().sum()
null_counts
# Out:
# id      0
# text    0
# dtype: int64

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

nltk.download('stopwords')
stemmer = PorterStemmer()
english_stopwords = set(nltk.corpus.stopwords.words('english'))

def tokenize_english(text):
    tokens = nltk.word_tokenize(text)
    return tokens

def normalize_english_text(tokenized_text):
    tokenized_text = [token.lower() for token in tokenized_text]
    tokenized_text = [remove_punctuation(token) for token in tokenized_text]
    return tokenized_text

def removeStopwords_English(tokens):
    tokens = [token for token in tokens if token.isalpha() and token not in english_stopwords]
    return tokens

def stem_english(tokens):
    tokens = [stemmer.stem(token) for token in tokens]
    return tokens

def remove_punctuation(tokenized_text):
    tokens = nltk.word_tokenize(tokenized_text)
    tokens = [token for token in tokens if token.isalpha()]
    return ' '.join(tokens)

df2['tokenized_text'] = df2['text'].apply(tokenize_english)
df2['tokenized_text'] = df2['tokenized_text'].apply(removeStopwords_English)
df2['normalized_text'] = df2['tokenized_text'].apply(normalize_english_text)
df2['stemming_text'] = df2['normalized_text'].apply(stem_english)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df2.loc[0,'text']
# Out:
# "Shlykov, a hard-working taxi driver and Lyosha, a saxophonist, develop a bizarre love-hate relationship, and despite their prejudices, realize they aren't so different after all."

# %%
df2.loc[0,'tokenized_text']
# Out:
# ['Shlykov',
#  'taxi',
#  'driver',
#  'Lyosha',
#  'saxophonist',
#  'develop',
#  'bizarre',
#  'relationship',
#  'despite',
#  'prejudices',
#  'realize',
#  'different']

# %%
df2.loc[0,'normalized_text']
# Out:
# ['shlykov',
#  'taxi',
#  'driver',
#  'lyosha',
#  'saxophonist',
#  'develop',
#  'bizarre',
#  'relationship',
#  'despite',
#  'prejudices',
#  'realize',
#  'different']

# %%
df2.loc[0,'stemming_text']
# Out:
# ['shlykov',
#  'taxi',
#  'driver',
#  'lyosha',
#  'saxophonist',
#  'develop',
#  'bizarr',
#  'relationship',
#  'despit',
#  'prejudic',
#  'realiz',
#  'differ']

# %%
df2.iloc[0]
# Out:
# id                                                          23890098
# text               Shlykov, a hard-working taxi driver and Lyosha...
# tokenized_text     [Shlykov, taxi, driver, Lyosha, saxophonist, d...
# normalized_text    [shlykov, taxi, driver, lyosha, saxophonist, d...
# stemming_text      [shlykov, taxi, driver, lyosha, saxophonist, d...
# Name: 0, dtype: object

# %%
def create_english_inverted_index(df):
  subset_dataset_english = df.head(1000)

  inverted_index_english = defaultdict(list)
  term_dictionary_english = defaultdict(int)

  for index, row in subset_dataset_english.iterrows():
      document_id = index + 1
      normalized_text = row['stemming_text']

      term_count = defaultdict(int)
      for token in normalized_text:
          term_count[token] += 1

      for term, count in term_count.items():
          if term not in term_dictionary_english:
              term_dictionary_english[term] = 0
          term_dictionary_english[term] += count

          inverted_index_english[term].append((document_id, count))

  for term, postings in inverted_index_english.items():
      inverted_index_english[term] = sorted(postings, key=lambda x: x[1], reverse=True)

  with open('inverted_index_english.txt', 'w') as file:
    for term, postings in inverted_index_english.items():
        term_freq = term_dictionary_english[term]
        posting_list = [(doc_id, count) for doc_id, count in postings]
        output_line = f"({term}) : frequency = {term_freq}, posting list: {posting_list}\n"
        print(f"({term}) : frequency = {term_freq}, posting list: {posting_list}")
        file.write(output_line)
  return inverted_index_english

# %%
start_time = time.time()
english_inverted_index = create_english_inverted_index(df2)
end_time = time.time()
execution_time = end_time - start_time
print(f"زمان اجرا: {execution_time} ثانیه")
# Out:
# Streaming output truncated to the last 5000 lines.
# (shenanigan) : frequency = 1, posting list: [(427, 1)]
# (lucidli) : frequency = 1, posting list: [(427, 1)]
# (cremona) : frequency = 1, posting list: [(428, 1)]
# (luthier) : frequency = 1, posting list: [(428, 1)]
# (stradivari) : frequency = 1, posting list: [(428, 1)]
# (qualiti) : frequency = 4, posting list: [(428, 1), (435, 1), (634, 1), (747, 1)]
# (impecc) : frequency = 2, posting list: [(428, 1), (614, 1)]
# (sombor) : frequency = 1, posting list: [(428, 1)]
# (detroit) : frequency = 6, posting list: [(429, 2), (668, 2), (482, 1), (835, 1)]
# (ivanovich) : frequency = 1, posting list: [(429, 1)]
# (gail) : frequency = 5, posting list: [(429, 4), (809, 1)]
# (immort) : frequency = 6, posting list: [(811, 3), (429, 1), (520, 1), (537, 1)]
# (spaghetti) : frequency = 2, posting list: [(429, 1), (514, 1)]
# (advis) : frequency = 9, posting list: [(429, 1), (451, 1), (489, 1), (634, 1), (656, 1), (694, 1), (877, 1), (957, 1), (987, 1)]
# (formid) : frequency = 6, posting list: [(429, 1), (493, 1), (569, 1), (671, 1), (695, 1), (978, 1)]
# (rollercoast) : frequency = 1, posting list: [(429, 1)]
# (hospic) : frequency = 2, posting list: [(429, 2)]
# (theresa) : frequency = 1, posting list: [(429, 1)]
# (seuss) : frequency = 1, posting list: [(429, 1)]
# (ayatollah) : frequency = 1, posting list: [(430, 1)]
# (khomeini) : frequency = 1, posting list: [(430, 1)]
# (mikhail) : frequency = 2, posting list: [(430, 1), (876, 1)]
# (gorbachev) : frequency = 2, posting list: [(430, 2)]
# (yasser) : frequency = 1, posting list: [(430, 1)]
# (arafat) : frequency = 1, posting list: [(430, 1)]
# (muammar) : frequency = 1, posting list: [(430, 1)]
# (gaddafi) : frequency = 1, posting list: [(430, 1)]
# (fidel) : frequency = 1, posting list: [(430, 1)]
# (castro) : frequency = 1, posting list: [(430, 1)]
# (idi) : frequency = 1, posting list: [(430, 1)]
# (pahpshmir) : frequency = 2, posting list: [(430, 2)]
# (drebin) : frequency = 4, posting list: [(430, 4)]
# (attende) : frequency = 2, posting list: [(430, 1), (666, 1)]
# (dy) : frequency = 1, posting list: [(430, 1)]
# (nordberg) : frequency = 10, posting list: [(430, 10)]
# (ludwig) : frequency = 19, posting list: [(430, 19)]
# (hocken) : frequency = 3, posting list: [(430, 3)]
# (kennedi) : frequency = 11, posting list: [(918, 8), (430, 1), (760, 1), (888, 1)]
# (cryptic) : frequency = 2, posting list: [(430, 1), (485, 1)]
# (wacki) : frequency = 1, posting list: [(430, 1)]
# (olsen) : frequency = 1, posting list: [(430, 1)]
# (cufflink) : frequency = 3, posting list: [(430, 3)]
# (beeper) : frequency = 2, posting list: [(430, 2)]
# (unknow) : frequency = 2, posting list: [(430, 1), (895, 1)]
# (luckless) : frequency = 1, posting list: [(430, 1)]
# (spencer) : frequency = 5, posting list: [(728, 3), (430, 1), (723, 1)]
# (villaini) : frequency = 2, posting list: [(430, 1), (679, 1)]
# (pallazzo) : frequency = 1, posting list: [(430, 1)]
# (mangl) : frequency = 1, posting list: [(430, 1)]
# (anthem) : frequency = 2, posting list: [(430, 1), (991, 1)]
# (umpir) : frequency = 1, posting list: [(430, 1)]
# (frisk) : frequency = 1, posting list: [(430, 1)]
# (interf) : frequency = 2, posting list: [(430, 1), (488, 1)]
# (reggi) : frequency = 24, posting list: [(938, 23), (430, 1)]
# (incapacit) : frequency = 6, posting list: [(430, 1), (528, 1), (602, 1), (887, 1), (911, 1), (983, 1)]
# (mezzanin) : frequency = 1, posting list: [(430, 1)]
# (usc) : frequency = 1, posting list: [(430, 1)]
# (tromp) : frequency = 1, posting list: [(430, 1)]
# (mason) : frequency = 12, posting list: [(758, 4), (802, 4), (431, 1), (788, 1), (846, 1), (875, 1)]
# (whiz) : frequency = 1, posting list: [(431, 1)]
# (hobbi) : frequency = 1, posting list: [(431, 1)]
# (modifi) : frequency = 1, posting list: [(431, 1)]
# (jamaal) : frequency = 1, posting list: [(431, 1)]
# (delbert) : frequency = 1, posting list: [(431, 1)]
# (ritchi) : frequency = 1, posting list: [(431, 1)]
# (marinelli) : frequency = 1, posting list: [(431, 1)]
# (judi) : frequency = 1, posting list: [(431, 1)]
# (avid) : frequency = 1, posting list: [(431, 1)]
# (riget) : frequency = 3, posting list: [(432, 3)]
# (rigshospitalet) : frequency = 1, posting list: [(432, 1)]
# (copenhagen) : frequency = 1, posting list: [(432, 1)]
# (bleach) : frequency = 1, posting list: [(432, 1)]
# (blegdamsvej) : frequency = 1, posting list: [(432, 1)]
# (spiritualist) : frequency = 2, posting list: [(432, 1), (640, 1)]
# (sigrid) : frequency = 1, posting list: [(432, 1)]
# (druss) : frequency = 3, posting list: [(432, 3)]
# (illegitimaci) : frequency = 1, posting list: [(432, 1)]
# (specimen) : frequency = 5, posting list: [(488, 3), (432, 1), (502, 1)]
# (patholog) : frequency = 1, posting list: [(432, 1)]
# (bondo) : frequency = 3, posting list: [(432, 3)]
# (neurosurgeon) : frequency = 2, posting list: [(432, 2)]
# (stig) : frequency = 2, posting list: [(432, 2)]
# (helmer) : frequency = 2, posting list: [(432, 2)]
# (appointe) : frequency = 1, posting list: [(432, 1)]
# (sweden) : frequency = 1, posting list: [(432, 1)]
# (neurosurgeri) : frequency = 1, posting list: [(432, 1)]
# (veget) : frequency = 2, posting list: [(432, 1), (818, 1)]
# (pathologist) : frequency = 2, posting list: [(432, 1), (485, 1)]
# (liver) : frequency = 4, posting list: [(432, 3), (562, 1)]
# (plotlin) : frequency = 1, posting list: [(432, 1)]
# (abnorm) : frequency = 1, posting list: [(432, 1)]
# (dishwash) : frequency = 2, posting list: [(432, 1), (587, 1)]
# (danskjävlar) : frequency = 1, posting list: [(432, 1)]
# (jiab) : frequency = 3, posting list: [(433, 3)]
# (undo) : frequency = 2, posting list: [(433, 1), (537, 1)]
# (karma) : frequency = 1, posting list: [(433, 1)]
# (rhode) : frequency = 2, posting list: [(434, 2)]
# (tijuana) : frequency = 1, posting list: [(434, 1)]
# (embroil) : frequency = 1, posting list: [(434, 1)]
# (spader) : frequency = 1, posting list: [(434, 1)]
# (dirt) : frequency = 3, posting list: [(434, 1), (558, 1), (599, 1)]
# (biker) : frequency = 11, posting list: [(887, 4), (938, 3), (477, 2), (434, 1), (790, 1)]
# (liabil) : frequency = 1, posting list: [(434, 1)]
# (georgina) : frequency = 41, posting list: [(435, 41)]
# (salt) : frequency = 2, posting list: [(435, 1), (509, 1)]
# (contractor) : frequency = 3, posting list: [(435, 1), (661, 1), (869, 1)]
# (zach) : frequency = 49, posting list: [(435, 34), (767, 15)]
# (condom) : frequency = 3, posting list: [(435, 1), (498, 1), (933, 1)]
# (sadden) : frequency = 3, posting list: [(435, 1), (531, 1), (802, 1)]
# (conceiv) : frequency = 2, posting list: [(435, 1), (508, 1)]
# (goof) : frequency = 1, posting list: [(435, 1)]
# (georgia) : frequency = 3, posting list: [(435, 3)]
# (clem) : frequency = 16, posting list: [(435, 11), (559, 5)]
# (ovul) : frequency = 1, posting list: [(435, 1)]
# (aback) : frequency = 2, posting list: [(435, 1), (709, 1)]
# (alexandra) : frequency = 10, posting list: [(435, 5), (617, 3), (537, 2)]
# (darl) : frequency = 1, posting list: [(435, 1)]
# (zip) : frequency = 1, posting list: [(435, 1)]
# (sultri) : frequency = 2, posting list: [(435, 1), (763, 1)]
# (ferri) : frequency = 6, posting list: [(957, 3), (435, 1), (739, 1), (792, 1)]
# (sperm) : frequency = 4, posting list: [(435, 3), (451, 1)]
# (baster) : frequency = 2, posting list: [(435, 2)]
# (infertil) : frequency = 1, posting list: [(435, 1)]
# (insemin) : frequency = 1, posting list: [(435, 1)]
# (squirt) : frequency = 1, posting list: [(435, 1)]
# (spank) : frequency = 1, posting list: [(435, 1)]
# (mope) : frequency = 22, posting list: [(747, 17), (435, 1), (461, 1), (803, 1), (807, 1), (952, 1)]
# (scuffl) : frequency = 4, posting list: [(435, 1), (686, 1), (701, 1), (877, 1)]
# (sore) : frequency = 1, posting list: [(435, 1)]
# (dingman) : frequency = 1, posting list: [(436, 1)]
# (vanderpark) : frequency = 1, posting list: [(436, 1)]
# (vapoor) : frequency = 4, posting list: [(436, 4)]
# (fece) : frequency = 1, posting list: [(436, 1)]
# (scof) : frequency = 1, posting list: [(436, 1)]
# (squander) : frequency = 2, posting list: [(436, 1), (534, 1)]
# (generos) : frequency = 1, posting list: [(436, 1)]
# (corkey) : frequency = 3, posting list: [(436, 3)]
# (sequest) : frequency = 1, posting list: [(436, 1)]
# (elector) : frequency = 3, posting list: [(436, 1), (440, 1), (726, 1)]
# (veterinarian) : frequency = 2, posting list: [(436, 1), (877, 1)]
# (oblig) : frequency = 4, posting list: [(436, 1), (576, 1), (664, 1), (686, 1)]
# (flan) : frequency = 2, posting list: [(436, 2)]
# (dessert) : frequency = 1, posting list: [(436, 1)]
# (infomerci) : frequency = 2, posting list: [(436, 1), (907, 1)]
# (nasibo) : frequency = 9, posting list: [(437, 9)]
# (naajar) : frequency = 10, posting list: [(437, 10)]
# (santi) : frequency = 4, posting list: [(437, 4)]
# (veero) : frequency = 2, posting list: [(437, 2)]
# (gurmeet) : frequency = 4, posting list: [(437, 4)]
# (mela) : frequency = 1, posting list: [(437, 1)]
# (diala) : frequency = 7, posting list: [(437, 7)]
# (danpura) : frequency = 1, posting list: [(437, 1)]
# (bhan) : frequency = 3, posting list: [(437, 3)]
# (willingli) : frequency = 4, posting list: [(437, 1), (590, 1), (692, 1), (957, 1)]
# (najar) : frequency = 1, posting list: [(437, 1)]
# (seeta) : frequency = 8, posting list: [(437, 8)]
# (reus) : frequency = 1, posting list: [(437, 1)]
# (swarno) : frequency = 2, posting list: [(437, 2)]
# (primari) : frequency = 3, posting list: [(438, 1), (576, 1), (623, 1)]
# (homework) : frequency = 1, posting list: [(438, 1)]
# (mustafa) : frequency = 9, posting list: [(555, 6), (693, 2), (438, 1)]
# (kemal) : frequency = 1, posting list: [(438, 1)]
# (atatürk) : frequency = 2, posting list: [(438, 2)]
# (sher) : frequency = 9, posting list: [(439, 7), (975, 2)]
# (nagend) : frequency = 9, posting list: [(439, 9)]
# (poach) : frequency = 1, posting list: [(439, 1)]
# (bansi) : frequency = 2, posting list: [(439, 2)]
# (parrot) : frequency = 1, posting list: [(439, 1)]
# (mithu) : frequency = 1, posting list: [(439, 1)]
# (clutch) : frequency = 6, posting list: [(439, 2), (477, 1), (674, 1), (697, 1), (712, 1)]
# (enim) : frequency = 1, posting list: [(439, 1)]
# (unworthi) : frequency = 1, posting list: [(439, 1)]
# (brijmohan) : frequency = 2, posting list: [(439, 2)]
# (buddhi) : frequency = 3, posting list: [(439, 3)]
# (aval) : frequency = 1, posting list: [(439, 1)]
# (chand) : frequency = 1, posting list: [(439, 1)]
# (dimagwala) : frequency = 1, posting list: [(439, 1)]
# (wisher) : frequency = 1, posting list: [(439, 1)]
# (mangola) : frequency = 1, posting list: [(439, 1)]
# (extent) : frequency = 3, posting list: [(439, 1), (530, 1), (818, 1)]
# (berserk) : frequency = 2, posting list: [(439, 1), (895, 1)]
# (grievous) : frequency = 1, posting list: [(439, 1)]
# (quarrel) : frequency = 6, posting list: [(729, 2), (439, 1), (491, 1), (503, 1), (535, 1)]
# (sukhiya) : frequency = 1, posting list: [(439, 1)]
# (ballot) : frequency = 3, posting list: [(440, 3)]
# (leftist) : frequency = 1, posting list: [(440, 1)]
# (inelig) : frequency = 3, posting list: [(440, 2), (529, 1)]
# (voter) : frequency = 2, posting list: [(440, 2)]
# (stem) : frequency = 2, posting list: [(440, 1), (800, 1)]
# (exclud) : frequency = 4, posting list: [(440, 3), (693, 1)]
# (poll) : frequency = 1, posting list: [(440, 1)]
# (jeb) : frequency = 1, posting list: [(440, 1)]
# (statewid) : frequency = 1, posting list: [(440, 1)]
# (vastli) : frequency = 2, posting list: [(440, 1), (503, 1)]
# (jung) : frequency = 4, posting list: [(441, 1), (486, 1), (601, 1), (750, 1)]
# (jeollado) : frequency = 1, posting list: [(441, 1)]
# (bias) : frequency = 1, posting list: [(441, 1)]
# (soju) : frequency = 1, posting list: [(441, 1)]
# (nighttim) : frequency = 2, posting list: [(441, 1), (444, 1)]
# (nameseptemb) : frequency = 1, posting list: [(441, 1)]
# (bequeath) : frequency = 3, posting list: [(441, 1), (612, 1), (619, 1)]
# (monetari) : frequency = 1, posting list: [(441, 1)]
# (beneficiari) : frequency = 2, posting list: [(441, 1), (671, 1)]
# (elat) : frequency = 2, posting list: [(441, 1), (757, 1)]
# (choreographi) : frequency = 1, posting list: [(441, 1)]
# (boney) : frequency = 1, posting list: [(441, 1)]
# (m) : frequency = 1, posting list: [(441, 1)]
# (akademik) : frequency = 1, posting list: [(442, 1)]
# (mstislav) : frequency = 1, posting list: [(442, 1)]
# (keldysh) : frequency = 1, posting list: [(442, 1)]
# (nasa) : frequency = 2, posting list: [(442, 1), (930, 1)]
# (hydrotherm) : frequency = 1, posting list: [(442, 1)]
# (ecosystem) : frequency = 3, posting list: [(442, 3)]
# (tube) : frequency = 2, posting list: [(442, 1), (990, 1)]
# (worm) : frequency = 1, posting list: [(442, 1)]
# (superh) : frequency = 1, posting list: [(442, 1)]
# (harsher) : frequency = 1, posting list: [(442, 1)]
# (terrestri) : frequency = 1, posting list: [(442, 1)]
# (abyss) : frequency = 1, posting list: [(442, 1)]
# (rm) : frequency = 1, posting list: [(442, 1)]
# (titan) : frequency = 1, posting list: [(442, 1)]
# (imax) : frequency = 1, posting list: [(442, 1)]
# (maquiladora) : frequency = 3, posting list: [(443, 3)]
# (sentinel) : frequency = 3, posting list: [(443, 2), (542, 1)]
# (bordertown) : frequency = 1, posting list: [(443, 1)]
# (oaxaca) : frequency = 1, posting list: [(443, 1)]
# (ciudad) : frequency = 1, posting list: [(443, 1)]
# (juárez) : frequency = 4, posting list: [(443, 4)]
# (diaz) : frequency = 2, posting list: [(443, 2)]
# (sol) : frequency = 2, posting list: [(443, 2)]
# (coney) : frequency = 6, posting list: [(444, 6)]
# (carousel) : frequency = 1, posting list: [(444, 1)]
# (arc) : frequency = 1, posting list: [(444, 1)]
# (mckane) : frequency = 1, posting list: [(444, 1)]
# (ce) : frequency = 1, posting list: [(444, 1)]
# (tilyou) : frequency = 2, posting list: [(444, 2)]
# (steeplechas) : frequency = 2, posting list: [(444, 2)]
# (luna) : frequency = 3, posting list: [(444, 3)]
# (dreamland) : frequency = 2, posting list: [(444, 2)]
# (reynold) : frequency = 3, posting list: [(971, 2), (444, 1)]
# (reenact) : frequency = 1, posting list: [(444, 1)]
# (incub) : frequency = 1, posting list: [(444, 1)]
# (midway) : frequency = 2, posting list: [(444, 1), (584, 1)]
# (ubiqu) : frequency = 1, posting list: [(444, 1)]
# (automobil) : frequency = 5, posting list: [(458, 2), (444, 1), (612, 1), (987, 1)]
# (barnyard) : frequency = 1, posting list: [(445, 1)]
# (dawg) : frequency = 7, posting list: [(445, 7)]
# (heneri) : frequency = 13, posting list: [(445, 13)]
# (chees) : frequency = 4, posting list: [(445, 3), (807, 1)]
# (chun) : frequency = 1, posting list: [(446, 1)]
# (cha) : frequency = 10, posting list: [(446, 9), (750, 1)]
# (kang) : frequency = 2, posting list: [(446, 1), (750, 1)]
# (vagu) : frequency = 2, posting list: [(446, 1), (604, 1)]
# (judo) : frequency = 2, posting list: [(446, 1), (714, 1)]
# (schoolgirl) : frequency = 1, posting list: [(446, 1)]
# (sob) : frequency = 3, posting list: [(446, 1), (593, 1), (892, 1)]
# (bolt) : frequency = 14, posting list: [(535, 6), (707, 4), (446, 1), (656, 1), (692, 1), (866, 1)]
# (rochest) : frequency = 14, posting list: [(802, 13), (447, 1)]
# (geeki) : frequency = 1, posting list: [(447, 1)]
# (hesler) : frequency = 1, posting list: [(447, 1)]
# (doodl) : frequency = 1, posting list: [(447, 1)]
# (gabbi) : frequency = 23, posting list: [(898, 17), (447, 6)]
# (pr) : frequency = 1, posting list: [(447, 1)]
# (cara) : frequency = 5, posting list: [(447, 5)]
# (cabot) : frequency = 10, posting list: [(475, 9), (447, 1)]
# (eg) : frequency = 1, posting list: [(447, 1)]
# (supermarket) : frequency = 8, posting list: [(987, 6), (447, 1), (757, 1)]
# (pissi) : frequency = 1, posting list: [(447, 1)]
# (piccolo) : frequency = 1, posting list: [(448, 1)]
# (flute) : frequency = 1, posting list: [(448, 1)]
# (obo) : frequency = 1, posting list: [(448, 1)]
# (clarinet) : frequency = 2, posting list: [(448, 1), (455, 1)]
# (bassoon) : frequency = 1, posting list: [(448, 1)]
# (trombon) : frequency = 1, posting list: [(448, 1)]
# (tuba) : frequency = 3, posting list: [(448, 3)]
# (cymbal) : frequency = 1, posting list: [(448, 1)]
# (timpani) : frequency = 1, posting list: [(448, 1)]
# (tubbi) : frequency = 6, posting list: [(448, 6)]
# (warmup) : frequency = 2, posting list: [(448, 2)]
# (ridicul) : frequency = 5, posting list: [(448, 1), (475, 1), (643, 1), (792, 1), (892, 1)]
# (frog) : frequency = 4, posting list: [(448, 3), (957, 1)]
# (melodi) : frequency = 19, posting list: [(865, 16), (448, 2), (538, 1)]
# (heather) : frequency = 4, posting list: [(449, 3), (875, 1)]
# (lofton) : frequency = 1, posting list: [(449, 1)]
# (rotten) : frequency = 2, posting list: [(449, 1), (972, 1)]
# (penderghast) : frequency = 1, posting list: [(450, 1)]
# (rhiannon) : frequency = 4, posting list: [(450, 4)]
# (rhi) : frequency = 1, posting list: [(450, 1)]
# (bedingfield) : frequency = 1, posting list: [(450, 1)]
# (sunshin) : frequency = 1, posting list: [(450, 1)]
# (conserv) : frequency = 2, posting list: [(450, 1), (462, 1)]
# (skank) : frequency = 1, posting list: [(450, 1)]
# (counteract) : frequency = 1, posting list: [(450, 1)]
# (stitch) : frequency = 2, posting list: [(450, 1), (582, 1)]
# (micah) : frequency = 4, posting list: [(450, 2), (496, 2)]
# (chlamydia) : frequency = 1, posting list: [(450, 1)]
# (griffith) : frequency = 6, posting list: [(450, 6)]
# (mascot) : frequency = 3, posting list: [(760, 2), (450, 1)]
# (cam) : frequency = 31, posting list: [(789, 30), (450, 1)]
# (lawnmow) : frequency = 2, posting list: [(450, 2)]
# (inez) : frequency = 1, posting list: [(451, 1)]
# (mar) : frequency = 20, posting list: [(508, 8), (602, 7), (451, 2), (473, 1), (689, 1), (710, 1)]
# (extravag) : frequency = 1, posting list: [(451, 1)]
# (frida) : frequency = 6, posting list: [(451, 6)]
# (fri) : frequency = 24, posting list: [(451, 23), (653, 1)]
# (leela) : frequency = 11, posting list: [(451, 11)]
# (farnsworth) : frequency = 17, posting list: [(640, 11), (451, 6)]
# (stamp) : frequency = 2, posting list: [(451, 1), (583, 1)]
# (muck) : frequency = 1, posting list: [(451, 1)]
# (leech) : frequency = 3, posting list: [(451, 2), (817, 1)]
# (hutch) : frequency = 5, posting list: [(451, 5)]
# (transient) : frequency = 2, posting list: [(451, 1), (832, 1)]
# (tin) : frequency = 3, posting list: [(451, 1), (738, 1), (940, 1)]
# (bewar) : frequency = 1, posting list: [(451, 1)]
# (miniatur) : frequency = 1, posting list: [(451, 1)]
# (milki) : frequency = 1, posting list: [(451, 1)]
# (survey) : frequency = 1, posting list: [(451, 1)]
# (asteroid) : frequency = 4, posting list: [(866, 2), (451, 1), (508, 1)]
# (primordi) : frequency = 2, posting list: [(451, 1), (571, 1)]
# (legion) : frequency = 3, posting list: [(451, 2), (510, 1)]
# (evolutionari) : frequency = 1, posting list: [(451, 1)]
# (extinct) : frequency = 3, posting list: [(451, 2), (466, 1)]
# (encyclopod) : frequency = 7, posting list: [(451, 7)]
# (resurg) : frequency = 1, posting list: [(451, 1)]
# (chi) : frequency = 3, posting list: [(731, 2), (451, 1)]
# (immun) : frequency = 3, posting list: [(965, 2), (451, 1)]
# (psionic) : frequency = 1, posting list: [(451, 1)]
# (zapp) : frequency = 2, posting list: [(451, 2)]
# (brannigan) : frequency = 1, posting list: [(451, 1)]
# (kif) : frequency = 2, posting list: [(451, 2)]
# (kroker) : frequency = 1, posting list: [(451, 1)]
# (bender) : frequency = 4, posting list: [(451, 4)]
# (sexist) : frequency = 1, posting list: [(451, 1)]
# (zoidberg) : frequency = 3, posting list: [(451, 3)]
# (herm) : frequency = 2, posting list: [(451, 2)]
# (nimbu) : frequency = 2, posting list: [(451, 2)]
# (implos) : frequency = 1, posting list: [(451, 1)]
# (omega) : frequency = 2, posting list: [(451, 2)]
# (uphold) : frequency = 2, posting list: [(451, 1), (598, 1)]
# (scruffi) : frequency = 2, posting list: [(451, 1), (673, 1)]
# (unread) : frequency = 1, posting list: [(451, 1)]
# (dome) : frequency = 1, posting list: [(451, 1)]
# (embryo) : frequency = 1, posting list: [(451, 1)]
# (manta) : frequency = 2, posting list: [(451, 1), (865, 1)]
# (forehead) : frequency = 3, posting list: [(451, 1), (861, 1), (933, 1)]
# (trillion) : frequency = 2, posting list: [(451, 2)]
# (mapado) : frequency = 1, posting list: [(452, 1)]
# (intellectu) : frequency = 5, posting list: [(453, 1), (689, 1), (798, 1), (808, 1), (881, 1)]
# (jock) : frequency = 1, posting list: [(453, 1)]
# (threesom) : frequency = 3, posting list: [(453, 2), (607, 1)]
# (monogam) : frequency = 1, posting list: [(453, 1)]
# (comorian) : frequency = 1, posting list: [(454, 1)]
# (djibril) : frequency = 1, posting list: [(454, 1)]
# (hamelin) : frequency = 1, posting list: [(455, 1)]
# (bode) : frequency = 1, posting list: [(455, 1)]
# (supreem) : frequency = 8, posting list: [(455, 8)]
# (mohican) : frequency = 1, posting list: [(455, 1)]
# (doff) : frequency = 1, posting list: [(455, 1)]
# (impecuni) : frequency = 1, posting list: [(456, 1)]
# (bookmak) : frequency = 1, posting list: [(456, 1)]
# (grierson) : frequency = 3, posting list: [(456, 3)]
# (songwrit) : frequency = 2, posting list: [(456, 1), (968, 1)]
# (nevern) : frequency = 10, posting list: [(456, 10)]
# (hardwick) : frequency = 4, posting list: [(456, 4)]
# (assumpt) : frequency = 2, posting list: [(456, 1), (948, 1)]
# (foolproof) : frequency = 2, posting list: [(456, 1), (503, 1)]
# (finalis) : frequency = 1, posting list: [(456, 1)]
# (visual) : frequency = 5, posting list: [(710, 2), (457, 1), (641, 1), (767, 1)]
# (joanna) : frequency = 2, posting list: [(458, 2)]
# (radier) : frequency = 1, posting list: [(458, 1)]
# (elmer) : frequency = 4, posting list: [(757, 3), (458, 1)]
# (croy) : frequency = 2, posting list: [(458, 2)]
# (mueller) : frequency = 7, posting list: [(629, 6), (458, 1)]
# (azai) : frequency = 1, posting list: [(458, 1)]
# (leah) : frequency = 1, posting list: [(458, 1)]
# (ernst) : frequency = 1, posting list: [(458, 1)]
# (whet) : frequency = 1, posting list: [(458, 1)]
# (newfangl) : frequency = 1, posting list: [(458, 1)]
# (homer) : frequency = 1, posting list: [(458, 1)]
# (hazel) : frequency = 3, posting list: [(458, 2), (569, 1)]
# (rader) : frequency = 2, posting list: [(458, 2)]
# (benston) : frequency = 2, posting list: [(458, 2)]
# (heartsick) : frequency = 1, posting list: [(458, 1)]
# (hearten) : frequency = 1, posting list: [(458, 1)]
# (sila) : frequency = 2, posting list: [(460, 1), (786, 1)]
# (howard) : frequency = 11, posting list: [(598, 9), (460, 1), (915, 1)]
# (valentin) : frequency = 2, posting list: [(460, 2)]
# (adopte) : frequency = 1, posting list: [(460, 1)]
# (pronoun) : frequency = 1, posting list: [(460, 1)]
# (kinship) : frequency = 1, posting list: [(460, 1)]
# (corey) : frequency = 18, posting list: [(461, 16), (725, 1), (799, 1)]
# (webster) : frequency = 3, posting list: [(461, 1), (845, 1), (905, 1)]
# (downhil) : frequency = 5, posting list: [(461, 4), (478, 1)]
# (ramp) : frequency = 5, posting list: [(461, 4), (807, 1)]
# (cori) : frequency = 1, posting list: [(461, 1)]
# (disobedi) : frequency = 1, posting list: [(461, 1)]
# (disobey) : frequency = 1, posting list: [(461, 1)]
# (jerk) : frequency = 1, posting list: [(461, 1)]
# (halfpip) : frequency = 1, posting list: [(461, 1)]
# (joust) : frequency = 2, posting list: [(461, 1), (618, 1)]
# (unconsol) : frequency = 1, posting list: [(461, 1)]
# (mph) : frequency = 1, posting list: [(461, 1)]
# (mapl) : frequency = 1, posting list: [(462, 1)]
# (phil) : frequency = 10, posting list: [(462, 5), (553, 3), (581, 1), (991, 1)]
# (restaurateur) : frequency = 2, posting list: [(462, 1), (551, 1)]
# (recuper) : frequency = 1, posting list: [(462, 1)]
# (dysfunct) : frequency = 2, posting list: [(462, 1), (671, 1)]
# (vishnuvardhan) : frequency = 8, posting list: [(463, 8)]
# (jagadeesh) : frequency = 3, posting list: [(463, 3)]
# (enlarg) : frequency = 2, posting list: [(463, 1), (973, 1)]
# (mostyn) : frequency = 1, posting list: [(464, 1)]
# (monacl) : frequency = 1, posting list: [(464, 1)]
# (jackeroo) : frequency = 1, posting list: [(464, 1)]
# (bushrang) : frequency = 1, posting list: [(464, 1)]
# (brumbi) : frequency = 1, posting list: [(464, 1)]
# (op) : frequency = 1, posting list: [(464, 1)]
# (mercuri) : frequency = 1, posting list: [(464, 1)]
# (bookstor) : frequency = 3, posting list: [(465, 2), (518, 1)]
# (artifact) : frequency = 1, posting list: [(465, 1)]
# (yorkshir) : frequency = 1, posting list: [(465, 1)]
# (keychain) : frequency = 1, posting list: [(465, 1)]
# (predatori) : frequency = 1, posting list: [(465, 1)]
# (gargoyl) : frequency = 1, posting list: [(465, 1)]
# (pitch) : frequency = 4, posting list: [(465, 1), (631, 1), (767, 1), (808, 1)]
# (wyznowski) : frequency = 4, posting list: [(466, 4)]
# (yamata) : frequency = 2, posting list: [(466, 2)]
# (sulley) : frequency = 20, posting list: [(466, 20)]
# (taser) : frequency = 2, posting list: [(466, 1), (867, 1)]
# (spo) : frequency = 1, posting list: [(466, 1)]
# (analys) : frequency = 2, posting list: [(466, 1), (661, 1)]
# (countdown) : frequency = 1, posting list: [(466, 1)]
# (aztec) : frequency = 2, posting list: [(467, 2)]
# (drip) : frequency = 3, posting list: [(467, 1), (530, 1), (896, 1)]
# (scepter) : frequency = 2, posting list: [(467, 2)]
# (conquest) : frequency = 1, posting list: [(467, 1)]
# (mil) : frequency = 2, posting list: [(467, 2)]
# (máscara) : frequency = 1, posting list: [(467, 1)]
# (hallucinogen) : frequency = 1, posting list: [(467, 1)]
# (mushroom) : frequency = 1, posting list: [(467, 1)]
# (seductress) : frequency = 1, posting list: [(467, 1)]
# (houston) : frequency = 1, posting list: [(468, 1)]
# (traffick) : frequency = 4, posting list: [(685, 2), (468, 1), (953, 1)]
# (flashi) : frequency = 1, posting list: [(468, 1)]
# (improp) : frequency = 1, posting list: [(468, 1)]
# (dian) : frequency = 13, posting list: [(569, 8), (682, 4), (468, 1)]
# (pallon) : frequency = 1, posting list: [(468, 1)]
# (arwood) : frequency = 1, posting list: [(468, 1)]
# (talec) : frequency = 4, posting list: [(468, 4)]
# (endorphin) : frequency = 1, posting list: [(468, 1)]
# (synthes) : frequency = 1, posting list: [(468, 1)]
# (azeck) : frequency = 1, posting list: [(468, 1)]
# (intergalact) : frequency = 2, posting list: [(468, 1), (510, 1)]
# (asid) : frequency = 13, posting list: [(521, 2), (752, 2), (468, 1), (520, 1), (535, 1), (599, 1), (602, 1), (607, 1), (709, 1), (831, 1), (989, 1)]
# (porch) : frequency = 6, posting list: [(669, 3), (469, 1), (530, 1), (887, 1)]
# (intertwin) : frequency = 2, posting list: [(469, 1), (862, 1)]
# (ulsterman) : frequency = 1, posting list: [(469, 1)]
# (belfast) : frequency = 4, posting list: [(469, 4)]
# (quinlan) : frequency = 1, posting list: [(469, 1)]
# (poe) : frequency = 5, posting list: [(471, 3), (548, 1), (592, 1)]
# (ancestor) : frequency = 3, posting list: [(471, 1), (888, 1), (978, 1)]
# (smalltown) : frequency = 1, posting list: [(471, 1)]
# (dir) : frequency = 1, posting list: [(471, 1)]
# (kermit) : frequency = 1, posting list: [(471, 1)]
# (christman) : frequency = 1, posting list: [(471, 1)]
# (del) : frequency = 2, posting list: [(471, 1), (598, 1)]
# (tenney) : frequency = 1, posting list: [(471, 1)]
# (perf) : frequency = 1, posting list: [(471, 1)]
# (heigl) : frequency = 1, posting list: [(471, 1)]
# (timoteo) : frequency = 13, posting list: [(472, 13)]
# (italia) : frequency = 16, posting list: [(472, 16)]
# (inebri) : frequency = 1, posting list: [(472, 1)]
# (elsa) : frequency = 8, posting list: [(797, 4), (472, 3), (518, 1)]
# (perceiv) : frequency = 2, posting list: [(472, 1), (509, 1)]
# (frenziedli) : frequency = 1, posting list: [(472, 1)]
# (chide) : frequency = 2, posting list: [(472, 1), (742, 1)]
# (agitatedli) : frequency = 1, posting list: [(472, 1)]
# (woken) : frequency = 3, posting list: [(472, 1), (771, 1), (895, 1)]
# (unbear) : frequency = 1, posting list: [(472, 1)]
# (abdomen) : frequency = 2, posting list: [(472, 1), (887, 1)]
# (ultrasound) : frequency = 2, posting list: [(472, 1), (809, 1)]
# (stabilis) : frequency = 1, posting list: [(472, 1)]
# (gestur) : frequency = 2, posting list: [(472, 1), (949, 1)]
# (mortuari) : frequency = 4, posting list: [(585, 3), (473, 1)]
# (mortician) : frequency = 3, posting list: [(473, 3)]
# (shishedo) : frequency = 2, posting list: [(473, 2)]
# (gigi) : frequency = 2, posting list: [(473, 2)]
# (deepika) : frequency = 2, posting list: [(474, 2)]
# (fictiti) : frequency = 4, posting list: [(474, 1), (648, 1), (783, 1), (941, 1)]
# (irrit) : frequency = 1, posting list: [(474, 1)]
# (mayilravanan) : frequency = 1, posting list: [(474, 1)]
# (tarl) : frequency = 2, posting list: [(475, 2)]
# (gor) : frequency = 2, posting list: [(475, 2)]
# (tyrann) : frequency = 1, posting list: [(475, 1)]
# (sarm) : frequency = 7, posting list: [(475, 7)]
# (pathway) : frequency = 1, posting list: [(475, 1)]
# (talena) : frequency = 5, posting list: [(475, 5)]
# (scantili) : frequency = 1, posting list: [(475, 1)]
# (barbarian) : frequency = 1, posting list: [(475, 1)]
# (whereupon) : frequency = 3, posting list: [(475, 1), (794, 1), (989, 1)]
# (reacquir) : frequency = 1, posting list: [(475, 1)]
# (summarycrack) : frequency = 1, posting list: [(475, 1)]
# (filmedbondag) : frequency = 1, posting list: [(475, 1)]
# (erotica) : frequency = 1, posting list: [(475, 1)]
# (summari) : frequency = 2, posting list: [(475, 1), (598, 1)]
# (lai) : frequency = 1, posting list: [(476, 1)]
# (erot) : frequency = 2, posting list: [(476, 1), (531, 1)]
# (winsi) : frequency = 2, posting list: [(476, 2)]
# (avers) : frequency = 3, posting list: [(476, 1), (530, 1), (666, 1)]
# (akhil) : frequency = 23, posting list: [(477, 23)]
# (siri) : frequency = 6, posting list: [(477, 6)]
# (valli) : frequency = 6, posting list: [(477, 6)]
# (sonu) : frequency = 19, posting list: [(477, 19)]
# (stubborn) : frequency = 2, posting list: [(477, 1), (974, 1)]
# (mama) : frequency = 9, posting list: [(648, 5), (477, 3), (917, 1)]
# (motorboat) : frequency = 1, posting list: [(477, 1)]
# (catalogu) : frequency = 1, posting list: [(478, 1)]
# (taglin) : frequency = 2, posting list: [(478, 1), (531, 1)]
# (unsupervis) : frequency = 1, posting list: [(479, 1)]
# (melena) : frequency = 1, posting list: [(479, 1)]
# (steer) : frequency = 4, posting list: [(767, 2), (479, 1), (795, 1)]
# (reconstruct) : frequency = 1, posting list: [(480, 1)]
# (ahm) : frequency = 3, posting list: [(480, 1), (693, 1), (712, 1)]
# (robbi) : frequency = 11, posting list: [(624, 10), (480, 1)]
# (taekwondo) : frequency = 5, posting list: [(861, 4), (481, 1)]
# (arbitrari) : frequency = 1, posting list: [(481, 1)]
# (cruelti) : frequency = 1, posting list: [(481, 1)]
# (kenni) : frequency = 1, posting list: [(482, 1)]
# (veech) : frequency = 6, posting list: [(482, 6)]
# (lew) : frequency = 1, posting list: [(482, 1)]
# (lentz) : frequency = 4, posting list: [(482, 4)]
# (gitlo) : frequency = 4, posting list: [(482, 4)]
# (getaway) : frequency = 3, posting list: [(482, 1), (668, 1), (969, 1)]
# (presumpt) : frequency = 1, posting list: [(482, 1)]
# (mamman) : frequency = 10, posting list: [(483, 10)]
# (janardhanan) : frequency = 1, posting list: [(483, 1)]
# (fabric) : frequency = 2, posting list: [(483, 1), (555, 1)]
# (chandran) : frequency = 16, posting list: [(993, 11), (483, 5)]
# (eyesor) : frequency = 1, posting list: [(483, 1)]
# (swaminathan) : frequency = 8, posting list: [(483, 4), (818, 4)]
# (fatherlik) : frequency = 2, posting list: [(483, 1), (555, 1)]
# (dirham) : frequency = 1, posting list: [(483, 1)]
# (cun) : frequency = 2, posting list: [(483, 1), (914, 1)]
# (bhatta) : frequency = 10, posting list: [(483, 10)]
# (ammu) : frequency = 6, posting list: [(483, 6)]
# (kiran) : frequency = 23, posting list: [(726, 13), (483, 9), (924, 1)]
# (pothan) : frequency = 1, posting list: [(483, 1)]
# (cheriyan) : frequency = 1, posting list: [(483, 1)]
# (liquor) : frequency = 3, posting list: [(483, 1), (555, 1), (571, 1)]
# (oval) : frequency = 1, posting list: [(484, 1)]
# (mead) : frequency = 8, posting list: [(484, 4), (918, 4)]
# (lute) : frequency = 4, posting list: [(484, 4)]
# (racial) : frequency = 3, posting list: [(484, 1), (525, 1), (538, 1)]
# (corrin) : frequency = 2, posting list: [(484, 2)]
# (bathtub) : frequency = 6, posting list: [(484, 1), (522, 1), (576, 1), (640, 1), (739, 1), (835, 1)]
# (ryūji) : frequency = 7, posting list: [(485, 7)]
# (takayama) : frequency = 7, posting list: [(485, 7)]
# (reiko) : frequency = 6, posting list: [(485, 6)]
# (asakawa) : frequency = 2, posting list: [(485, 2)]
# (yōichi) : frequency = 4, posting list: [(485, 4)]
# (mitsuo) : frequency = 1, posting list: [(485, 1)]
# (andō) : frequency = 18, posting list: [(485, 18)]
# (videotap) : frequency = 4, posting list: [(485, 3), (645, 1)]
# (mai) : frequency = 9, posting list: [(485, 9)]
# (takano) : frequency = 3, posting list: [(485, 3)]
# (sadako) : frequency = 4, posting list: [(485, 4)]
# (yamamura) : frequency = 2, posting list: [(485, 2)]
# (yoshino) : frequency = 8, posting list: [(485, 8)]
# (intimaci) : frequency = 1, posting list: [(485, 1)]
# (perfectli) : frequency = 5, posting list: [(485, 1), (742, 1), (760, 1), (778, 1), (871, 1)]
# (miyashita) : frequency = 1, posting list: [(485, 1)]
# (clone) : frequency = 11, posting list: [(508, 7), (485, 1), (569, 1), (787, 1), (816, 1)]
# (nam) : frequency = 1, posting list: [(486, 1)]
# (ansaeng) : frequency = 1, posting list: [(486, 1)]
# (monitor) : frequency = 5, posting list: [(767, 2), (486, 1), (587, 1), (862, 1)]
# (morgu) : frequency = 4, posting list: [(646, 2), (486, 1), (537, 1)]
# (ineffect) : frequency = 2, posting list: [(487, 1), (989, 1)]
# (tarzan) : frequency = 11, posting list: [(487, 6), (831, 5)]
# (cheeta) : frequency = 2, posting list: [(487, 2)]
# (jigg) : frequency = 1, posting list: [(487, 1)]
# (tchaikovski) : frequency = 1, posting list: [(487, 1)]
# (juliet) : frequency = 2, posting list: [(487, 1), (971, 1)]
# (narutaki) : frequency = 3, posting list: [(778, 2), (488, 1)]
# (semen) : frequency = 3, posting list: [(488, 3)]
# (android) : frequency = 3, posting list: [(508, 2), (488, 1)]
# (marilyn) : frequency = 3, posting list: [(488, 1), (639, 1), (760, 1)]
# (spab) : frequency = 2, posting list: [(489, 2)]
# (dice) : frequency = 3, posting list: [(489, 1), (741, 1), (932, 1)]
# (worldwid) : frequency = 1, posting list: [(489, 1)]
# (uncut) : frequency = 2, posting list: [(489, 1), (668, 1)]
# (pfister) : frequency = 1, posting list: [(489, 1)]
# (fuck) : frequency = 4, posting list: [(489, 2), (602, 1), (925, 1)]
# (coverag) : frequency = 1, posting list: [(489, 1)]
# (icon) : frequency = 2, posting list: [(489, 1), (507, 1)]
# (commemor) : frequency = 1, posting list: [(489, 1)]
# (monica) : frequency = 2, posting list: [(489, 2)]
# (sieg) : frequency = 6, posting list: [(489, 2), (564, 1), (588, 1), (687, 1), (876, 1)]
# (morrow) : frequency = 2, posting list: [(489, 2)]
# (streeter) : frequency = 1, posting list: [(489, 1)]
# (eleg) : frequency = 1, posting list: [(489, 1)]
# (janet) : frequency = 3, posting list: [(489, 1), (693, 1), (932, 1)]
# (autograph) : frequency = 1, posting list: [(489, 1)]
# (hamper) : frequency = 1, posting list: [(489, 1)]
# (auditorium) : frequency = 1, posting list: [(489, 1)]
# (wyler) : frequency = 2, posting list: [(489, 2)]
# (bab) : frequency = 5, posting list: [(489, 5)]
# (indict) : frequency = 2, posting list: [(489, 1), (753, 1)]
# (privaci) : frequency = 1, posting list: [(489, 1)]
# (lincoln) : frequency = 1, posting list: [(490, 1)]
# (westward) : frequency = 1, posting list: [(490, 1)]
# (opportunist) : frequency = 2, posting list: [(490, 1), (942, 1)]
# (asa) : frequency = 1, posting list: [(490, 1)]
# (barrow) : frequency = 2, posting list: [(490, 2)]
# (obstruct) : frequency = 1, posting list: [(490, 1)]
# (troubleshoot) : frequency = 1, posting list: [(490, 1)]
# (sid) : frequency = 1, posting list: [(490, 1)]
# (campeau) : frequency = 2, posting list: [(490, 2)]
# (poh) : frequency = 6, posting list: [(491, 6)]
# (huat) : frequency = 6, posting list: [(491, 6)]
# (loh) : frequency = 1, posting list: [(491, 1)]
# (siew) : frequency = 5, posting list: [(491, 5)]
# (luan) : frequency = 5, posting list: [(491, 5)]
# (teh) : frequency = 1, posting list: [(491, 1)]
# (seng) : frequency = 18, posting list: [(491, 18)]
# (mei) : frequency = 16, posting list: [(491, 16)]
# (polytechn) : frequency = 2, posting list: [(491, 2)]
# (idaho) : frequency = 1, posting list: [(491, 1)]
# (iren) : frequency = 6, posting list: [(491, 6)]
# (matern) : frequency = 2, posting list: [(491, 1), (917, 1)]
# (keong) : frequency = 7, posting list: [(491, 7)]
# (belittl) : frequency = 2, posting list: [(491, 1), (663, 1)]
# (sanguin) : frequency = 1, posting list: [(491, 1)]
# (toto) : frequency = 10, posting list: [(682, 9), (491, 1)]
# (s) : frequency = 6, posting list: [(491, 6)]
# (overspend) : frequency = 1, posting list: [(491, 1)]
# (membership) : frequency = 1, posting list: [(491, 1)]
# (carton) : frequency = 1, posting list: [(491, 1)]
# (unreason) : frequency = 1, posting list: [(491, 1)]
# (photocopi) : frequency = 1, posting list: [(491, 1)]
# (pek) : frequency = 1, posting list: [(491, 1)]
# (wrongli) : frequency = 3, posting list: [(491, 1), (505, 1), (548, 1)]
# (pinki) : frequency = 13, posting list: [(602, 10), (491, 2), (692, 1)]
# (indign) : frequency = 1, posting list: [(491, 1)]
# (singaporean) : frequency = 1, posting list: [(491, 1)]
# (ricketi) : frequency = 1, posting list: [(492, 1)]
# (stateless) : frequency = 1, posting list: [(492, 1)]
# (stowaway) : frequency = 5, posting list: [(492, 3), (539, 1), (878, 1)]
# (hoist) : frequency = 1, posting list: [(492, 1)]
# (liferaft) : frequency = 1, posting list: [(492, 1)]
# (helm) : frequency = 1, posting list: [(492, 1)]
# (crusoeland) : frequency = 1, posting list: [(492, 1)]
# (uranium) : frequency = 1, posting list: [(492, 1)]
# (deposit) : frequency = 4, posting list: [(492, 1), (608, 1), (891, 1), (923, 1)]
# (flock) : frequency = 4, posting list: [(525, 2), (492, 1), (559, 1)]
# (overthrow) : frequency = 2, posting list: [(492, 1), (989, 1)]
# (unscrupul) : frequency = 3, posting list: [(493, 1), (818, 1), (938, 1)]
# (bottleneck) : frequency = 2, posting list: [(493, 2)]
# (keogh) : frequency = 1, posting list: [(493, 1)]
# (frenchi) : frequency = 3, posting list: [(493, 3)]
# (stranglehold) : frequency = 1, posting list: [(493, 1)]
# (hiram) : frequency = 2, posting list: [(493, 1), (581, 1)]
# (slade) : frequency = 2, posting list: [(493, 1), (494, 1)]
# (collus) : frequency = 1, posting list: [(493, 1)]
# (dimsdal) : frequency = 2, posting list: [(493, 2)]
# (lawman) : frequency = 1, posting list: [(493, 1)]
# (destri) : frequency = 10, posting list: [(493, 5), (581, 5)]
# (confound) : frequency = 2, posting list: [(493, 1), (713, 1)]
# (strap) : frequency = 5, posting list: [(887, 3), (493, 1), (783, 1)]
# (crossfir) : frequency = 2, posting list: [(493, 1), (804, 1)]
# (nan) : frequency = 1, posting list: [(494, 1)]
# (matron) : frequency = 7, posting list: [(798, 6), (494, 1)]
# (noonan) : frequency = 1, posting list: [(494, 1)]
# (genr) : frequency = 4, posting list: [(494, 1), (538, 1), (592, 1), (697, 1)]
# (jenkin) : frequency = 1, posting list: [(495, 1)]
# (lillith) : frequency = 28, posting list: [(495, 28)]
# (roast) : frequency = 2, posting list: [(495, 1), (981, 1)]
# (barron) : frequency = 3, posting list: [(495, 3)]
# (evalu) : frequency = 4, posting list: [(495, 2), (879, 1), (965, 1)]
# (ame) : frequency = 1, posting list: [(495, 1)]
# (subtli) : frequency = 4, posting list: [(835, 2), (495, 1), (576, 1)]
# (hornet) : frequency = 2, posting list: [(495, 1), (676, 1)]
# (cellphon) : frequency = 8, posting list: [(583, 6), (495, 1), (925, 1)]
# (lilith) : frequency = 3, posting list: [(688, 2), (495, 1)]
# (sed) : frequency = 3, posting list: [(502, 2), (495, 1)]
# (rainstorm) : frequency = 2, posting list: [(495, 1), (529, 1)]
# (mockingli) : frequency = 3, posting list: [(495, 1), (640, 1), (888, 1)]
# (burglari) : frequency = 3, posting list: [(496, 1), (621, 1), (918, 1)]
# (kristi) : frequency = 22, posting list: [(496, 22)]
# (rey) : frequency = 3, posting list: [(496, 2), (727, 1)]
# (untouch) : frequency = 1, posting list: [(496, 1)]
# (cleans) : frequency = 2, posting list: [(496, 1), (895, 1)]
# (sage) : frequency = 1, posting list: [(496, 1)]
# (vet) : frequency = 2, posting list: [(496, 1), (590, 1)]
# (meu) : frequency = 1, posting list: [(496, 1)]
# (exorcis) : frequency = 3, posting list: [(496, 1), (653, 1), (805, 1)]
# (handheld) : frequency = 1, posting list: [(496, 1)]
# (chandeli) : frequency = 3, posting list: [(576, 2), (496, 1)]
# (growl) : frequency = 3, posting list: [(949, 2), (496, 1)]
# (roar) : frequency = 2, posting list: [(496, 1), (550, 1)]
# (approxim) : frequency = 1, posting list: [(496, 1)]
# (bloodstain) : frequency = 2, posting list: [(496, 1), (522, 1)]
# (superhuman) : frequency = 5, posting list: [(602, 2), (496, 1), (751, 1), (831, 1)]
# (kirik) : frequency = 3, posting list: [(497, 3)]
# (sorceress) : frequency = 4, posting list: [(497, 2), (653, 2)]
# (karaba) : frequency = 1, posting list: [(497, 1)]
# (cont) : frequency = 1, posting list: [(497, 1)]
# (nuit) : frequency = 1, posting list: [(497, 1)]
# (antholog) : frequency = 1, posting list: [(497, 1)]
# (michel) : frequency = 1, posting list: [(497, 1)]
# (ocelot) : frequency = 1, posting list: [(497, 1)]
# (bénédict) : frequency = 1, posting list: [(497, 1)]
# (galup) : frequency = 1, posting list: [(497, 1)]
# (emeri) : frequency = 27, posting list: [(498, 26), (640, 1)]
# (allanah) : frequency = 6, posting list: [(498, 6)]
# (afterword) : frequency = 1, posting list: [(498, 1)]
# (alannah) : frequency = 3, posting list: [(498, 3)]
# (resturaunt) : frequency = 1, posting list: [(498, 1)]
# (condo) : frequency = 5, posting list: [(498, 5)]
# (cutter) : frequency = 1, posting list: [(498, 1)]
# (unpack) : frequency = 2, posting list: [(498, 1), (521, 1)]
# (allannah) : frequency = 1, posting list: [(498, 1)]
# (alaanh) : frequency = 1, posting list: [(498, 1)]
# (conni) : frequency = 10, posting list: [(498, 7), (514, 1), (813, 1), (928, 1)]
# (statment) : frequency = 1, posting list: [(498, 1)]
# (devorc) : frequency = 1, posting list: [(498, 1)]
# (prision) : frequency = 1, posting list: [(498, 1)]
# (which) : frequency = 3, posting list: [(498, 1), (502, 1), (590, 1)]
# (suceed) : frequency = 1, posting list: [(498, 1)]
# (pete) : frequency = 14, posting list: [(499, 6), (997, 4), (745, 3), (611, 1)]
# (diagnosi) : frequency = 2, posting list: [(499, 1), (682, 1)]
# (jusa) : frequency = 6, posting list: [(499, 6)]
# (vodka) : frequency = 2, posting list: [(499, 1), (807, 1)]
# (kata) : frequency = 5, posting list: [(499, 5)]
# (lapland) : frequency = 2, posting list: [(499, 2)]
# (mombasa) : frequency = 2, posting list: [(499, 2)]
# (finnish) : frequency = 1, posting list: [(499, 1)]
# (sceneri) : frequency = 1, posting list: [(500, 1)]
# (superhero) : frequency = 4, posting list: [(954, 2), (500, 1), (751, 1)]
# (thyssen) : frequency = 2, posting list: [(500, 2)]
# (synthet) : frequency = 2, posting list: [(500, 1), (713, 1)]
# (saboteur) : frequency = 1, posting list: [(500, 1)]
# (gase) : frequency = 1, posting list: [(500, 1)]
# (innumer) : frequency = 1, posting list: [(500, 1)]
# (annihil) : frequency = 1, posting list: [(500, 1)]
# (aggreg) : frequency = 1, posting list: [(500, 1)]
# (ahmedabad) : frequency = 1, posting list: [(501, 1)]
# (gandhi) : frequency = 1, posting list: [(501, 1)]
# (thesi) : frequency = 2, posting list: [(501, 1), (610, 1)]
# (pithawala) : frequency = 4, posting list: [(501, 4)]
# (cyru) : frequency = 4, posting list: [(501, 3), (623, 1)]
# (shernaz) : frequency = 2, posting list: [(501, 2)]
# (parzan) : frequency = 2, posting list: [(501, 2)]
# (dilshad) : frequency = 2, posting list: [(501, 2)]
# (parsi) : frequency = 1, posting list: [(501, 1)]
# (zoroastrian) : frequency = 1, posting list: [(501, 1)]
# (gandhian) : frequency = 1, posting list: [(501, 1)]
# (gujarat) : frequency = 3, posting list: [(501, 2), (649, 1)]
# (pogrom) : frequency = 1, posting list: [(501, 1)]
# (explan) : frequency = 8, posting list: [(821, 3), (501, 1), (543, 1), (602, 1), (726, 1), (877, 1)]
# (downplay) : frequency = 1, posting list: [(501, 1)]
# (rioter) : frequency = 1, posting list: [(501, 1)]
# (corn) : frequency = 6, posting list: [(502, 6)]
# (incharg) : frequency = 1, posting list: [(502, 1)]
# (amudhan) : frequency = 13, posting list: [(502, 13)]
# (vendhan) : frequency = 15, posting list: [(502, 15)]
# (hostel) : frequency = 5, posting list: [(726, 3), (502, 1), (922, 1)]
# (poongavanm) : frequency = 1, posting list: [(502, 1)]
# (poomanandhipuram) : frequency = 3, posting list: [(502, 3)]
# (ambuli) : frequency = 39, posting list: [(502, 39)]
# (poongavanam) : frequency = 1, posting list: [(502, 1)]
# (sengodan) : frequency = 9, posting list: [(502, 9)]
# (sengoden) : frequency = 7, posting list: [(502, 7)]
# (enquir) : frequency = 3, posting list: [(502, 3)]
# (about) : frequency = 2, posting list: [(502, 1), (925, 1)]
# (neanderth) : frequency = 1, posting list: [(502, 1)]
# (till) : frequency = 9, posting list: [(829, 2), (502, 1), (540, 1), (571, 1), (626, 1), (761, 1), (817, 1), (871, 1)]
# (marudhan) : frequency = 3, posting list: [(502, 3)]
# (grandma) : frequency = 11, posting list: [(723, 5), (502, 3), (832, 2), (528, 1)]
# (pic) : frequency = 2, posting list: [(502, 2)]
# (th) : frequency = 1, posting list: [(502, 1)]
# (goat) : frequency = 9, posting list: [(602, 5), (502, 2), (732, 1), (949, 1)]
# (maruthan) : frequency = 6, posting list: [(502, 6)]
# (projector) : frequency = 3, posting list: [(502, 2), (807, 1)]
# (healthili) : frequency = 1, posting list: [(502, 1)]
# (womb) : frequency = 2, posting list: [(502, 2)]
# (checkup) : frequency = 1, posting list: [(502, 1)]
# (venthan) : frequency = 2, posting list: [(502, 2)]
# (tranqualis) : frequency = 2, posting list: [(502, 2)]
# (dehradun) : frequency = 1, posting list: [(502, 1)]
# (vettai) : frequency = 1, posting list: [(502, 1)]
# (thodarum) : frequency = 1, posting list: [(502, 1)]
# (ghajini) : frequency = 1, posting list: [(503, 1)]
# (murugadoss) : frequency = 1, posting list: [(503, 1)]
# (rut) : frequency = 1, posting list: [(503, 1)]
# (kirikalam) : frequency = 5, posting list: [(503, 5)]
# (magician) : frequency = 3, posting list: [(503, 1), (610, 1), (949, 1)]
# (amateurish) : frequency = 1, posting list: [(503, 1)]
# (mermaid) : frequency = 13, posting list: [(519, 6), (865, 4), (503, 2), (896, 1)]
# (velli) : frequency = 15, posting list: [(503, 15)]
# (unfairli) : frequency = 1, posting list: [(503, 1)]
# (unsavouri) : frequency = 1, posting list: [(503, 1)]
# (miscreant) : frequency = 1, posting list: [(503, 1)]
# (collag) : frequency = 1, posting list: [(503, 1)]
# (rucku) : frequency = 1, posting list: [(503, 1)]
# (manivannan) : frequency = 1, posting list: [(503, 1)]
# (pretext) : frequency = 1, posting list: [(503, 1)]
# (thoroughli) : frequency = 2, posting list: [(503, 1), (747, 1)]
# (maapillai) : frequency = 1, posting list: [(503, 1)]
# (torrent) : frequency = 1, posting list: [(503, 1)]
# (slink) : frequency = 1, posting list: [(503, 1)]
# (pictori) : frequency = 1, posting list: [(503, 1)]
# (thru) : frequency = 1, posting list: [(503, 1)]
# (kannan) : frequency = 13, posting list: [(503, 13)]
# (jyoti) : frequency = 2, posting list: [(503, 2)]
# (wonderland) : frequency = 3, posting list: [(708, 2), (503, 1)]
# (whi) : frequency = 1, posting list: [(503, 1)]
# (dignitari) : frequency = 2, posting list: [(503, 1), (648, 1)]
# (bloodedli) : frequency = 1, posting list: [(503, 1)]
# (baddi) : frequency = 2, posting list: [(503, 1), (982, 1)]
# (bhanumati) : frequency = 4, posting list: [(504, 4)]
# (meghana) : frequency = 1, posting list: [(504, 1)]
# (gagana) : frequency = 1, posting list: [(504, 1)]
# (payrol) : frequency = 3, posting list: [(505, 1), (938, 1), (972, 1)]
# (showboat) : frequency = 1, posting list: [(505, 1)]
# (hairdress) : frequency = 1, posting list: [(506, 1)]
# (seren) : frequency = 1, posting list: [(506, 1)]
# (dictatorship) : frequency = 3, posting list: [(507, 2), (989, 1)]
# (indi) : frequency = 1, posting list: [(507, 1)]
# (overpopul) : frequency = 1, posting list: [(508, 1)]
# (colon) : frequency = 3, posting list: [(508, 2), (664, 1)]
# (terraform) : frequency = 1, posting list: [(508, 1)]
# (unfriendli) : frequency = 4, posting list: [(508, 1), (674, 1), (724, 1), (845, 1)]
# (seventi) : frequency = 2, posting list: [(508, 1), (673, 1)]
# (syllibu) : frequency = 3, posting list: [(508, 3)]
# (naomi) : frequency = 5, posting list: [(508, 5)]
# (armitag) : frequency = 27, posting list: [(508, 27)]
# (mccannon) : frequency = 3, posting list: [(508, 3)]
# (superfici) : frequency = 1, posting list: [(508, 1)]
# (replay) : frequency = 1, posting list: [(508, 1)]
# (rené) : frequency = 2, posting list: [(508, 2)]
# (julian) : frequency = 5, posting list: [(508, 5)]
# (moor) : frequency = 6, posting list: [(508, 3), (661, 2), (610, 1)]
# (databank) : frequency = 1, posting list: [(508, 1)]
# ...
# (hinsdal) : frequency = 1, posting list: [(957, 1)]
# (illinoi) : frequency = 1, posting list: [(957, 1)]
# (obi) : frequency = 81, posting list: [(957, 81)]
# (dawkin) : frequency = 2, posting list: [(957, 2)]
# (dissect) : frequency = 1, posting list: [(957, 1)]
# (linger) : frequency = 2, posting list: [(957, 2)]
# (keegan) : frequency = 12, posting list: [(957, 12)]
# (revenu) : frequency = 1, posting list: [(957, 1)]
# (ir) : frequency = 1, posting list: [(957, 1)]
# (missouri) : frequency = 1, posting list: [(957, 1)]
# (urin) : frequency = 1, posting list: [(957, 1)]
# (decreas) : frequency = 1, posting list: [(957, 1)]
# (wateri) : frequency = 1, posting list: [(957, 1)]
# (cadillac) : frequency = 1, posting list: [(957, 1)]
# (inquiri) : frequency = 2, posting list: [(957, 1), (998, 1)]
# (swirv) : frequency = 1, posting list: [(957, 1)]
# (ferryman) : frequency = 2, posting list: [(957, 2)]
# (workday) : frequency = 1, posting list: [(957, 1)]
# (clinch) : frequency = 1, posting list: [(957, 1)]
# (unclinch) : frequency = 1, posting list: [(957, 1)]
# (blain) : frequency = 2, posting list: [(958, 2)]
# (benton) : frequency = 1, posting list: [(958, 1)]
# (refa) : frequency = 3, posting list: [(959, 3)]
# (astari) : frequency = 4, posting list: [(959, 4)]
# (casablanca) : frequency = 1, posting list: [(959, 1)]
# (kuntilanak) : frequency = 1, posting list: [(959, 1)]
# (mikado) : frequency = 1, posting list: [(961, 1)]
# (finac) : frequency = 1, posting list: [(961, 1)]
# (goga) : frequency = 2, posting list: [(962, 2)]
# (palkin) : frequency = 1, posting list: [(962, 1)]
# (undiscov) : frequency = 1, posting list: [(962, 1)]
# (dusya) : frequency = 2, posting list: [(962, 2)]
# (fairbank) : frequency = 1, posting list: [(962, 1)]
# (pickford) : frequency = 1, posting list: [(962, 1)]
# (imit) : frequency = 1, posting list: [(963, 1)]
# (uninhabit) : frequency = 1, posting list: [(964, 1)]
# (yuro) : frequency = 2, posting list: [(964, 2)]
# (backup) : frequency = 1, posting list: [(964, 1)]
# (outcom) : frequency = 1, posting list: [(964, 1)]
# (kayla) : frequency = 2, posting list: [(965, 2)]
# (riptid) : frequency = 1, posting list: [(965, 1)]
# (offshoot) : frequency = 1, posting list: [(965, 1)]
# (widespread) : frequency = 1, posting list: [(965, 1)]
# (tuberculosi) : frequency = 3, posting list: [(965, 2), (996, 1)]
# (tubercular) : frequency = 1, posting list: [(965, 1)]
# (antibodi) : frequency = 2, posting list: [(965, 2)]
# (purifi) : frequency = 1, posting list: [(965, 1)]
# (mwansa) : frequency = 2, posting list: [(966, 2)]
# (shula) : frequency = 1, posting list: [(966, 1)]
# (pepe) : frequency = 4, posting list: [(967, 4)]
# (moko) : frequency = 2, posting list: [(967, 2)]
# (algeria) : frequency = 1, posting list: [(967, 1)]
# (casbah) : frequency = 1, posting list: [(967, 1)]
# (algier) : frequency = 1, posting list: [(967, 1)]
# (unfaz) : frequency = 1, posting list: [(967, 1)]
# (sliman) : frequency = 1, posting list: [(967, 1)]
# (bide) : frequency = 1, posting list: [(967, 1)]
# (stronghold) : frequency = 1, posting list: [(967, 1)]
# (gabi) : frequency = 2, posting list: [(967, 2)]
# (ine) : frequency = 1, posting list: [(967, 1)]
# (algerian) : frequency = 1, posting list: [(967, 1)]
# (mona) : frequency = 6, posting list: [(968, 6)]
# (berglund) : frequency = 1, posting list: [(968, 1)]
# (eurovis) : frequency = 3, posting list: [(968, 3)]
# (poster) : frequency = 1, posting list: [(968, 1)]
# (kikki) : frequency = 1, posting list: [(968, 1)]
# (ph) : frequency = 1, posting list: [(968, 1)]
# (carola) : frequency = 1, posting list: [(968, 1)]
# (transvestit) : frequency = 1, posting list: [(968, 1)]
# (cerebr) : frequency = 1, posting list: [(968, 1)]
# (profici) : frequency = 1, posting list: [(968, 1)]
# (melodifestivalen) : frequency = 1, posting list: [(968, 1)]
# (kraurya) : frequency = 1, posting list: [(969, 1)]
# (rangajji) : frequency = 10, posting list: [(969, 10)]
# (murti) : frequency = 10, posting list: [(969, 6), (975, 4)]
# (subbanna) : frequency = 5, posting list: [(969, 5)]
# (spate) : frequency = 1, posting list: [(969, 1)]
# (conner) : frequency = 5, posting list: [(970, 5)]
# (fuckin) : frequency = 1, posting list: [(970, 1)]
# (alloy) : frequency = 2, posting list: [(970, 2)]
# (muller) : frequency = 3, posting list: [(970, 3)]
# (landmin) : frequency = 1, posting list: [(970, 1)]
# (quip) : frequency = 1, posting list: [(970, 1)]
# (bastard) : frequency = 1, posting list: [(970, 1)]
# (yanke) : frequency = 1, posting list: [(971, 1)]
# (mirbeau) : frequency = 3, posting list: [(971, 3)]
# (riverboat) : frequency = 1, posting list: [(971, 1)]
# (charit) : frequency = 1, posting list: [(971, 1)]
# (leve) : frequency = 2, posting list: [(971, 2)]
# (blacki) : frequency = 1, posting list: [(971, 1)]
# (cuffi) : frequency = 1, posting list: [(971, 1)]
# (esclat) : frequency = 1, posting list: [(971, 1)]
# (torrenti) : frequency = 1, posting list: [(971, 1)]
# (raik) : frequency = 1, posting list: [(972, 1)]
# (cfo) : frequency = 1, posting list: [(972, 1)]
# (lela) : frequency = 2, posting list: [(972, 2)]
# (forin) : frequency = 1, posting list: [(972, 1)]
# (mellow) : frequency = 1, posting list: [(972, 1)]
# (oleg) : frequency = 2, posting list: [(972, 2)]
# (butraskaya) : frequency = 1, posting list: [(972, 1)]
# (sift) : frequency = 1, posting list: [(972, 1)]
# (pornographi) : frequency = 2, posting list: [(972, 1), (986, 1)]
# (masato) : frequency = 1, posting list: [(973, 1)]
# (ayumi) : frequency = 1, posting list: [(973, 1)]
# (zo) : frequency = 3, posting list: [(973, 3)]
# (bringer) : frequency = 1, posting list: [(973, 1)]
# (crosser) : frequency = 1, posting list: [(973, 1)]
# (proport) : frequency = 1, posting list: [(973, 1)]
# (xiaochun) : frequency = 30, posting list: [(974, 30)]
# (prodigi) : frequency = 2, posting list: [(974, 2)]
# (conservatori) : frequency = 2, posting list: [(974, 2)]
# (tutorship) : frequency = 1, posting list: [(974, 1)]
# (chen) : frequency = 1, posting list: [(974, 1)]
# (hui) : frequency = 3, posting list: [(974, 3)]
# (learnt) : frequency = 1, posting list: [(974, 1)]
# (shifeng) : frequency = 1, posting list: [(974, 1)]
# (unmov) : frequency = 1, posting list: [(974, 1)]
# (lin) : frequency = 3, posting list: [(974, 3)]
# (relinquish) : frequency = 1, posting list: [(974, 1)]
# (dharam) : frequency = 4, posting list: [(975, 4)]
# (bandookwala) : frequency = 7, posting list: [(975, 7)]
# (menaka) : frequency = 1, posting list: [(975, 1)]
# (padma) : frequency = 2, posting list: [(975, 2)]
# (munimji) : frequency = 1, posting list: [(975, 1)]
# (panchayat) : frequency = 1, posting list: [(975, 1)]
# (caan) : frequency = 1, posting list: [(977, 1)]
# (blasé) : frequency = 1, posting list: [(977, 1)]
# (overprivileg) : frequency = 1, posting list: [(977, 1)]
# (propens) : frequency = 1, posting list: [(977, 1)]
# (chic) : frequency = 1, posting list: [(977, 1)]
# (cosmet) : frequency = 1, posting list: [(977, 1)]
# (discord) : frequency = 1, posting list: [(977, 1)]
# (calmli) : frequency = 1, posting list: [(977, 1)]
# (oriana) : frequency = 17, posting list: [(978, 17)]
# (zill) : frequency = 5, posting list: [(978, 5)]
# (dimensport) : frequency = 4, posting list: [(978, 4)]
# (nap) : frequency = 1, posting list: [(978, 1)]
# (poindext) : frequency = 3, posting list: [(978, 3)]
# (pim) : frequency = 4, posting list: [(978, 4)]
# (wack) : frequency = 3, posting list: [(978, 3)]
# (lizardi) : frequency = 1, posting list: [(978, 1)]
# (lackey) : frequency = 1, posting list: [(978, 1)]
# (pacifist) : frequency = 1, posting list: [(978, 1)]
# (rebuilt) : frequency = 1, posting list: [(978, 1)]
# (workforc) : frequency = 1, posting list: [(978, 1)]
# (consolingli) : frequency = 1, posting list: [(978, 1)]
# (angecon) : frequency = 1, posting list: [(979, 1)]
# (danish) : frequency = 1, posting list: [(980, 1)]
# (radar) : frequency = 1, posting list: [(980, 1)]
# (jannik) : frequency = 2, posting list: [(980, 2)]
# (overreact) : frequency = 1, posting list: [(980, 1)]
# (statsfængslet) : frequency = 1, posting list: [(980, 1)]
# (krazi) : frequency = 6, posting list: [(981, 6)]
# (spaniel) : frequency = 4, posting list: [(981, 4)]
# (leisur) : frequency = 1, posting list: [(981, 1)]
# (startov) : frequency = 1, posting list: [(981, 1)]
# (driftwood) : frequency = 1, posting list: [(981, 1)]
# (nightmarish) : frequency = 1, posting list: [(981, 1)]
# (vayuputhran) : frequency = 2, posting list: [(982, 2)]
# (jailmat) : frequency = 1, posting list: [(982, 1)]
# (bala) : frequency = 2, posting list: [(982, 2)]
# (sathish) : frequency = 2, posting list: [(982, 2)]
# (vallakottai) : frequency = 3, posting list: [(982, 3)]
# (eswarapandian) : frequency = 3, posting list: [(982, 3)]
# (jameen) : frequency = 1, posting list: [(982, 1)]
# (archriv) : frequency = 1, posting list: [(982, 1)]
# (nachiyar) : frequency = 3, posting list: [(982, 3)]
# (sethupathi) : frequency = 1, posting list: [(982, 1)]
# (veera) : frequency = 1, posting list: [(982, 1)]
# (sangili) : frequency = 1, posting list: [(982, 1)]
# (getup) : frequency = 1, posting list: [(982, 1)]
# (flaherti) : frequency = 1, posting list: [(983, 1)]
# (celtic) : frequency = 9, posting list: [(983, 9)]
# (hungov) : frequency = 1, posting list: [(983, 1)]
# (streetwis) : frequency = 1, posting list: [(983, 1)]
# (derid) : frequency = 1, posting list: [(983, 1)]
# (campi) : frequency = 1, posting list: [(983, 1)]
# (mayer) : frequency = 1, posting list: [(983, 1)]
# (antagonist) : frequency = 2, posting list: [(983, 1), (989, 1)]
# (deion) : frequency = 1, posting list: [(983, 1)]
# (aam) : frequency = 1, posting list: [(984, 1)]
# (mccabe) : frequency = 1, posting list: [(984, 1)]
# (bachelor) : frequency = 1, posting list: [(984, 1)]
# (sofia) : frequency = 10, posting list: [(984, 10)]
# (serrano) : frequency = 1, posting list: [(984, 1)]
# (gianni) : frequency = 1, posting list: [(984, 1)]
# (wallow) : frequency = 1, posting list: [(984, 1)]
# (odditi) : frequency = 1, posting list: [(984, 1)]
# (cryonic) : frequency = 2, posting list: [(984, 2)]
# (salesclerk) : frequency = 1, posting list: [(984, 1)]
# (ailment) : frequency = 1, posting list: [(984, 1)]
# (lucid) : frequency = 4, posting list: [(984, 4)]
# (vanilla) : frequency = 1, posting list: [(984, 1)]
# (incorpor) : frequency = 1, posting list: [(984, 1)]
# (reinsert) : frequency = 1, posting list: [(984, 1)]
# (envis) : frequency = 1, posting list: [(984, 1)]
# (stefano) : frequency = 1, posting list: [(985, 1)]
# (mousi) : frequency = 1, posting list: [(985, 1)]
# (rees) : frequency = 1, posting list: [(985, 1)]
# (rosen) : frequency = 1, posting list: [(985, 1)]
# (unexperienc) : frequency = 1, posting list: [(985, 1)]
# (twine) : frequency = 1, posting list: [(985, 1)]
# (cecili) : frequency = 1, posting list: [(985, 1)]
# (weber) : frequency = 1, posting list: [(985, 1)]
# (focuss) : frequency = 1, posting list: [(985, 1)]
# (bartman) : frequency = 1, posting list: [(985, 1)]
# (rathcabbin) : frequency = 1, posting list: [(986, 1)]
# (tipperari) : frequency = 1, posting list: [(986, 1)]
# (gallagh) : frequency = 2, posting list: [(986, 2)]
# (pint) : frequency = 1, posting list: [(986, 1)]
# (carmel) : frequency = 1, posting list: [(986, 1)]
# (pornograph) : frequency = 1, posting list: [(986, 1)]
# (trucker) : frequency = 1, posting list: [(986, 1)]
# (clarifi) : frequency = 1, posting list: [(986, 1)]
# (gardaí) : frequency = 1, posting list: [(986, 1)]
# (craic) : frequency = 1, posting list: [(986, 1)]
# (neatli) : frequency = 1, posting list: [(986, 1)]
# (hon) : frequency = 1, posting list: [(987, 1)]
# (keung) : frequency = 16, posting list: [(987, 16)]
# (elain) : frequency = 2, posting list: [(987, 2)]
# (biki) : frequency = 5, posting list: [(987, 5)]
# (angelo) : frequency = 5, posting list: [(987, 5)]
# (handov) : frequency = 1, posting list: [(987, 1)]
# (towtruck) : frequency = 1, posting list: [(987, 1)]
# (hovercraft) : frequency = 4, posting list: [(987, 4)]
# (clamp) : frequency = 1, posting list: [(987, 1)]
# (immobilis) : frequency = 1, posting list: [(987, 1)]
# (androcl) : frequency = 6, posting list: [(988, 6)]
# (persecutor) : frequency = 1, posting list: [(988, 1)]
# (aghast) : frequency = 1, posting list: [(988, 1)]
# (boar) : frequency = 2, posting list: [(989, 2)]
# (parasit) : frequency = 1, posting list: [(989, 1)]
# (motherless) : frequency = 1, posting list: [(989, 1)]
# (workhors) : frequency = 1, posting list: [(989, 1)]
# (snowbal) : frequency = 5, posting list: [(989, 5)]
# (windmil) : frequency = 5, posting list: [(989, 5)]
# (cowardli) : frequency = 1, posting list: [(989, 1)]
# (squealer) : frequency = 2, posting list: [(989, 2)]
# (whiski) : frequency = 1, posting list: [(989, 1)]
# (whymper) : frequency = 3, posting list: [(989, 3)]
# (jelli) : frequency = 1, posting list: [(989, 1)]
# (hen) : frequency = 3, posting list: [(989, 3)]
# (glorifi) : frequency = 1, posting list: [(989, 1)]
# (complac) : frequency = 1, posting list: [(990, 1)]
# (anorex) : frequency = 1, posting list: [(990, 1)]
# (malnutrit) : frequency = 1, posting list: [(990, 1)]
# (lesh) : frequency = 1, posting list: [(991, 1)]
# (weir) : frequency = 1, posting list: [(991, 1)]
# (grisman) : frequency = 2, posting list: [(991, 2)]
# (psychedel) : frequency = 1, posting list: [(991, 1)]
# (barncard) : frequency = 1, posting list: [(991, 1)]
# (keyboardist) : frequency = 1, posting list: [(991, 1)]
# (constanten) : frequency = 1, posting list: [(991, 1)]
# (hefner) : frequency = 1, posting list: [(991, 1)]
# (mandolin) : frequency = 1, posting list: [(991, 1)]
# (rippl) : frequency = 1, posting list: [(991, 1)]
# (sora) : frequency = 1, posting list: [(992, 1)]
# (konoha) : frequency = 8, posting list: [(992, 8)]
# (naruto) : frequency = 25, posting list: [(992, 25)]
# (sakura) : frequency = 7, posting list: [(992, 7)]
# (hinata) : frequency = 4, posting list: [(992, 4)]
# (amaru) : frequency = 15, posting list: [(992, 15)]
# (shinnō) : frequency = 14, posting list: [(992, 14)]
# (sensei) : frequency = 2, posting list: [(992, 2)]
# (scapel) : frequency = 1, posting list: [(992, 1)]
# (chakra) : frequency = 8, posting list: [(992, 8)]
# (tsunad) : frequency = 1, posting list: [(992, 1)]
# (kakashi) : frequency = 1, posting list: [(992, 1)]
# (shikamaru) : frequency = 1, posting list: [(992, 1)]
# (shino) : frequency = 2, posting list: [(992, 2)]
# (orochimaru) : frequency = 5, posting list: [(992, 5)]
# (jutsu) : frequency = 4, posting list: [(992, 4)]
# (sasuk) : frequency = 14, posting list: [(992, 14)]
# (jiraiya) : frequency = 2, posting list: [(992, 2)]
# (ancor) : frequency = 1, posting list: [(992, 1)]
# (vantian) : frequency = 1, posting list: [(992, 1)]
# (rasengan) : frequency = 2, posting list: [(992, 2)]
# (chidori) : frequency = 2, posting list: [(992, 2)]
# (shinno) : frequency = 1, posting list: [(992, 1)]
# (senbon) : frequency = 1, posting list: [(992, 1)]
# (cocoon) : frequency = 3, posting list: [(992, 3)]
# (reibi) : frequency = 1, posting list: [(992, 1)]
# (freefal) : frequency = 1, posting list: [(992, 1)]
# (gamabunta) : frequency = 1, posting list: [(992, 1)]
# (puramanayil) : frequency = 1, posting list: [(993, 1)]
# (indira) : frequency = 9, posting list: [(993, 9)]
# (malu) : frequency = 8, posting list: [(993, 8)]
# (sankaran) : frequency = 2, posting list: [(993, 2)]
# (audio) : frequency = 1, posting list: [(994, 1)]
# (filmographi) : frequency = 1, posting list: [(994, 1)]
# (panther) : frequency = 5, posting list: [(995, 5)]
# (overdr) : frequency = 1, posting list: [(995, 1)]
# (gentlemen) : frequency = 1, posting list: [(995, 1)]
# (sawdust) : frequency = 1, posting list: [(997, 1)]
# (leonard) : frequency = 2, posting list: [(997, 2)]
# (moneymak) : frequency = 1, posting list: [(997, 1)]
# (aloysiu) : frequency = 1, posting list: [(998, 1)]
# (reilli) : frequency = 4, posting list: [(998, 4)]
# (texador) : frequency = 2, posting list: [(998, 2)]
# (bosch) : frequency = 1, posting list: [(998, 1)]
# (derrick) : frequency = 1, posting list: [(999, 1)]
# (innat) : frequency = 1, posting list: [(999, 1)]
# (brazenli) : frequency = 1, posting list: [(999, 1)]
# (foursom) : frequency = 1, posting list: [(999, 1)]
# (balan) : frequency = 1, posting list: [(1000, 1)]
# (ooruku) : frequency = 1, posting list: [(1000, 1)]
# (noorup) : frequency = 1, posting list: [(1000, 1)]
# زمان اجرا: 4.766721963882446 ثانیه

# %%
import os
def calculate_statistics_english(df):
    total_tokens = 0
    for index, row in df.iterrows():
        normalized_text = row['stemming_text']
        total_tokens += len(normalized_text)

    total_documents = len(df)
    total_file_size = df['stemming_text'].apply(lambda x: len(x)).sum()
    file_path = "/content/inverted_index_english.txt"
    if os.path.exists(file_path):
      file_size = os.path.getsize(file_path)
    else:
      print("file not found")

    return total_tokens, total_documents, total_file_size,file_size

total_tokens, total_documents, total_file_size, file_size = calculate_statistics_english(df2)
print(f"Total Tokens: {total_tokens}")
print(f"Total Documents: {total_documents}")
print(f"Total File Size: {total_file_size} bytes")
print(f"The size of English inverted index file: {file_size} bytes")
# Out:
# Total Tokens: 7360226
# Total Documents: 42303
# Total File Size: 7360226 bytes
# The size of English inverted index file: 1804880 bytes

# %%
english_terms_binary = create_terms_binary(english_inverted_index)

# %%
def process_term_in_query_english(term):
  tokenized = tokenize_english(term)
  normalized = normalize_english_text(tokenized)
  stem = stem_english(normalized)

  return stem

# %%
def boolean_retrieval(terms_binary, terms, operators):


  length_of_values = max(len(value) for value in terms_binary.values())


  cur_term = terms[0]
  is_not = 0

  print('term: ', cur_term)

  if cur_term.startswith('!'):
    cur_term = cur_term[1:]
    is_not = 1

  processed_term = process_term_in_query_english(cur_term)[0]
  print('processed term : ', processed_term)

  if processed_term in terms_binary:
    term_binary = terms_binary.get(processed_term, '')
    term_binary = ''.join(map(str, term_binary))
  else:
    term_binary = '0'.zfill(length_of_values)
    print('(not found)')

  if is_not == 1:
    term_binary = ''.join(['1' if bit == '0' else '0' for bit in term_binary])
    print('(NOT)')

  print('term binary : ', term_binary)

  result = term_binary


  for i in range(1, len(terms)):
      is_not = 0
      term = terms[i]
      operator = operators[i - 1]
      print('term : ', term)

      if term.startswith('!'):
        term = term[1:]
        is_not = 1

      processed_term = process_term_in_query_persian(term)[0]

      print('processed term : ', processed_term)


      if processed_term in terms_binary:
        term_binary = terms_binary.get(processed_term, '')
        term_binary = ''.join(map(str, term_binary))
      else:
        term_binary = '0'.zfill(length_of_values)
        print('(not found)')

      if is_not == 1:
        term_binary = ''.join(['1' if bit == '0' else '0' for bit in term_binary])
        print('(NOT)')

      print('term binary : ', term_binary)

      if operator == '+':
          result = "".join(['1' if a == '1' or b == '1' else '0' for a, b in zip(result, term_binary)])
      elif operator == '.':
          result = "".join(['1' if a == '1' and b == '1' else '0' for a, b in zip(result, term_binary)])

  document_numbers = [i + 1 for i, bit in enumerate(result) if bit == '1']

  print("Result:", result)
  print("Document Numbers:", document_numbers)

  return result, document_numbers

# %%
def english_query_processing(query):

  pattern = r'[\w!]+|[\+\.\*]'
  matches = re.findall(pattern, query)

  terms = []
  operators = []

  for match in matches:
      if match in ('+', '.'):
          operators.append(match)
      else:
          terms.append(match)

  print("List of terms:", terms)
  print("List of operators:", operators)

  return terms, operators

# %%
query = input("Enter query ... : ")
print(query)
# Out:
# Enter query ... : jobless+unemployment+work
# jobless+unemployment+work

# %%
terms, operators = english_query_processing(query)
result, document_numbers = boolean_retrieval(english_terms_binary, terms, operators)
# Out:
# List of terms: ['jobless', 'unemployment', 'work']
# List of operators: ['+', '+']
# term:  jobless
# processed term :  jobless
# term binary :  100000000000000000000000000000000000000000000000000000
# term :  unemployment
# processed term :  unemploy
# term binary :  110000000000000000000000000000000000000000000000000000
# term :  work
# processed term :  work
# term binary :  111111100000000000000000000000000000000000000000000000
# Result: 111111100000000000000000000000000000000000000000000000
# Document Numbers: [1, 2, 3, 4, 5, 6, 7]

# %%
file_path = "english_queries.txt"

query_number = "1"

result_list = [str(item) for item in document_numbers]

result_list_str = ','.join(result_list)


with open(file_path, 'w') as file:
    file.write(query_number + ',')
    file.write(result_list_str)

# %%
query_number = "13"

result_list = [str(item) for item in document_numbers]

result_list_str = ','.join(result_list)

with open(file_path, 'a') as file:
    file.write('\n')
    file.write(query_number + ',')
    file.write(result_list_str)
